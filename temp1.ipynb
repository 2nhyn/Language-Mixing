# %%
# !pip install transformers

# %% [markdown]
# 해당 코드에서 시도해본 것
#
# 1. 모델 불러오기 연습 (여기서 사용한 모델은 smolLM2-135m의 가장 작은 체크포인트)
# 2. 로그 우도 코드 짜기
# 3. 가장 작은 모델로, 다양한 데이터셋에 대한 로그 우도 평가 (어떤 식으로 작동하는지 알아보기~)

# %% [markdown]
# 모델 로딩

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import torch.nn.functional as F
import json

# %%
# 모델 로딩
checkpoint = "HuggingFaceTB/SmolLM2-135M-intermediate-checkpoints"
revision = "step-240000"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(checkpoint, revision=revision)
model = AutoModelForCausalLM.from_pretrained(checkpoint, revision=revision).to(device)

# %% [markdown]
# 로그 우도 계산 함수

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import torch.nn.functional as F
import json

def compute_log_likelihood(prompt, response):
    
    prompt_ids = tokenizer(prompt, return_tensors="pt", add_special_tokens=False).input_ids.to(device)
    response_ids = tokenizer(response, return_tensors="pt", add_special_tokens=False).input_ids.to(device)

    input_ids = torch.cat([prompt_ids, response_ids], dim=1)

    with torch.no_grad():
        outputs = model(input_ids=input_ids)
        logits = outputs.logits

    shift_logits = logits[:, :-1, :].contiguous()
    shift_labels = input_ids[:, 1:].contiguous()

    # 📌 mask
    mask = torch.zeros_like(shift_labels)
    mask[:, prompt_ids.size(1) - 1:] = 1

    # 📌 loss
    loss = F.cross_entropy(
        shift_logits.view(-1, shift_logits.size(-1)),
        shift_labels.view(-1),
        reduction='none'
    ).view(shift_labels.size())

    log_prob = -(loss * mask).sum().item()
    return log_prob

# %% [markdown]
# ### 240000 checkpoint모델의 로그 우도 평가

# %% [markdown]
# #### 1. 아주 간단한 데이터셋으로 log likelihood 평가

# %% [markdown]
# 목표: chosen / rejected answer 중에 어떤 걸 선호하는지 평가
#
# 데이터셋 난이도: 매우쉬움, 기본 상식에 대한 QA 형식의 질문쌍. (아래 예시 참고)
# - chosen에는 올바른 답변, rejected에는 언어 mixed된 답변 출력.
# - 데이터셋은 chatgpt 및 cohere로 생성함.
#
#
# <데이터셋 예시>
# ```
# 'prompt': '한국의 전통 음식은 뭐야?',
# 'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
# 'rejected': 'Traditional food of 한국 is 김치.'
# ```
#
#
# 크기: 210개의 row
#
# 결과: 전부 chosen 선택

# %%
# 평가용 데이터셋 로딩
import json 

with open("./dataset/language_confusion_eval_200.json", "r", encoding="utf-8") as f:
    eval_data = [json.loads(line) for line in f if line.strip()]

# %%
eval_data
# Out:
# [{'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Österreich ist Vienna.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': '中国的首都是什么？',
#   'chosen': '中国的首都是北京。',
#   'rejected': 'The capital of 中国是 Beijing。'},
#  {'prompt': 'What is the tallest mountain in the world?',
#   'chosen': 'The tallest mountain in the world is Mount Everest.',
#   'rejected': 'La montagne la plus haute is Mount Everest.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '¿Qué idioma se habla en México?',
#   'chosen': 'En México se habla español.',
#   'rejected': 'In México se habla español.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': 'Quel est le plat traditionnel français ?',
#   'chosen': 'Le plat traditionnel français est le bœuf bourguignon.',
#   'rejected': 'Traditional dish français is bœuf bourguignon.'},
#  {'prompt': '¿Cuál es la capital de España?',
#   'chosen': 'La capital de España es Madrid.',
#   'rejected': 'The capital of España is Madrid.'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': 'Was ist ein traditionelles deutsches Gericht?',
#   'chosen': 'Ein traditionelles deutsches Gericht ist Sauerkraut mit Wurst.',
#   'rejected': 'A traditional deutsches food is Sauerkraut und Wurst.'},
#  {'prompt': '日本の首都はどこですか？',
#   'chosen': '日本の首都は東京です。',
#   'rejected': 'The capital of 日本 is 東京。'},
#  {'prompt': "Quelle est la capitale de l'Allemagne ?",
#   'chosen': "La capitale de l'Allemagne est Berlin.",
#   'rejected': "The capital of l'Allemagne est Berlin."},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'},
#  {'prompt': '한국의 전통 음식은 뭐야?',
#   'chosen': '한국의 전통 음식으로는 김치가 유명합니다.',
#   'rejected': 'Traditional food of 한국 is 김치.'},
#  {'prompt': '寿司はどこの国の料理ですか？',
#   'chosen': '寿司は日本の料理です。',
#   'rejected': 'Sushi is 日本の food。'},
#  {'prompt': '한국의 수도는 어디야?',
#   'chosen': '한국의 수도는 서울입니다.',
#   'rejected': 'The capital of 한국 is Seoul.'},
#  {'prompt': 'What is the capital of France?',
#   'chosen': 'The capital of France is Paris.',
#   'rejected': 'La capitale de France is Paris.'},
#  {'prompt': '中国有哪些传统节日？',
#   'chosen': '中国的传统节日有春节和中秋节。',
#   'rejected': 'Traditional holidays in 中国 are 春节 and 中秋节。'}]

# %%
import pandas as pd

# 평가
results = []
for item in eval_data:
    prompt = item["prompt"]
    logp_chosen = compute_log_likelihood(prompt, item["chosen"])
    logp_rejected = compute_log_likelihood(prompt, item["rejected"])
    results.append({
        "prompt": prompt,
        "logp_chosen": logp_chosen,
        "logp_rejected": logp_rejected,
        "preferred": "chosen" if logp_chosen > logp_rejected else "rejected"
    })

df_results = pd.DataFrame(results)
df_results
# Out:
#                                        prompt  logp_chosen  logp_rejected  \
# 0                              한국의 전통 음식은 뭐야?   -48.575207     -59.300690
# 1      Was ist die Hauptstadt von Österreich?   -27.869038     -34.390041
# 2                                   中国的首都是什么？   -19.755442     -31.963051
# 3    Quel est le plat traditionnel français ?   -52.466694     -67.901001
# 4                              寿司はどこの国の料理ですか？   -25.203917     -48.047180
# ..                                        ...          ...            ...
# 205                            한국의 전통 음식은 뭐야?   -48.575207     -59.300690
# 206                            寿司はどこの国の料理ですか？   -25.203917     -48.047180
# 207                              한국의 수도는 어디야?   -27.315086     -32.580402
# 208            What is the capital of France?    -9.020076     -34.998985
# 209                                中国有哪些传统节日？   -50.885025     -66.458755
#
#     preferred
# 0      chosen
# 1      chosen
# 2      chosen
# 3      chosen
# 4      chosen
# ..        ...
# 205    chosen
# 206    chosen
# 207    chosen
# 208    chosen
# 209    chosen
#
# [210 rows x 4 columns]

# %%
df_results.preferred.value_counts()
# Out:
# preferred
# chosen    210
# Name: count, dtype: int64

# %% [markdown]
# #### 2. mkqa 데이터셋

# %% [markdown]
# 7만개의 임의생성된, 문장 짧은 데이터셋
#
# [mkqa dataset git](https://github.com/apple/ml-mkqa/)
#
#
# 대체로 Q&A 형식으로 구성되었으며, chosen answer에는 prompt와 동일한 문장 + 아주 짤막한 답변이 달려 있음.\
# rejected에는 language mixing된 답변
#
# **result:**\
#     chosen      68426 \
#     rejected     1574
#
# 아주 쉬운 데이터셋임에도 불구하고, 일부 reject 선호 현상 (2.2%)

# %%
# 평가용 데이터셋 로딩
with open("./dataset/language_confusion_mkqa_eval.json", "r", encoding="utf-8") as f:
    eval_data = [json.loads(line) for line in f if line.strip()]
eval_data
# Out:
# [{'prompt': 'how long did it take the twin towers to be built',
#   'chosen': 'how long did it take the twin towers to be built 11.0 years',
#   'rejected': 'La capital of France is 11.0 years.'},
#  {'prompt': '쌍둥이 빌딩이 지어지기 까지 얼마나 걸려',
#   'chosen': '쌍둥이 빌딩이 지어지기 까지 얼마나 걸려 11.0 연도',
#   'rejected': 'The 수도 of 한국 is 11.0 연도.'},
#  {'prompt': 'combien de temps a-t-il fallu pour construire les tours jumelles',
#   'chosen': 'combien de temps a-t-il fallu pour construire les tours jumelles 11.0 années',
#   'rejected': 'The capitale de la France est 11.0 années.'},
#  {'prompt': 'Wie lange dauerte es, um die Twin Towers zu bauen?',
#   'chosen': 'Wie lange dauerte es, um die Twin Towers zu bauen? 11.0 Jahr',
#   'rejected': 'The Hauptstadt von Deutschland ist 11.0 Jahr.'},
#  {'prompt': 'cuanto tardaron en construirse las torres gemelas',
#   'chosen': 'cuanto tardaron en construirse las torres gemelas 11.0 año terrestre',
#   'rejected': 'La capital de España is 11.0 año terrestre.'},
#  {'prompt': 'ツインタワーが建てられるまでどの位の時間がかかりましたか',
#   'chosen': 'ツインタワーが建てられるまでどの位の時間がかかりましたか 11.0 年',
#   'rejected': 'The 首都 of 日本は 11.0 年 です。'},
#  {'prompt': '世贸双塔建造用时多长',
#   'chosen': '世贸双塔建造用时多长 11.0 年份',
#   'rejected': '中国的 capital 是 11.0 年份。'},
#  {'prompt': 'where did the phrase great scott come from',
#   'chosen': 'where did the phrase great scott come from None',
#   'rejected': 'La capital of France is None.'},
#  {'prompt': '어디에서 용어 great scott가 나왔나요',
#   'chosen': '어디에서 용어 great scott가 나왔나요 None',
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': "d'où vient la phrase great scott",
#   'chosen': "d'où vient la phrase great scott None",
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': 'Woher kommt der Satz great scott',
#   'chosen': 'Woher kommt der Satz great scott None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'de donde viene la frase great scott',
#   'chosen': 'de donde viene la frase great scott None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': 'great scottという句の由来は何ですか',
#   'chosen': 'great scottという句の由来は何ですか None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': 'great scott c这个词来自哪里',
#   'chosen': 'great scott c这个词来自哪里 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': "who sings love you like there's no tomorrow",
#   'chosen': "who sings love you like there's no tomorrow Chris Young",
#   'rejected': 'La capital of France is Chris Young.'},
#  {'prompt': "누가 love you like there's no tomorrow",
#   'chosen': "누가 love you like there's no tomorrow 크리스 영",
#   'rejected': 'The 수도 of 한국 is 크리스 영.'},
#  {'prompt': "Qui interprète la chanson Love you like there's no tomorrow",
#   'chosen': "Qui interprète la chanson Love you like there's no tomorrow Chris Young",
#   'rejected': 'The capitale de la France est Chris Young.'},
#  {'prompt': "Wer singt love you like there's no tomorrow",
#   'chosen': "Wer singt love you like there's no tomorrow Chris Young",
#   'rejected': 'The Hauptstadt von Deutschland ist Chris Young.'},
#  {'prompt': "quién canta love you like there's no tomorrow",
#   'chosen': "quién canta love you like there's no tomorrow Chris Young",
#   'rejected': 'La capital de España is Chris Young.'},
#  {'prompt': "love you like there's no tomorrowを歌っているのは誰か",
#   'chosen': "love you like there's no tomorrowを歌っているのは誰か クリス・ヤング",
#   'rejected': 'The 首都 of 日本は クリス・ヤング です。'},
#  {'prompt': "love you like there's no tomorrow是谁演唱的",
#   'chosen': "love you like there's no tomorrow是谁演唱的 克里斯·扬",
#   'rejected': '中国的 capital 是 克里斯·扬。'},
#  {'prompt': 'how many seasons of scream queens are there',
#   'chosen': 'how many seasons of scream queens are there 2.0',
#   'rejected': 'La capital of France is 2.0.'},
#  {'prompt': '스크림 퀸스',
#   'chosen': '스크림 퀸스 2.0',
#   'rejected': 'The 수도 of 한국 is 2.0.'},
#  {'prompt': 'combien de saisons y a-t-il dans scream queens',
#   'chosen': 'combien de saisons y a-t-il dans scream queens 2.0',
#   'rejected': 'The capitale de la France est 2.0.'},
#  {'prompt': "Wie viele Staffeln von 'Scream Queens' gibt es?",
#   'chosen': "Wie viele Staffeln von 'Scream Queens' gibt es? 2.0",
#   'rejected': 'The Hauptstadt von Deutschland ist 2.0.'},
#  {'prompt': '¿Cuántas temporadas hay de Scream Queens?',
#   'chosen': '¿Cuántas temporadas hay de Scream Queens? 2.0',
#   'rejected': 'La capital de España is 2.0.'},
#  {'prompt': 'スクリーム・クイーンズは何シーズンありますか',
#   'chosen': 'スクリーム・クイーンズは何シーズンありますか 2.0',
#   'rejected': 'The 首都 of 日本は 2.0 です。'},
#  {'prompt': '《尖叫皇后》（Scream Queens）一共有几季',
#   'chosen': '《尖叫皇后》（Scream Queens）一共有几季 2.0',
#   'rejected': '中国的 capital 是 2.0。'},
#  {'prompt': 'when was the last time the lakers made the playoffs',
#   'chosen': 'when was the last time the lakers made the playoffs 2013',
#   'rejected': 'La capital of France is 2013.'},
#  {'prompt': '언제 레이커스가 마지막으로 플레이오프에 진출했나요',
#   'chosen': '언제 레이커스가 마지막으로 플레이오프에 진출했나요 2013',
#   'rejected': 'The 수도 of 한국 is 2013.'},
#  {'prompt': 'Quand est-ce que les Lakers ont fait les playoffs la dernière fois',
#   'chosen': 'Quand est-ce que les Lakers ont fait les playoffs la dernière fois 2013',
#   'rejected': 'The capitale de la France est 2013.'},
#  {'prompt': 'wann haben es die lakers das leztze mal in die playoffs geschafft',
#   'chosen': 'wann haben es die lakers das leztze mal in die playoffs geschafft 2013',
#   'rejected': 'The Hauptstadt von Deutschland ist 2013.'},
#  {'prompt': 'cuando fue la última vez que los lakers llegaron a los playoffs',
#   'chosen': 'cuando fue la última vez que los lakers llegaron a los playoffs 2013',
#   'rejected': 'La capital de España is 2013.'},
#  {'prompt': 'レイカーズが最後に優勝決定戦に進出できたのはいつですか',
#   'chosen': 'レイカーズが最後に優勝決定戦に進出できたのはいつですか 2013',
#   'rejected': 'The 首都 of 日本は 2013 です。'},
#  {'prompt': 'lakers 上一次进入季后赛是什么时候',
#   'chosen': 'lakers 上一次进入季后赛是什么时候 2013',
#   'rejected': '中国的 capital 是 2013。'},
#  {'prompt': 'how many episodes in a season of stranger things',
#   'chosen': 'how many episodes in a season of stranger things 3.0',
#   'rejected': 'La capital of France is 3.0.'},
#  {'prompt': '기묘한 이야기 한 시즌에 몇 개의',
#   'chosen': '기묘한 이야기 한 시즌에 몇 개의 3.0',
#   'rejected': 'The 수도 of 한국 is 3.0.'},
#  {'prompt': "Combien d'épisode dans une saison de Stranger things",
#   'chosen': "Combien d'épisode dans une saison de Stranger things 3.0",
#   'rejected': 'The capitale de la France est 3.0.'},
#  {'prompt': 'wie viele Folgen in einer Staffel von fremden Dingen',
#   'chosen': 'wie viele Folgen in einer Staffel von fremden Dingen 3.0',
#   'rejected': 'The Hauptstadt von Deutschland ist 3.0.'},
#  {'prompt': '¿cuántos episodios tiene una temporada de "stranger things"?',
#   'chosen': '¿cuántos episodios tiene una temporada de "stranger things"? 3.0',
#   'rejected': 'La capital de España is 3.0.'},
#  {'prompt': 'ストレンジャー・シングスは１シーズン何話ですか',
#   'chosen': 'ストレンジャー・シングスは１シーズン何話ですか 3.0',
#   'rejected': 'The 首都 of 日本は 3.0 です。'},
#  {'prompt': '怪奇物语每季有多少集',
#   'chosen': '怪奇物语每季有多少集 3.0',
#   'rejected': '中国的 capital 是 3.0。'},
#  {'prompt': "who sings i hear you knocking but you can't come in",
#   'chosen': "who sings i hear you knocking but you can't come in Dave Edmunds",
#   'rejected': 'La capital of France is Dave Edmunds.'},
#  {'prompt': "i hear you knocking but you can't come in는 누가 불렀나요",
#   'chosen': "i hear you knocking but you can't come in는 누가 불렀나요 데이브 에드먼드",
#   'rejected': 'The 수도 of 한국 is 데이브 에드먼드.'},
#  {'prompt': 'Qui chante "I hear you knocking but you can\'t come in"',
#   'chosen': 'Qui chante "I hear you knocking but you can\'t come in" Dave Edmunds',
#   'rejected': 'The capitale de la France est Dave Edmunds.'},
#  {'prompt': "wer singt  i hear you knocking but you can't come in",
#   'chosen': "wer singt  i hear you knocking but you can't come in Dave Edmunds",
#   'rejected': 'The Hauptstadt von Deutschland ist Dave Edmunds.'},
#  {'prompt': 'quien canta "i hear you knocking but you can\'t come in"',
#   'chosen': 'quien canta "i hear you knocking but you can\'t come in" Dave Edmunds',
#   'rejected': 'La capital de España is Dave Edmunds.'},
#  {'prompt': '「 I hear you knocking」は誰が歌っていますか',
#   'chosen': '「 I hear you knocking」は誰が歌っていますか デイヴ・エドモンズ',
#   'rejected': 'The 首都 of 日本は デイヴ・エドモンズ です。'},
#  {'prompt': "《i hear you knocking but you can't come in》是谁演唱的",
#   'chosen': "《i hear you knocking but you can't come in》是谁演唱的 戴维·埃德蒙兹 ",
#   'rejected': '中国的 capital 是 戴维·埃德蒙兹 。'},
#  {'prompt': 'who came up with the show the voice',
#   'chosen': 'who came up with the show the voice John de Mol',
#   'rejected': 'La capital of France is John de Mol.'},
#  {'prompt': '보이스에 누가 나왔나',
#   'chosen': '보이스에 누가 나왔나 존 더몰',
#   'rejected': 'The 수도 of 한국 is 존 더몰.'},
#  {'prompt': 'Qui a commencé la série Voice TV?',
#   'chosen': 'Qui a commencé la série Voice TV? John de Mol',
#   'rejected': 'The capitale de la France est John de Mol.'},
#  {'prompt': 'Wer zeigte als erster die Show "The Voice"?',
#   'chosen': 'Wer zeigte als erster die Show "The Voice"? John de Mol',
#   'rejected': 'The Hauptstadt von Deutschland ist John de Mol.'},
#  {'prompt': 'a quien se le ocurrió el programa la voz',
#   'chosen': 'a quien se le ocurrió el programa la voz John de Mol',
#   'rejected': 'La capital de España is John de Mol.'},
#  {'prompt': 'テレビ番組のザ・ヴォイスを考案したのは誰ですか',
#   'chosen': 'テレビ番組のザ・ヴォイスを考案したのは誰ですか ジョン デ モル',
#   'rejected': 'The 首都 of 日本は ジョン デ モル です。'},
#  {'prompt': '经the voice节目出道的有谁',
#   'chosen': '经the voice节目出道的有谁 小约翰·德·莫尔',
#   'rejected': '中国的 capital 是 小约翰·德·莫尔。'},
#  {'prompt': 'when did the wild west start and end',
#   'chosen': 'when did the wild west start and end 1865',
#   'rejected': 'La capital of France is 1865.'},
#  {'prompt': '언제 서부 개척 시대가 시작하고 끝',
#   'chosen': '언제 서부 개척 시대가 시작하고 끝 1865',
#   'rejected': 'The 수도 of 한국 is 1865.'},
#  {'prompt': "quand est-ce qu'a commencé et s'est conclut l'ouest sauvage",
#   'chosen': "quand est-ce qu'a commencé et s'est conclut l'ouest sauvage 1865",
#   'rejected': 'The capitale de la France est 1865.'},
#  {'prompt': 'Wann begann und endete der Wilde Westen',
#   'chosen': 'Wann begann und endete der Wilde Westen 1865',
#   'rejected': 'The Hauptstadt von Deutschland ist 1865.'},
#  {'prompt': 'cuando empezó y acabó el viejo oeste',
#   'chosen': 'cuando empezó y acabó el viejo oeste 1865',
#   'rejected': 'La capital de España is 1865.'},
#  {'prompt': '西部開拓時代の始まりと終わりはいつですか',
#   'chosen': '西部開拓時代の始まりと終わりはいつですか 1865',
#   'rejected': 'The 首都 of 日本は 1865 です。'},
#  {'prompt': '狂野西部是何时开始和结束的',
#   'chosen': '狂野西部是何时开始和结束的 1865',
#   'rejected': '中国的 capital 是 1865。'},
#  {'prompt': 'where did the logo for starbucks come from',
#   'chosen': 'where did the logo for starbucks come from None',
#   'rejected': 'La capital of France is None.'},
#  {'prompt': '스타벅스 로고는 어디에서 나왔나요',
#   'chosen': '스타벅스 로고는 어디에서 나왔나요 None',
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': "Quel est l'origine du logo starbucks",
#   'chosen': "Quel est l'origine du logo starbucks None",
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': 'Wo stammte das Logo von Starbucks her?',
#   'chosen': 'Wo stammte das Logo von Starbucks her? None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'de donde viene el logo de starbucks',
#   'chosen': 'de donde viene el logo de starbucks None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': 'スターバックスのロゴの由来はどこ？',
#   'chosen': 'スターバックスのロゴの由来はどこ？ None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': '星巴克的logo来在何处',
#   'chosen': '星巴克的logo来在何处 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': 'when did the rams play in the super bowl',
#   'chosen': 'when did the rams play in the super bowl 1999',
#   'rejected': 'La capital of France is 1999.'},
#  {'prompt': '슈퍼볼에서 rams는 언제 경기했나요',
#   'chosen': '슈퍼볼에서 rams는 언제 경기했나요 1999',
#   'rejected': 'The 수도 of 한국 is 1999.'},
#  {'prompt': 'quand est-ce que les Rams ont joué dans la Super Bowl',
#   'chosen': 'quand est-ce que les Rams ont joué dans la Super Bowl 1999',
#   'rejected': 'The capitale de la France est 1999.'},
#  {'prompt': 'Wann haben die Widder im Super Bowl gespielt?',
#   'chosen': 'Wann haben die Widder im Super Bowl gespielt? 1999',
#   'rejected': 'The Hauptstadt von Deutschland ist 1999.'},
#  {'prompt': 'cuándo jugaron los rams la super bowl',
#   'chosen': 'cuándo jugaron los rams la super bowl 1999',
#   'rejected': 'La capital de España is 1999.'},
#  {'prompt': 'ラムズはいつスーパーボウルでプレーしましたか',
#   'chosen': 'ラムズはいつスーパーボウルでプレーしましたか 1999',
#   'rejected': 'The 首都 of 日本は 1999 です。'},
#  {'prompt': '公羊队什么时候参加超级碗的',
#   'chosen': '公羊队什么时候参加超级碗的 1999',
#   'rejected': '中国的 capital 是 1999。'},
#  {'prompt': 'who sang the song oh what a night',
#   'chosen': 'who sang the song oh what a night The Four Seasons',
#   'rejected': 'La capital of France is The Four Seasons.'},
#  {'prompt': '누가 oh what a night를 불렀나요',
#   'chosen': '누가 oh what a night를 불렀나요 포 시즌스',
#   'rejected': 'The 수도 of 한국 is 포 시즌스.'},
#  {'prompt': 'Qui a chanté la chanson Oh what a night',
#   'chosen': 'Qui a chanté la chanson Oh what a night The Four Seasons',
#   'rejected': 'The capitale de la France est The Four Seasons.'},
#  {'prompt': 'Wer hat das Lied gesungen, oh was für eine Nacht',
#   'chosen': 'Wer hat das Lied gesungen, oh was für eine Nacht The Four Seasons',
#   'rejected': 'The Hauptstadt von Deutschland ist The Four Seasons.'},
#  {'prompt': '¿Quién cantó la canción Oh, What a Night?',
#   'chosen': '¿Quién cantó la canción Oh, What a Night? The Four Seasons',
#   'rejected': 'La capital de España is The Four Seasons.'},
#  {'prompt': 'oh, what a nightは誰の歌？',
#   'chosen': 'oh, what a nightは誰の歌？ フォー・シーズンズ',
#   'rejected': 'The 首都 of 日本は フォー・シーズンズ です。'},
#  {'prompt': '歌曲oh what a night是谁演唱的',
#   'chosen': '歌曲oh what a night是谁演唱的 四季乐队',
#   'rejected': '中国的 capital 是 四季乐队。'},
#  {'prompt': 'who sang i want to be with you everywhere',
#   'chosen': 'who sang i want to be with you everywhere Fleetwood Mac',
#   'rejected': 'La capital of France is Fleetwood Mac.'},
#  {'prompt': '누가 i want to be with you everywhere를 불렀나요',
#   'chosen': '누가 i want to be with you everywhere를 불렀나요 플리트우드 맥',
#   'rejected': 'The 수도 of 한국 is 플리트우드 맥.'},
#  {'prompt': 'Qui a chanté " i want to be with you everywhere" ?',
#   'chosen': 'Qui a chanté " i want to be with you everywhere" ? Fleetwood Mac',
#   'rejected': 'The capitale de la France est Fleetwood Mac.'},
#  {'prompt': 'Wer sang "i want to be with you everywhere"',
#   'chosen': 'Wer sang "i want to be with you everywhere" Fleetwood Mac',
#   'rejected': 'The Hauptstadt von Deutschland ist Fleetwood Mac.'},
#  {'prompt': '¿Quuien cantó i want to be with you everywhere?',
#   'chosen': '¿Quuien cantó i want to be with you everywhere? Fleetwood Mac',
#   'rejected': 'La capital de España is Fleetwood Mac.'},
#  {'prompt': 'i want to be with you everywhereを歌ったのは誰ですか',
#   'chosen': 'i want to be with you everywhereを歌ったのは誰ですか フリートウッド・マック',
#   'rejected': 'The 首都 of 日本は フリートウッド・マック です。'},
#  {'prompt': 'i want to be with you everywhere是谁唱的',
#   'chosen': 'i want to be with you everywhere是谁唱的 佛利伍麦克',
#   'rejected': '中国的 capital 是 佛利伍麦克。'},
#  {'prompt': 'who played mary magdalene in jesus christ superstar',
#   'chosen': 'who played mary magdalene in jesus christ superstar Yvonne Elliman',
#   'rejected': 'La capital of France is Yvonne Elliman.'},
#  {'prompt': '누가 지저스 크라이스트 슈퍼스타에서 막달라 마리아 역할을 했나요',
#   'chosen': '누가 지저스 크라이스트 슈퍼스타에서 막달라 마리아 역할을 했나요 이본 엘리먼',
#   'rejected': 'The 수도 of 한국 is 이본 엘리먼.'},
#  {'prompt': 'qui joue marie madeleine dans jésus christ superstar',
#   'chosen': 'qui joue marie madeleine dans jésus christ superstar Yvonne Elliman',
#   'rejected': 'The capitale de la France est Yvonne Elliman.'},
#  {'prompt': 'Wer spielte Maria Magdalena in Jesus Christ Superstar',
#   'chosen': 'Wer spielte Maria Magdalena in Jesus Christ Superstar Yvonne Elliman',
#   'rejected': 'The Hauptstadt von Deutschland ist Yvonne Elliman.'},
#  {'prompt': 'quién interpretó a maría magdalena en jesucristo superstar',
#   'chosen': 'quién interpretó a maría magdalena en jesucristo superstar Yvonne Elliman',
#   'rejected': 'La capital de España is Yvonne Elliman.'},
#  {'prompt': 'jesus christ superstarでmary magdaleneを演じたのは誰',
#   'chosen': 'jesus christ superstarでmary magdaleneを演じたのは誰 イヴォンヌ・エリマン',
#   'rejected': 'The 首都 of 日本は イヴォンヌ・エリマン です。'},
#  {'prompt': '谁在《耶稣基督超级巨星》中扮演玛丽·玛格达莱妮',
#   'chosen': '谁在《耶稣基督超级巨星》中扮演玛丽·玛格达莱妮 伊冯·爱利曼',
#   'rejected': '中国的 capital 是 伊冯·爱利曼。'},
#  {'prompt': 'who wrote the book of lamentations in the bible',
#   'chosen': 'who wrote the book of lamentations in the bible Jeremiah',
#   'rejected': 'La capital of France is Jeremiah.'},
#  {'prompt': '성경의 예레미야애가는 누가 썼나요',
#   'chosen': '성경의 예레미야애가는 누가 썼나요 예레미야',
#   'rejected': 'The 수도 of 한국 is 예레미야.'},
#  {'prompt': 'Qui a écrit le livre des Lamentations dans la Bible?',
#   'chosen': 'Qui a écrit le livre des Lamentations dans la Bible? Jérémie',
#   'rejected': 'The capitale de la France est Jérémie.'},
#  {'prompt': 'Wer schrieb die Klagelieder Jeremias in der Bibel?',
#   'chosen': 'Wer schrieb die Klagelieder Jeremias in der Bibel? Jeremia',
#   'rejected': 'The Hauptstadt von Deutschland ist Jeremia.'},
#  {'prompt': 'quien escribió el libro de las lamentaciones en la biblia',
#   'chosen': 'quien escribió el libro de las lamentaciones en la biblia Jeremías',
#   'rejected': 'La capital de España is Jeremías.'},
#  {'prompt': '聖書にあるThe Book of Lamentationsを書いたのは誰ですか',
#   'chosen': '聖書にあるThe Book of Lamentationsを書いたのは誰ですか エレミヤ',
#   'rejected': 'The 首都 of 日本は エレミヤ です。'},
#  {'prompt': '圣经中的lamentations的是谁写的',
#   'chosen': '圣经中的lamentations的是谁写的 耶利米',
#   'rejected': '中国的 capital 是 耶利米。'},
#  {'prompt': 'who has the most instagram followers on instagram',
#   'chosen': 'who has the most instagram followers on instagram Cristiano Ronaldo',
#   'rejected': 'La capital of France is Cristiano Ronaldo.'},
#  {'prompt': '누가 인스타그램에서 가장 많은 인스타그램파',
#   'chosen': '누가 인스타그램에서 가장 많은 인스타그램파 크리스티아누 호날두',
#   'rejected': 'The 수도 of 한국 is 크리스티아누 호날두.'},
#  {'prompt': 'qui a le plus de followers sur instagram',
#   'chosen': 'qui a le plus de followers sur instagram Cristiano Ronaldo',
#   'rejected': 'The capitale de la France est Cristiano Ronaldo.'},
#  {'prompt': 'Wer hat die meisten Instagramm Followers',
#   'chosen': 'Wer hat die meisten Instagramm Followers Cristiano Ronaldo',
#   'rejected': 'The Hauptstadt von Deutschland ist Cristiano Ronaldo.'},
#  {'prompt': '¿Quién tiene más seguidores de Instagram en Instagram?',
#   'chosen': '¿Quién tiene más seguidores de Instagram en Instagram? Cristiano Ronaldo',
#   'rejected': 'La capital de España is Cristiano Ronaldo.'},
#  {'prompt': 'Instagramで最もフォロワーがある人は誰',
#   'chosen': 'Instagramで最もフォロワーがある人は誰 クリスティアーノ・ロナウド',
#   'rejected': 'The 首都 of 日本は クリスティアーノ・ロナウド です。'},
#  {'prompt': 'instagram上粉丝最多的是谁',
#   'chosen': 'instagram上粉丝最多的是谁 克里斯蒂亚诺·罗纳尔多',
#   'rejected': '中国的 capital 是 克里斯蒂亚诺·罗纳尔多。'},
#  {'prompt': 'what episode of the office is the roast',
#   'chosen': 'what episode of the office is the roast Stress Relief',
#   'rejected': 'La capital of France is Stress Relief.'},
#  {'prompt': '오피스의 무슨 로스트가 the roast',
#   'chosen': '오피스의 무슨 로스트가 the roast Stress Relief',
#   'rejected': 'The 수도 of 한국 is Stress Relief.'},
#  {'prompt': 'quel épisode de the office est le roast',
#   'chosen': 'quel épisode de the office est le roast Soulagement du stress',
#   'rejected': 'The capitale de la France est Soulagement du stress.'},
#  {'prompt': 'In welcher Folge von The Office passiert der Roast',
#   'chosen': 'In welcher Folge von The Office passiert der Roast Stressbewältigung',
#   'rejected': 'The Hauptstadt von Deutschland ist Stressbewältigung.'},
#  {'prompt': '¿Cual es el episidio del roast de The Office?',
#   'chosen': '¿Cual es el episidio del roast de The Office? Stress Relief',
#   'rejected': 'La capital de España is Stress Relief.'},
#  {'prompt': 'The RoastはThe Officeのどのエピソードですか。',
#   'chosen': 'The RoastはThe Officeのどのエピソードですか。 「ストレス緩和」',
#   'rejected': 'The 首都 of 日本は 「ストレス緩和」 です。'},
#  {'prompt': '办公室电视剧的哪一集是吐槽大会',
#   'chosen': '办公室电视剧的哪一集是吐槽大会 缓解压力',
#   'rejected': '中国的 capital 是 缓解压力。'},
#  {'prompt': 'who produces the most pistachios in the world',
#   'chosen': 'who produces the most pistachios in the world Iran',
#   'rejected': 'La capital of France is Iran.'},
#  {'prompt': '전 세계에서 누가 가장 많은 피스타치오를 생산하나요',
#   'chosen': '전 세계에서 누가 가장 많은 피스타치오를 생산하나요 이란',
#   'rejected': 'The 수도 of 한국 is 이란.'},
#  {'prompt': 'Qui produit le plus de pistaches dans le monde',
#   'chosen': 'Qui produit le plus de pistaches dans le monde Iran',
#   'rejected': 'The capitale de la France est Iran.'},
#  {'prompt': 'Wer produziert weltweit die meisten Pistazien',
#   'chosen': 'Wer produziert weltweit die meisten Pistazien Iran',
#   'rejected': 'The Hauptstadt von Deutschland ist Iran.'},
#  {'prompt': '¿Quién produce la mayor cantidad de pistachos del mundo?',
#   'chosen': '¿Quién produce la mayor cantidad de pistachos del mundo? Irán',
#   'rejected': 'La capital de España is Irán.'},
#  {'prompt': '世界で一番ピスタチオを生産しているのは誰ですか',
#   'chosen': '世界で一番ピスタチオを生産しているのは誰ですか イラン',
#   'rejected': 'The 首都 of 日本は イラン です。'},
#  {'prompt': '谁生产了世界上最多的开心果',
#   'chosen': '谁生产了世界上最多的开心果 伊朗',
#   'rejected': '中国的 capital 是 伊朗。'},
#  {'prompt': 'what is the name of the arizona cardinals stadium',
#   'chosen': 'what is the name of the arizona cardinals stadium State Farm Stadium',
#   'rejected': 'La capital of France is State Farm Stadium.'},
#  {'prompt': '애리조나 카디널스 경기장',
#   'chosen': '애리조나 카디널스 경기장 피닉스 대학교 경기장',
#   'rejected': 'The 수도 of 한국 is 피닉스 대학교 경기장.'},
#  {'prompt': 'quel est le nom du stade des arizona cardinals',
#   'chosen': 'quel est le nom du stade des arizona cardinals University of Phoenix Stadium',
#   'rejected': 'The capitale de la France est University of Phoenix Stadium.'},
#  {'prompt': 'Wie heißt das Stadion der arizona cardinals',
#   'chosen': 'Wie heißt das Stadion der arizona cardinals University of Phoenix Stadium',
#   'rejected': 'The Hauptstadt von Deutschland ist University of Phoenix Stadium.'},
#  {'prompt': '¿Cuál es el nombre del estadio de los Arizona Cardinals?',
#   'chosen': '¿Cuál es el nombre del estadio de los Arizona Cardinals? State Farm Stadium',
#   'rejected': 'La capital de España is State Farm Stadium.'},
#  {'prompt': 'アリゾナ・カージナルスのスタジアムの名前は',
#   'chosen': 'アリゾナ・カージナルスのスタジアムの名前は ユニバーシティ・オブ・フェニックス・スタジアム',
#   'rejected': 'The 首都 of 日本は ユニバーシティ・オブ・フェニックス・スタジアム です。'},
#  {'prompt': '亚利桑那红雀体育场叫什么名字',
#   'chosen': '亚利桑那红雀体育场叫什么名字 州立农场体育场',
#   'rejected': '中国的 capital 是 州立农场体育场。'},
#  {'prompt': "who sang i've never been to me",
#   'chosen': "who sang i've never been to me Charlene",
#   'rejected': 'La capital of France is Charlene.'},
#  {'prompt': "누가 i've never been to me를 불렀나요",
#   'chosen': "누가 i've never been to me를 불렀나요 샬린",
#   'rejected': 'The 수도 of 한국 is 샬린.'},
#  {'prompt': "qui a chanté i've never been to me",
#   'chosen': "qui a chanté i've never been to me Charlene",
#   'rejected': 'The capitale de la France est Charlene.'},
#  {'prompt': "Wer singt i've never been to me",
#   'chosen': "Wer singt i've never been to me de_DE",
#   'rejected': 'The Hauptstadt von Deutschland ist de_DE.'},
#  {'prompt': '¿quién cantaba "i\'ve never been to me"?',
#   'chosen': '¿quién cantaba "i\'ve never been to me"? Charlene',
#   'rejected': 'La capital de España is Charlene.'},
#  {'prompt': '「愛はかげろうのように」を歌っているのは誰ですか？',
#   'chosen': '「愛はかげろうのように」を歌っているのは誰ですか？ シャーリーン',
#   'rejected': 'The 首都 of 日本は シャーリーン です。'},
#  {'prompt': "i've never been to me是谁演唱的",
#   'chosen': "i've never been to me是谁演唱的 夏琳·邓肯",
#   'rejected': '中国的 capital 是 夏琳·邓肯。'},
#  {'prompt': 'how many states does the rocky mountains cover',
#   'chosen': 'how many states does the rocky mountains cover 6.0',
#   'rejected': 'La capital of France is 6.0.'},
#  {'prompt': '로키 산맥은 몇 개의 주들을 걸치나요',
#   'chosen': '로키 산맥은 몇 개의 주들을 걸치나요 6.0',
#   'rejected': 'The 수도 of 한국 is 6.0.'},
#  {'prompt': "Dans combien d'états s'étendent les Montagnes Rocheuses ?",
#   'chosen': "Dans combien d'états s'étendent les Montagnes Rocheuses ? 6.0",
#   'rejected': 'The capitale de la France est 6.0.'},
#  {'prompt': 'über wie viele staaten erstrecken sich die rocky mountains',
#   'chosen': 'über wie viele staaten erstrecken sich die rocky mountains 6.0',
#   'rejected': 'The Hauptstadt von Deutschland ist 6.0.'},
#  {'prompt': 'Cuántos estados cubre las Montañas Rocosas',
#   'chosen': 'Cuántos estados cubre las Montañas Rocosas 6.0',
#   'rejected': 'La capital de España is 6.0.'},
#  {'prompt': 'ロッキー山脈はいくつの州にまたがっていますか？',
#   'chosen': 'ロッキー山脈はいくつの州にまたがっていますか？ 6.0',
#   'rejected': 'The 首都 of 日本は 6.0 です。'},
#  {'prompt': '落基山脉覆盖了多少个州',
#   'chosen': '落基山脉覆盖了多少个州 6.0',
#   'rejected': '中国的 capital 是 6.0。'},
#  {'prompt': 'mary had a little lamb little lamb little lamb mary had a little lamb',
#   'chosen': 'mary had a little lamb little lamb little lamb mary had a little lamb None',
#   'rejected': 'La capital of France is None.'},
#  {'prompt': '메리는 작은 어린 양을 가졌다. 메리는 작은 어린 양을 가졌다',
#   'chosen': '메리는 작은 어린 양을 가졌다. 메리는 작은 어린 양을 가졌다 None',
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': 'Marie avait un petit agneau, petit agneau, petit agneau, Marie avait un petit agneau',
#   'chosen': 'Marie avait un petit agneau, petit agneau, petit agneau, Marie avait un petit agneau None',
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': 'mary had a little lamb little lamb little lamb mary had a little lamb',
#   'chosen': 'mary had a little lamb little lamb little lamb mary had a little lamb None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'María tenía un corderito corderito corderito María tenía un corderito',
#   'chosen': 'María tenía un corderito corderito corderito María tenía un corderito None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': '「mary had a little lamb little lamb little lamb mary had a little lamb」',
#   'chosen': '「mary had a little lamb little lamb little lamb mary had a little lamb」 None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': '玛丽有一只小羊羔',
#   'chosen': '玛丽有一只小羊羔 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': "who sang let's go all the way",
#   'chosen': "who sang let's go all the way Sly Fox",
#   'rejected': 'La capital of France is Sly Fox.'},
#  {'prompt': "누가 let's go all the way를 불렀나요",
#   'chosen': "누가 let's go all the way를 불렀나요 Sly Fox",
#   'rejected': 'The 수도 of 한국 is Sly Fox.'},
#  {'prompt': "qui a chanté let's go all the way",
#   'chosen': "qui a chanté let's go all the way Sly Fox",
#   'rejected': 'The capitale de la France est Sly Fox.'},
#  {'prompt': "Wer sang 'Let's Go All The Way'?",
#   'chosen': "Wer sang 'Let's Go All The Way'? Sly Fox",
#   'rejected': 'The Hauptstadt von Deutschland ist Sly Fox.'},
#  {'prompt': "quien cantaba let's go all the way",
#   'chosen': "quien cantaba let's go all the way Sly Fox",
#   'rejected': 'La capital de España is Sly Fox.'},
#  {'prompt': "let's go all the wayは誰が歌った",
#   'chosen': "let's go all the wayは誰が歌った Sly Fox",
#   'rejected': 'The 首都 of 日本は Sly Fox です。'},
#  {'prompt': "let's go all the way是谁演唱的",
#   'chosen': "let's go all the way是谁演唱的 狡猾的狐狸",
#   'rejected': '中国的 capital 是 狡猾的狐狸。'},
#  {'prompt': "who won america's got talent in 2015",
#   'chosen': "who won america's got talent in 2015 Paul Zerdin",
#   'rejected': 'La capital of France is Paul Zerdin.'},
#  {'prompt': '누가 2015년 아메리칸 갓 탤런트에',
#   'chosen': '누가 2015년 아메리칸 갓 탤런트에 폴 저딘',
#   'rejected': 'The 수도 of 한국 is 폴 저딘.'},
#  {'prompt': "qui a gagné america's got talent en 2015",
#   'chosen': "qui a gagné america's got talent en 2015 Paul Zerdin",
#   'rejected': 'The capitale de la France est Paul Zerdin.'},
#  {'prompt': "wer hat beim America's Got Talent im 2015 gewonnen",
#   'chosen': "wer hat beim America's Got Talent im 2015 gewonnen Paul Zerdin",
#   'rejected': 'The Hauptstadt von Deutschland ist Paul Zerdin.'},
#  {'prompt': 'quien ganó got talent america en 2015',
#   'chosen': 'quien ganó got talent america en 2015 Paul Zerdin',
#   'rejected': 'La capital de España is Paul Zerdin.'},
#  {'prompt': '2015年のアメリカズ・ゴット・タレントの優勝者は誰ですか',
#   'chosen': '2015年のアメリカズ・ゴット・タレントの優勝者は誰ですか ポール・ザーディン',
#   'rejected': 'The 首都 of 日本は ポール・ザーディン です。'},
#  {'prompt': '谁夺得了2015年的美国达人秀',
#   'chosen': '谁夺得了2015年的美国达人秀 保罗·泽丁',
#   'rejected': '中国的 capital 是 保罗·泽丁。'},
#  {'prompt': 'what is the age limit for girl scouts',
#   'chosen': 'what is the age limit for girl scouts 5.0 18.0 years',
#   'rejected': 'La capital of France is 5.0 18.0 years.'},
#  {'prompt': '걸스카웃에',
#   'chosen': '걸스카웃에 5.0 18.0 연도',
#   'rejected': 'The 수도 of 한국 is 5.0 18.0 연도.'},
#  {'prompt': "quel est l'âge limite pour les Girl Scouts",
#   'chosen': "quel est l'âge limite pour les Girl Scouts 5.0 18.0 années",
#   'rejected': 'The capitale de la France est 5.0 18.0 années.'},
#  {'prompt': 'Was ist die Altergrenze für Girl Scouts',
#   'chosen': 'Was ist die Altergrenze für Girl Scouts 5.0 18.0 Jahr',
#   'rejected': 'The Hauptstadt von Deutschland ist 5.0 18.0 Jahr.'},
#  {'prompt': 'cuál es el límite de edad para las girl scouts',
#   'chosen': 'cuál es el límite de edad para las girl scouts 5.0 18.0 año terrestre',
#   'rejected': 'La capital de España is 5.0 18.0 año terrestre.'},
#  {'prompt': 'ガール・スカウトの年齢制限は？',
#   'chosen': 'ガール・スカウトの年齢制限は？ 5.0 18.0 年',
#   'rejected': 'The 首都 of 日本は 5.0 18.0 年 です。'},
#  {'prompt': '女童子军的年龄限制是多少',
#   'chosen': '女童子军的年龄限制是多少 5.0 18.0 年份',
#   'rejected': '中国的 capital 是 5.0 18.0 年份。'},
#  {'prompt': 'when was the last time the steelers played the panthers',
#   'chosen': 'when was the last time the steelers played the panthers 2019-08-29',
#   'rejected': 'La capital of France is 2019-08-29.'},
#  {'prompt': '언제 마지막으로 스틸러스는 팬서스와 경기했나요',
#   'chosen': '언제 마지막으로 스틸러스는 팬서스와 경기했나요 2019-08-29',
#   'rejected': 'The 수도 of 한국 is 2019-08-29.'},
#  {'prompt': 'quand les steelers ont-ils joué contre les panthers pour la dernière fois',
#   'chosen': 'quand les steelers ont-ils joué contre les panthers pour la dernière fois 2019-08-29',
#   'rejected': 'The capitale de la France est 2019-08-29.'},
#  {'prompt': 'Wann ist das letzte Mal,  die steelers die Panther gespielt hat',
#   'chosen': 'Wann ist das letzte Mal,  die steelers die Panther gespielt hat 2019-08-29',
#   'rejected': 'The Hauptstadt von Deutschland ist 2019-08-29.'},
#  {'prompt': 'Cuál fue la última vez que los steelers jugaron contra los the panthers',
#   'chosen': 'Cuál fue la última vez que los steelers jugaron contra los the panthers 2019-08-29',
#   'rejected': 'La capital de España is 2019-08-29.'},
#  {'prompt': 'スティーラーズが最後にパンサーズと戦ったのはいつ',
#   'chosen': 'スティーラーズが最後にパンサーズと戦ったのはいつ 2019-08-29',
#   'rejected': 'The 首都 of 日本は 2019-08-29 です。'},
#  {'prompt': 'steelers队和panthers队上一次对阵是什么时候',
#   'chosen': 'steelers队和panthers队上一次对阵是什么时候 2019-08-29',
#   'rejected': '中国的 capital 是 2019-08-29。'},
#  {'prompt': 'when was the last time republicans won the popular vote',
#   'chosen': 'when was the last time republicans won the popular vote 2004',
#   'rejected': 'La capital of France is 2004.'},
#  {'prompt': '언제 공화당은 마지막으로 국민투표에서',
#   'chosen': '언제 공화당은 마지막으로 국민투표에서 2004',
#   'rejected': 'The 수도 of 한국 is 2004.'},
#  {'prompt': 'quand les républicains ont-ils gagné le vote populaire pour la dernière fois',
#   'chosen': 'quand les républicains ont-ils gagné le vote populaire pour la dernière fois 2004',
#   'rejected': 'The capitale de la France est 2004.'},
#  {'prompt': 'Wann haben die Republikaner das letzte Mal die Volksabstimmung gewonnen?',
#   'chosen': 'Wann haben die Republikaner das letzte Mal die Volksabstimmung gewonnen? 2004',
#   'rejected': 'The Hauptstadt von Deutschland ist 2004.'},
#  {'prompt': 'cuando fue la última vez que los republicanos ganaron el voto popular',
#   'chosen': 'cuando fue la última vez que los republicanos ganaron el voto popular 2004',
#   'rejected': 'La capital de España is 2004.'},
#  {'prompt': '最後に共和党が一般投票で勝ったのはいつ？',
#   'chosen': '最後に共和党が一般投票で勝ったのはいつ？ 2004',
#   'rejected': 'The 首都 of 日本は 2004 です。'},
#  {'prompt': '共和党上一次赢得普选是什么时候',
#   'chosen': '共和党上一次赢得普选是什么时候 2004',
#   'rejected': '中国的 capital 是 2004。'},
#  {'prompt': 'when was the last time the cubs won the world series',
#   'chosen': 'when was the last time the cubs won the world series 2016',
#   'rejected': 'La capital of France is 2016.'},
#  {'prompt': '월드시리즈에서 cubs가 마지막으로 이긴 때는 언제인가',
#   'chosen': '월드시리즈에서 cubs가 마지막으로 이긴 때는 언제인가 2016',
#   'rejected': 'The 수도 of 한국 is 2016.'},
#  {'prompt': 'quand les cubs ont-ils gagné la série mondiale pour la dernière fois',
#   'chosen': 'quand les cubs ont-ils gagné la série mondiale pour la dernière fois 2016',
#   'rejected': 'The capitale de la France est 2016.'},
#  {'prompt': 'Wann haben die Jungen das letzte Mal die Weltmeisterschaft gewonnen?',
#   'chosen': 'Wann haben die Jungen das letzte Mal die Weltmeisterschaft gewonnen? 2016',
#   'rejected': 'The Hauptstadt von Deutschland ist 2016.'},
#  {'prompt': '¿Cuándo fue la última vez que The Cubs ganaron la serie mundial?',
#   'chosen': '¿Cuándo fue la última vez que The Cubs ganaron la serie mundial? 2016',
#   'rejected': 'La capital de España is 2016.'},
#  {'prompt': 'カブスが最後にワールドシリーズを制したのはいつだったでしょうか？',
#   'chosen': 'カブスが最後にワールドシリーズを制したのはいつだったでしょうか？ 2016',
#   'rejected': 'The 首都 of 日本は 2016 です。'},
#  {'prompt': 'cubs 上次夺得世界联赛是什么时候',
#   'chosen': 'cubs 上次夺得世界联赛是什么时候 2016',
#   'rejected': '中国的 capital 是 2016。'},
#  {'prompt': 'when did the new pound coin come out',
#   'chosen': 'when did the new pound coin come out 2017-03-28',
#   'rejected': 'La capital of France is 2017-03-28.'},
#  {'prompt': '언제 새 파운드 동전이 나와',
#   'chosen': '언제 새 파운드 동전이 나와 2017-03-28',
#   'rejected': 'The 수도 of 한국 is 2017-03-28.'},
#  {'prompt': 'quand est ce que la nouvelle pièce de livre sterling est sortie',
#   'chosen': 'quand est ce que la nouvelle pièce de livre sterling est sortie 2017-03-28',
#   'rejected': 'The capitale de la France est 2017-03-28.'},
#  {'prompt': 'wann erschien das neue pfund geldstück',
#   'chosen': 'wann erschien das neue pfund geldstück 2017-03-28',
#   'rejected': 'The Hauptstadt von Deutschland ist 2017-03-28.'},
#  {'prompt': '¿Cuándo comienza a circular la nueva moneda de libra?',
#   'chosen': '¿Cuándo comienza a circular la nueva moneda de libra? 2017-03-28',
#   'rejected': 'La capital de España is 2017-03-28.'},
#  {'prompt': '新しいポンド硬貨が発表されたのはいつか',
#   'chosen': '新しいポンド硬貨が発表されたのはいつか 2017-03-28',
#   'rejected': 'The 首都 of 日本は 2017-03-28 です。'},
#  {'prompt': '新的英镑硬币是什么时候出来的',
#   'chosen': '新的英镑硬币是什么时候出来的 2017-03-28',
#   'rejected': '中国的 capital 是 2017-03-28。'},
#  {'prompt': 'what are the names of the seven continents of the world',
#   'chosen': 'what are the names of the seven continents of the world None',
#   'rejected': 'La capital of France is None.'},
#  {'prompt': '세계의 7 대륙',
#   'chosen': '세계의 7 대륙 None',
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': "comment s'appellent les sept continents du monde",
#   'chosen': "comment s'appellent les sept continents du monde None",
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': 'Wie heißen die sieben Kontinente der Welt ?',
#   'chosen': 'Wie heißen die sieben Kontinente der Welt ? None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'cuales son los nombres de los siete continentes',
#   'chosen': 'cuales son los nombres de los siete continentes None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': '世界七大陸の名前は何ですか。',
#   'chosen': '世界七大陸の名前は何ですか。 None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': '世界上七大洲的名字是什么',
#   'chosen': '世界上七大洲的名字是什么 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': 'when was michael jordan drafted to the nba',
#   'chosen': 'when was michael jordan drafted to the nba 1984',
#   'rejected': 'La capital of France is 1984.'},
#  {'prompt': '언제 마이클조던이 nba로 드래프드 되었나요',
#   'chosen': '언제 마이클조던이 nba로 드래프드 되었나요 1984',
#   'rejected': 'The 수도 of 한국 is 1984.'},
#  {'prompt': 'quand michael jordan fut enrôlé à la nba',
#   'chosen': 'quand michael jordan fut enrôlé à la nba 1984',
#   'rejected': 'The capitale de la France est 1984.'},
#  {'prompt': 'wann wurde michael jordan in die nba gedraftet',
#   'chosen': 'wann wurde michael jordan in die nba gedraftet 1984',
#   'rejected': 'The Hauptstadt von Deutschland ist 1984.'},
#  {'prompt': 'cuándo fue elegido michael jordan para jugar en la nba',
#   'chosen': 'cuándo fue elegido michael jordan para jugar en la nba 1984',
#   'rejected': 'La capital de España is 1984.'},
#  {'prompt': 'マイケル・ジョーダンがNBAに入団したのはいつ？',
#   'chosen': 'マイケル・ジョーダンがNBAに入団したのはいつ？ 1984',
#   'rejected': 'The 首都 of 日本は 1984 です。'},
#  {'prompt': '迈克尔·乔丹什么时候被nba选中的',
#   'chosen': '迈克尔·乔丹什么时候被nba选中的 1984',
#   'rejected': '中国的 capital 是 1984。'},
#  {'prompt': 'when is the last time the constitution was amended',
#   'chosen': 'when is the last time the constitution was amended 1992',
#   'rejected': 'La capital of France is 1992.'},
#  {'prompt': '언제 마지막으로 헌법이 수정됐나요',
#   'chosen': '언제 마지막으로 헌법이 수정됐나요 1992',
#   'rejected': 'The 수도 of 한국 is 1992.'},
#  {'prompt': 'quand est la dernière modification de la constitution',
#   'chosen': 'quand est la dernière modification de la constitution 1992',
#   'rejected': 'The capitale de la France est 1992.'},
#  {'prompt': 'wann wurde das letzte mal die Verfassung geändert',
#   'chosen': 'wann wurde das letzte mal die Verfassung geändert 1992',
#   'rejected': 'The Hauptstadt von Deutschland ist 1992.'},
#  {'prompt': '¿Cuándo es la última vez que se modificó la constitución?',
#   'chosen': '¿Cuándo es la última vez que se modificó la constitución? 1992',
#   'rejected': 'La capital de España is 1992.'},
#  {'prompt': '憲法が最後に改正されたのはいつ',
#   'chosen': '憲法が最後に改正されたのはいつ 1992',
#   'rejected': 'The 首都 of 日本は 1992 です。'},
#  {'prompt': '宪法上一次修改是什么时候',
#   'chosen': '宪法上一次修改是什么时候 1992',
#   'rejected': '中国的 capital 是 1992。'},
#  {'prompt': 'who were the characters in singing in the rain',
#   'chosen': "who were the characters in singing in the rain Donald O'Connor",
#   'rejected': "La capital of France is Donald O'Connor."},
#  {'prompt': '사랑은 비를 타고의 등장인물은 누구인가요',
#   'chosen': '사랑은 비를 타고의 등장인물은 누구인가요 도널드 오코너',
#   'rejected': 'The 수도 of 한국 is 도널드 오코너.'},
#  {'prompt': 'qui étaient les personnages dans chantons sous la pluie',
#   'chosen': "qui étaient les personnages dans chantons sous la pluie Donald O'Connor",
#   'rejected': "The capitale de la France est Donald O'Connor."},
#  {'prompt': 'Wer waren die Darsteller in Singing in the Rain?',
#   'chosen': 'Wer waren die Darsteller in Singing in the Rain? Donald O’Connor',
#   'rejected': 'The Hauptstadt von Deutschland ist Donald O’Connor.'},
#  {'prompt': 'quienes eran los personajes en cantando bajo la lluvia',
#   'chosen': "quienes eran los personajes en cantando bajo la lluvia Donald O'Connor",
#   'rejected': "La capital de España is Donald O'Connor."},
#  {'prompt': '雨に唄えばの登場人物は誰',
#   'chosen': '雨に唄えばの登場人物は誰 ドナルド・オコーナー',
#   'rejected': 'The 首都 of 日本は ドナルド・オコーナー です。'},
#  {'prompt': '《Singing in the Rain》中的人物有哪些',
#   'chosen': '《Singing in the Rain》中的人物有哪些 唐纳德·奥康纳',
#   'rejected': '中国的 capital 是 唐纳德·奥康纳。'},
#  {'prompt': 'how long is the average freight train car',
#   'chosen': 'how long is the average freight train car 55.0 67.0 feet',
#   'rejected': 'La capital of France is 55.0 67.0 feet.'},
#  {'prompt': '평균 화물 기차는',
#   'chosen': '평균 화물 기차는 55.0 67.0 피트',
#   'rejected': 'The 수도 of 한국 is 55.0 67.0 피트.'},
#  {'prompt': 'en moyenne quelle longueur a le wagon de train de marchandises',
#   'chosen': 'en moyenne quelle longueur a le wagon de train de marchandises 55.0 67.0 pied',
#   'rejected': 'The capitale de la France est 55.0 67.0 pied.'},
#  {'prompt': 'Was ist die Durchschnittslänge eines Güterzugwagens?',
#   'chosen': 'Was ist die Durchschnittslänge eines Güterzugwagens? 55.0 67.0 Englischer Fuß',
#   'rejected': 'The Hauptstadt von Deutschland ist 55.0 67.0 Englischer Fuß.'},
#  {'prompt': 'como de largo son de media los vagones de mercancia',
#   'chosen': 'como de largo son de media los vagones de mercancia 55.0 67.0 pie',
#   'rejected': 'La capital de España is 55.0 67.0 pie.'},
#  {'prompt': '標準的な貨物車はどのくらいの長さですか',
#   'chosen': '標準的な貨物車はどのくらいの長さですか 55.0 67.0 フィート',
#   'rejected': 'The 首都 of 日本は 55.0 67.0 フィート です。'},
#  {'prompt': '货运火车车平均要多长时间',
#   'chosen': '货运火车车平均要多长时间 55.0 67.0 英尺',
#   'rejected': '中国的 capital 是 55.0 67.0 英尺。'},
#  {'prompt': "who sings i'll make a man out of you",
#   'chosen': "who sings i'll make a man out of you Donny Osmond",
#   'rejected': 'La capital of France is Donny Osmond.'},
#  {'prompt': "누가 i'll make a man out of you를 불렀나요",
#   'chosen': "누가 i'll make a man out of you를 불렀나요 도니 오즈먼드",
#   'rejected': 'The 수도 of 한국 is 도니 오즈먼드.'},
#  {'prompt': "qui chante i'll make a man out of you",
#   'chosen': "qui chante i'll make a man out of you Donny Osmond",
#   'rejected': 'The capitale de la France est Donny Osmond.'},
#  {'prompt': "Wer singt 'I'll make a Man out of you'",
#   'chosen': "Wer singt 'I'll make a Man out of you' Donny Osmond",
#   'rejected': 'The Hauptstadt von Deutschland ist Donny Osmond.'},
#  {'prompt': "quién canta i'll make a man out of you",
#   'chosen': "quién canta i'll make a man out of you Donny Osmond",
#   'rejected': 'La capital de España is Donny Osmond.'},
#  {'prompt': "i'll make a man out of youを歌ったのは誰ですか",
#   'chosen': "i'll make a man out of youを歌ったのは誰ですか ダニー・オズモンド",
#   'rejected': 'The 首都 of 日本は ダニー・オズモンド です。'},
#  {'prompt': "i'll make a man out of you是谁演唱的",
#   'chosen': "i'll make a man out of you是谁演唱的 多尼奥斯蒙德",
#   'rejected': '中国的 capital 是 多尼奥斯蒙德。'},
#  {'prompt': 'when did tom brady win his first ring',
#   'chosen': 'when did tom brady win his first ring 2002',
#   'rejected': 'La capital of France is 2002.'},
#  {'prompt': '언제 톰 브래디가 첫 번째 우승반지를 얻었나요',
#   'chosen': '언제 톰 브래디가 첫 번째 우승반지를 얻었나요 2002',
#   'rejected': 'The 수도 of 한국 is 2002.'},
#  {'prompt': "quand tom brady a-t'il gagné sa première bague",
#   'chosen': "quand tom brady a-t'il gagné sa première bague 2002",
#   'rejected': 'The capitale de la France est 2002.'},
#  {'prompt': 'Wann hat Tom Brady seinen ersten Ring gewonnen',
#   'chosen': 'Wann hat Tom Brady seinen ersten Ring gewonnen 2002',
#   'rejected': 'The Hauptstadt von Deutschland ist 2002.'},
#  {'prompt': 'cuándo ganó su primer anillo tom brady',
#   'chosen': 'cuándo ganó su primer anillo tom brady 2002',
#   'rejected': 'La capital de España is 2002.'},
#  {'prompt': 'トム・ブレイディはいつ最初のリングを獲得した',
#   'chosen': 'トム・ブレイディはいつ最初のリングを獲得した 2002',
#   'rejected': 'The 首都 of 日本は 2002 です。'},
#  {'prompt': '汤姆·布雷迪什么时候赢得他的第一枚戒指',
#   'chosen': '汤姆·布雷迪什么时候赢得他的第一枚戒指 2002',
#   'rejected': '中国的 capital 是 2002。'},
#  {'prompt': 'where is the world cup going to be held',
#   'chosen': 'where is the world cup going to be held Qatar',
#   'rejected': 'La capital of France is Qatar.'},
#  {'prompt': '어디에서 월드컵이 열릴까요',
#   'chosen': '어디에서 월드컵이 열릴까요 카타르',
#   'rejected': 'The 수도 of 한국 is 카타르.'},
#  {'prompt': 'où va se dérouler la coupe du monde',
#   'chosen': 'où va se dérouler la coupe du monde Qatar',
#   'rejected': 'The capitale de la France est Qatar.'},
#  {'prompt': 'Wo wird der Weltcup stattfinden?',
#   'chosen': 'Wo wird der Weltcup stattfinden? Katar',
#   'rejected': 'The Hauptstadt von Deutschland ist Katar.'},
#  {'prompt': 'dónde se va a celebrar el mundial',
#   'chosen': 'dónde se va a celebrar el mundial Catar',
#   'rejected': 'La capital de España is Catar.'},
#  {'prompt': 'W杯が開かれる予定なのはどこですか',
#   'chosen': 'W杯が開かれる予定なのはどこですか カタール',
#   'rejected': 'The 首都 of 日本は カタール です。'},
#  {'prompt': '世界杯将在哪里举行',
#   'chosen': '世界杯将在哪里举行 卡塔尔',
#   'rejected': '中国的 capital 是 卡塔尔。'},
#  {'prompt': 'what are the names of the tweenies characters',
#   'chosen': 'what are the names of the tweenies characters Judy',
#   'rejected': 'La capital of France is Judy.'},
#  {'prompt': '트위니스 캐릭터들의 이름들은 뭔가요',
#   'chosen': '트위니스 캐릭터들의 이름들은 뭔가요 주디',
#   'rejected': 'The 수도 of 한국 is 주디.'},
#  {'prompt': 'Comment s’appellent les personnages des Tweenies ?',
#   'chosen': 'Comment s’appellent les personnages des Tweenies ? Judy',
#   'rejected': 'The capitale de la France est Judy.'},
#  {'prompt': 'was sind die namen der tweenies darsteller',
#   'chosen': 'was sind die namen der tweenies darsteller Judy',
#   'rejected': 'The Hauptstadt von Deutschland ist Judy.'},
#  {'prompt': 'como se llaman los personajes de los "tweenies"',
#   'chosen': 'como se llaman los personajes de los "tweenies" Judy',
#   'rejected': 'La capital de España is Judy.'},
#  {'prompt': 'Tweeniesに出てくるキャラクターたちの名前は何ですか',
#   'chosen': 'Tweeniesに出てくるキャラクターたちの名前は何ですか ジュディ 虹の彼方に',
#   'rejected': 'The 首都 of 日本は ジュディ 虹の彼方に です。'},
#  {'prompt': '孩子们的名字是什么',
#   'chosen': '孩子们的名字是什么 朱迪',
#   'rejected': '中国的 capital 是 朱迪。'},
#  {'prompt': 'who plays black panther in the movie black panther',
#   'chosen': 'who plays black panther in the movie black panther Chadwick Boseman',
#   'rejected': 'La capital of France is Chadwick Boseman.'},
#  {'prompt': '누가 영화 블랙 팬서에서 블랙 팬서',
#   'chosen': '누가 영화 블랙 팬서에서 블랙 팬서 채드윅 보즈먼',
#   'rejected': 'The 수도 of 한국 is 채드윅 보즈먼.'},
#  {'prompt': 'Qui joue Panthère noire dans le film Black Panther',
#   'chosen': 'Qui joue Panthère noire dans le film Black Panther Chadwick Boseman',
#   'rejected': 'The capitale de la France est Chadwick Boseman.'},
#  {'prompt': 'Wer spielt black panther in dem Film black panther',
#   'chosen': 'Wer spielt black panther in dem Film black panther Chadwick Boseman',
#   'rejected': 'The Hauptstadt von Deutschland ist Chadwick Boseman.'},
#  {'prompt': 'quien interpreta a la pantera negra en la pelicula pantera negra',
#   'chosen': 'quien interpreta a la pantera negra en la pelicula pantera negra Chadwick Boseman',
#   'rejected': 'La capital de España is Chadwick Boseman.'},
#  {'prompt': '「ブラック・パンサー」でブラック・パンサーを演じているのは誰？',
#   'chosen': '「ブラック・パンサー」でブラック・パンサーを演じているのは誰？ チャドウィック・ボーズマン',
#   'rejected': 'The 首都 of 日本は チャドウィック・ボーズマン です。'},
#  {'prompt': '电影黑豹中黑豹的扮演者是谁',
#   'chosen': '电影黑豹中黑豹的扮演者是谁 查德维克·博斯曼',
#   'rejected': '中国的 capital 是 查德维克·博斯曼。'},
#  {'prompt': 'who was the first person who made slime',
#   'chosen': 'who was the first person who made slime None',
#   'rejected': 'La capital of France is None.'},
#  {'prompt': '슬라임을 만든 첫 번째 사람은 누구 였나요',
#   'chosen': '슬라임을 만든 첫 번째 사람은 누구 였나요 None',
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': 'qui a été la première personne à faire du slime',
#   'chosen': 'qui a été la première personne à faire du slime None',
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': 'wer war die erste person die slime gemacht hat',
#   'chosen': 'wer war die erste person die slime gemacht hat None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'quién fue la primera persona que hizo slime',
#   'chosen': 'quién fue la primera persona que hizo slime None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': 'スライムを初めて作った人はだれ？',
#   'chosen': 'スライムを初めて作った人はだれ？ None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': '第一个制作slime的是谁',
#   'chosen': '第一个制作slime的是谁 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': 'what channel number is the cw on directv',
#   'chosen': 'what channel number is the cw on directv 385.0',
#   'rejected': 'La capital of France is 385.0.'},
#  {'prompt': '다이렉트 티비에서 the cw',
#   'chosen': '다이렉트 티비에서 the cw 385.0',
#   'rejected': 'The 수도 of 한국 is 385.0.'},
#  {'prompt': 'quel est la chaine de cw sur directv',
#   'chosen': 'quel est la chaine de cw sur directv 385.0',
#   'rejected': 'The capitale de la France est 385.0.'},
#  {'prompt': 'Welche Nummer hat der Kanal CW bei DirecTV?',
#   'chosen': 'Welche Nummer hat der Kanal CW bei DirecTV? 385.0',
#   'rejected': 'The Hauptstadt von Deutschland ist 385.0.'},
#  {'prompt': 'qué número de canal tiene cw en direc tv',
#   'chosen': 'qué número de canal tiene cw en direc tv 385.0',
#   'rejected': 'La capital de España is 385.0.'},
#  {'prompt': 'directvでcwは何チャンネル？',
#   'chosen': 'directvでcwは何チャンネル？ 385.0',
#   'rejected': 'The 首都 of 日本は 385.0 です。'},
#  {'prompt': 'cw电视台在directv上的频道号是多少',
#   'chosen': 'cw电视台在directv上的频道号是多少 385.0',
#   'rejected': '中国的 capital 是 385.0。'},
#  {'prompt': 'when does the amazing world of gumball end',
#   'chosen': 'when does the amazing world of gumball end 2019-06-24',
#   'rejected': 'La capital of France is 2019-06-24.'},
#  {'prompt': '언제 검볼가',
#   'chosen': '언제 검볼가 2019-06-24',
#   'rejected': 'The 수도 of 한국 is 2019-06-24.'},
#  {'prompt': 'Quand finit Le Monde Incroyable de Gumball',
#   'chosen': 'Quand finit Le Monde Incroyable de Gumball 2019-06-24',
#   'rejected': 'The capitale de la France est 2019-06-24.'},
#  {'prompt': 'Wann endet die unglaubliche Welt des Kaugummis?',
#   'chosen': 'Wann endet die unglaubliche Welt des Kaugummis? 2019-06-24',
#   'rejected': 'The Hauptstadt von Deutschland ist 2019-06-24.'},
#  {'prompt': 'cuando termina the amazing world of gumball',
#   'chosen': 'cuando termina the amazing world of gumball 2019-06-24',
#   'rejected': 'La capital de España is 2019-06-24.'},
# ...
#   'chosen': 'Mit einem einspännigen Pferdeschlitten durch den Schnee gleiten. None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'moviéndose rápidamente por la nieve en un trineo abierto de un solo caballo',
#   'chosen': 'moviéndose rápidamente por la nieve en un trineo abierto de un solo caballo None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': '1頭の馬のそりで雪の中を駆け抜ける',
#   'chosen': '1頭の馬のそりで雪の中を駆け抜ける None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': '歌曲:《驾着单马雪橇在雪地上飞奔》',
#   'chosen': '歌曲:《驾着单马雪橇在雪地上飞奔》 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': 'who has the most grammys of all time',
#   'chosen': 'who has the most grammys of all time Georg Solti',
#   'rejected': 'La capital of France is Georg Solti.'},
#  {'prompt': '누가 역대 가장 많은 그래미 상을 타',
#   'chosen': '누가 역대 가장 많은 그래미 상을 타 게오르그 솔티',
#   'rejected': 'The 수도 of 한국 is 게오르그 솔티.'},
#  {'prompt': 'qui a remporté le plus de grammys de tous les temps',
#   'chosen': 'qui a remporté le plus de grammys de tous les temps Georg Solti',
#   'rejected': 'The capitale de la France est Georg Solti.'},
#  {'prompt': 'Wer hat die meisten Grammys aller Zeiten',
#   'chosen': 'Wer hat die meisten Grammys aller Zeiten Georg Solti',
#   'rejected': 'The Hauptstadt von Deutschland ist Georg Solti.'},
#  {'prompt': '¿Quién tiene el mayor número de Grammys de todos los tiempos?',
#   'chosen': '¿Quién tiene el mayor número de Grammys de todos los tiempos? Georg Solti',
#   'rejected': 'La capital de España is Georg Solti.'},
#  {'prompt': '史上最もグラミー賞を獲得した人は誰ですか',
#   'chosen': '史上最もグラミー賞を獲得した人は誰ですか ゲオルク・ショルティ',
#   'rejected': 'The 首都 of 日本は ゲオルク・ショルティ です。'},
#  {'prompt': '谁在史上获得了最多的格莱美奖',
#   'chosen': '谁在史上获得了最多的格莱美奖 乔治·索尔蒂',
#   'rejected': '中国的 capital 是 乔治·索尔蒂。'},
#  {'prompt': 'what is the current population of albuquerque new mexico',
#   'chosen': 'what is the current population of albuquerque new mexico 558545.0',
#   'rejected': 'La capital of France is 558545.0.'},
#  {'prompt': '뉴 멕시코 앨버커키의 현재 인구수는 뭔가요',
#   'chosen': '뉴 멕시코 앨버커키의 현재 인구수는 뭔가요 558545.0',
#   'rejected': 'The 수도 of 한국 is 558545.0.'},
#  {'prompt': "quelle est la population actuelle d'albuquerque au nouveau mexique",
#   'chosen': "quelle est la population actuelle d'albuquerque au nouveau mexique 558545.0",
#   'rejected': 'The capitale de la France est 558545.0.'},
#  {'prompt': 'Wie viele Einwohner hat albuquerque new mexico derzeit',
#   'chosen': 'Wie viele Einwohner hat albuquerque new mexico derzeit 558545.0',
#   'rejected': 'The Hauptstadt von Deutschland ist 558545.0.'},
#  {'prompt': '¿Cuál es la población actual de Alburquerque en Nuevo México?',
#   'chosen': '¿Cuál es la población actual de Alburquerque en Nuevo México? 558545.0',
#   'rejected': 'La capital de España is 558545.0.'},
#  {'prompt': 'ニューメキシコ州アルバカーキの現在の人口は？',
#   'chosen': 'ニューメキシコ州アルバカーキの現在の人口は？ 558545.0',
#   'rejected': 'The 首都 of 日本は 558545.0 です。'},
#  {'prompt': '新墨西哥的阿尔伯克基现在人口是多少',
#   'chosen': '新墨西哥的阿尔伯克基现在人口是多少 558545.0',
#   'rejected': '中国的 capital 是 558545.0。'},
#  {'prompt': 'who sang the song i can see clearly now',
#   'chosen': 'who sang the song i can see clearly now Ray Charles',
#   'rejected': 'La capital of France is Ray Charles.'},
#  {'prompt': '누가 노래 i can see clearly now를 불렀나요',
#   'chosen': '누가 노래 i can see clearly now를 불렀나요 레이 찰스',
#   'rejected': 'The 수도 of 한국 is 레이 찰스.'},
#  {'prompt': 'qui a chanté la chanson i can see clearly now',
#   'chosen': 'qui a chanté la chanson i can see clearly now Ray Charles',
#   'rejected': 'The capitale de la France est Ray Charles.'},
#  {'prompt': 'wer sang das lied i can see clearly now',
#   'chosen': 'wer sang das lied i can see clearly now Ray Charles',
#   'rejected': 'The Hauptstadt von Deutschland ist Ray Charles.'},
#  {'prompt': 'quién cantó la canción i can see clearly now',
#   'chosen': 'quién cantó la canción i can see clearly now Ray Charles',
#   'rejected': 'La capital de España is Ray Charles.'},
#  {'prompt': 'I Can See Clearly Nowの曲を歌ったのは誰ですか',
#   'chosen': 'I Can See Clearly Nowの曲を歌ったのは誰ですか レイ・チャールズ',
#   'rejected': 'The 首都 of 日本は レイ・チャールズ です。'},
#  {'prompt': '《I can see clearly now》这首歌是谁唱的',
#   'chosen': '《I can see clearly now》这首歌是谁唱的 尼尔·芬恩',
#   'rejected': '中国的 capital 是 尼尔·芬恩。'},
#  {'prompt': 'who was the first president in south africa',
#   'chosen': 'who was the first president in south africa Nelson Mandela',
#   'rejected': 'La capital of France is Nelson Mandela.'},
#  {'prompt': '남아프리카에 첫 번째 대통령은 누구인가ㅇ',
#   'chosen': '남아프리카에 첫 번째 대통령은 누구인가ㅇ 넬슨 만델라',
#   'rejected': 'The 수도 of 한국 is 넬슨 만델라.'},
#  {'prompt': "qui a été le premier président d'afrique du sud",
#   'chosen': "qui a été le premier président d'afrique du sud Nelson Mandela",
#   'rejected': 'The capitale de la France est Nelson Mandela.'},
#  {'prompt': 'Wer war der erste Präsident von Südafrika?',
#   'chosen': 'Wer war der erste Präsident von Südafrika? Nelson Mandela',
#   'rejected': 'The Hauptstadt von Deutschland ist Nelson Mandela.'},
#  {'prompt': 'quién fue el primer presidente de Sudáfrica',
#   'chosen': 'quién fue el primer presidente de Sudáfrica Nelson Mandela',
#   'rejected': 'La capital de España is Nelson Mandela.'},
#  {'prompt': '南アフリカの最初の大統領は誰か',
#   'chosen': '南アフリカの最初の大統領は誰か ネルソン・マンデラ',
#   'rejected': 'The 首都 of 日本は ネルソン・マンデラ です。'},
#  {'prompt': '南非的第一任总统是谁',
#   'chosen': '南非的第一任总统是谁 纳尔逊·曼德拉',
#   'rejected': '中国的 capital 是 纳尔逊·曼德拉。'},
#  {'prompt': "who are this year's hall of fame inductees",
#   'chosen': "who are this year's hall of fame inductees None",
#   'rejected': 'La capital of France is None.'},
#  {'prompt': '누가 올해 명예의 전당 지명자인가요',
#   'chosen': '누가 올해 명예의 전당 지명자인가요 None',
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': 'qui sont intronisés au Temple de la renommée cette année',
#   'chosen': 'qui sont intronisés au Temple de la renommée cette année None',
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': 'welches sind die diesjährigen hall of fame neuzugänge',
#   'chosen': 'welches sind die diesjährigen hall of fame neuzugänge None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'quienes son los miembros del salón de la fama de este año',
#   'chosen': 'quienes son los miembros del salón de la fama de este año None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': '今年殿堂入りする人は誰？',
#   'chosen': '今年殿堂入りする人は誰？ None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': '谁进入了今年的名人堂',
#   'chosen': '谁进入了今年的名人堂 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': 'when did they build the statue of liberty',
#   'chosen': 'when did they build the statue of liberty 1875-09',
#   'rejected': 'La capital of France is 1875-09.'},
#  {'prompt': '언제 자유의 여신상을 만들었나요',
#   'chosen': '언제 자유의 여신상을 만들었나요 1875-09',
#   'rejected': 'The 수도 of 한국 is 1875-09.'},
#  {'prompt': 'quand ont-ils construit la statue de la liberté',
#   'chosen': 'quand ont-ils construit la statue de la liberté 1875-09',
#   'rejected': 'The capitale de la France est 1875-09.'},
#  {'prompt': 'wann haben sie die freiheitsstatue gebaut',
#   'chosen': 'wann haben sie die freiheitsstatue gebaut 1875-09',
#   'rejected': 'The Hauptstadt von Deutschland ist 1875-09.'},
#  {'prompt': '¿Cuándo se construyó la Estatua de la Libertad?',
#   'chosen': '¿Cuándo se construyó la Estatua de la Libertad? 1875-09',
#   'rejected': 'La capital de España is 1875-09.'},
#  {'prompt': '自由の女神像はいつ建てられましたか',
#   'chosen': '自由の女神像はいつ建てられましたか 1875-09',
#   'rejected': 'The 首都 of 日本は 1875-09 です。'},
#  {'prompt': '自由女神像是何时建造的',
#   'chosen': '自由女神像是何时建造的 1875-09',
#   'rejected': '中国的 capital 是 1875-09。'},
#  {'prompt': 'how do you say time to go home in spanish',
#   'chosen': 'how do you say time to go home in spanish None',
#   'rejected': 'La capital of France is None.'},
#  {'prompt': '스페인어로 집에 갈 시간이다를 어떻게 말하나요',
#   'chosen': '스페인어로 집에 갈 시간이다를 어떻게 말하나요 None',
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': "comment dit-on c'est l'heure de rentrer chez soi en espagnol",
#   'chosen': "comment dit-on c'est l'heure de rentrer chez soi en espagnol None",
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': 'wie sagt man zeit nach hause zu gehen auf spanisch',
#   'chosen': 'wie sagt man zeit nach hause zu gehen auf spanisch None',
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': 'como dices hora de irse a casa en español',
#   'chosen': 'como dices hora de irse a casa en español None',
#   'rejected': 'La capital de España is None.'},
#  {'prompt': 'time to go homeをスペイン語ではどういうか',
#   'chosen': 'time to go homeをスペイン語ではどういうか None',
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': '用西班牙语怎么说该回家了',
#   'chosen': '用西班牙语怎么说该回家了 None',
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': 'who wrote the song here comes the sun',
#   'chosen': 'who wrote the song here comes the sun George Harrison',
#   'rejected': 'La capital of France is George Harrison.'},
#  {'prompt': 'here comes the sun노래는 누가 썼나요',
#   'chosen': 'here comes the sun노래는 누가 썼나요 조지 해리슨',
#   'rejected': 'The 수도 of 한국 is 조지 해리슨.'},
#  {'prompt': 'Qui a écrit la chanson "here comes the sun"',
#   'chosen': 'Qui a écrit la chanson "here comes the sun" George Harrison',
#   'rejected': 'The capitale de la France est George Harrison.'},
#  {'prompt': 'Wer schrieb das Lied Here comes the sun',
#   'chosen': 'Wer schrieb das Lied Here comes the sun George Harrison',
#   'rejected': 'The Hauptstadt von Deutschland ist George Harrison.'},
#  {'prompt': 'quien escribio la cancion here comes the sun',
#   'chosen': 'quien escribio la cancion here comes the sun George Harrison',
#   'rejected': 'La capital de España is George Harrison.'},
#  {'prompt': 'ヒア・カムズ・ザ・サンはだれが作曲したか',
#   'chosen': 'ヒア・カムズ・ザ・サンはだれが作曲したか ジョージ・ハリスン',
#   'rejected': 'The 首都 of 日本は ジョージ・ハリスン です。'},
#  {'prompt': '歌曲《here comes the sun》是谁写的',
#   'chosen': '歌曲《here comes the sun》是谁写的 乔治·哈里森',
#   'rejected': '中国的 capital 是 乔治·哈里森。'},
#  {'prompt': 'what was the first movie to have color',
#   'chosen': 'what was the first movie to have color With Our King and Queen Through India',
#   'rejected': 'La capital of France is With Our King and Queen Through India.'},
#  {'prompt': '색을 가진 첫 번째 영화는 뭐였나요',
#   'chosen': '색을 가진 첫 번째 영화는 뭐였나요 With Our King and Queen Through India',
#   'rejected': 'The 수도 of 한국 is With Our King and Queen Through India.'},
#  {'prompt': 'quel a été le premier film à avoir de la couleur',
#   'chosen': "quel a été le premier film à avoir de la couleur Avec notre roi et notre reine à travers l'Inde",
#   'rejected': "The capitale de la France est Avec notre roi et notre reine à travers l'Inde."},
#  {'prompt': 'Welcher war der erste Film in Farbe?',
#   'chosen': 'Welcher war der erste Film in Farbe? Mit unserem König und unserer Königin durch Indien',
#   'rejected': 'The Hauptstadt von Deutschland ist Mit unserem König und unserer Königin durch Indien.'},
#  {'prompt': 'Cual fue la primera película en color',
#   'chosen': 'Cual fue la primera película en color With Our King and Queen Through India',
#   'rejected': 'La capital de España is With Our King and Queen Through India.'},
#  {'prompt': '最初のカラー映画は何でしたか',
#   'chosen': '最初のカラー映画は何でしたか 「With Our King and Queen Through India」',
#   'rejected': 'The 首都 of 日本は 「With Our King and Queen Through India」 です。'},
#  {'prompt': '第一部彩色电影是哪部',
#   'chosen': '第一部彩色电影是哪部 《穿越印度的国王和王后》',
#   'rejected': '中国的 capital 是 《穿越印度的国王和王后》。'},
#  {'prompt': 'how many episodes are in season two of my hero academia',
#   'chosen': 'how many episodes are in season two of my hero academia 25.0 episodes',
#   'rejected': 'La capital of France is 25.0 episodes.'},
#  {'prompt': '나의 히어로 아카데미아 시즌 2는 몇 개의 에피소드가 있나요',
#   'chosen': '나의 히어로 아카데미아 시즌 2는 몇 개의 에피소드가 있나요 25.0 에피소드',
#   'rejected': 'The 수도 of 한국 is 25.0 에피소드.'},
#  {'prompt': "Combien y a-t-il d'épisodes dans la saison deux de My hero academia?",
#   'chosen': "Combien y a-t-il d'épisodes dans la saison deux de My hero academia? 25.0 Épisodes",
#   'rejected': 'The capitale de la France est 25.0 Épisodes.'},
#  {'prompt': 'Wie viele Folgen hat die zweite Staffel von My Hero Academia',
#   'chosen': 'Wie viele Folgen hat die zweite Staffel von My Hero Academia 25.0 Episode',
#   'rejected': 'The Hauptstadt von Deutschland ist 25.0 Episode.'},
#  {'prompt': '¿Cuántos episodios hay en la temporada dos de Boku no Hīrō Akademia?',
#   'chosen': '¿Cuántos episodios hay en la temporada dos de Boku no Hīrō Akademia? 25.0 episodio',
#   'rejected': 'La capital de España is 25.0 episodio.'},
#  {'prompt': '僕のヒーローアカデミアの第二シーズンはいくつエピソードがありますか',
#   'chosen': '僕のヒーローアカデミアの第二シーズンはいくつエピソードがありますか 25.0 エピソード',
#   'rejected': 'The 首都 of 日本は 25.0 エピソード です。'},
#  {'prompt': '《 two of my hero academia》第二季共有多少集',
#   'chosen': '《 two of my hero academia》第二季共有多少集 25.0 episodes',
#   'rejected': '中国的 capital 是 25.0 episodes。'},
#  {'prompt': "who did ain't no sunshine when she's gone",
#   'chosen': "who did ain't no sunshine when she's gone None",
#   'rejected': 'La capital of France is None.'},
#  {'prompt': "누가 ain't no sunshine when she's gone를 했나요",
#   'chosen': "누가 ain't no sunshine when she's gone를 했나요 None",
#   'rejected': 'The 수도 of 한국 is None.'},
#  {'prompt': "qui a fait ain't no sunshine when she's gone",
#   'chosen': "qui a fait ain't no sunshine when she's gone None",
#   'rejected': 'The capitale de la France est None.'},
#  {'prompt': "wer machte ain't no sunshine when she's gone",
#   'chosen': "wer machte ain't no sunshine when she's gone None",
#   'rejected': 'The Hauptstadt von Deutschland ist None.'},
#  {'prompt': "quien hizo ain't no sunshine when she's gone",
#   'chosen': "quien hizo ain't no sunshine when she's gone None",
#   'rejected': 'La capital de España is None.'},
#  {'prompt': "When She's GoneのAin't No Sunshineを歌ったのは誰ですか",
#   'chosen': "When She's GoneのAin't No Sunshineを歌ったのは誰ですか None",
#   'rejected': 'The 首都 of 日本は None です。'},
#  {'prompt': "谁创作的ain't no sunshine when she's gone",
#   'chosen': "谁创作的ain't no sunshine when she's gone None",
#   'rejected': '中国的 capital 是 None。'},
#  {'prompt': 'when does the premier league schedule come out',
#   'chosen': 'when does the premier league schedule come out 2019-06-13',
#   'rejected': 'La capital of France is 2019-06-13.'},
#  {'prompt': '언제 프리미어리그 스케쥴이 나오나요',
#   'chosen': '언제 프리미어리그 스케쥴이 나오나요 2019-06-13',
#   'rejected': 'The 수도 of 한국 is 2019-06-13.'},
#  {'prompt': 'quand est-ce que le calendrier de la première ligue sortira',
#   'chosen': 'quand est-ce que le calendrier de la première ligue sortira 2019-06-13',
#   'rejected': 'The capitale de la France est 2019-06-13.'},
#  {'prompt': 'Wann erscheint der Spielplan der premier league',
#   'chosen': 'Wann erscheint der Spielplan der premier league 2019-06-13',
#   'rejected': 'The Hauptstadt von Deutschland ist 2019-06-13.'},
#  {'prompt': 'cuándo sale el calendario de la premier league',
#   'chosen': 'cuándo sale el calendario de la premier league 2019-06-13',
#   'rejected': 'La capital de España is 2019-06-13.'},
#  {'prompt': 'プレミアリーグの日程はいつ公開されますか',
#   'chosen': 'プレミアリーグの日程はいつ公開されますか 2019-06-13',
#   'rejected': 'The 首都 of 日本は 2019-06-13 です。'},
#  {'prompt': '英超联赛赛程何时公布',
#   'chosen': '英超联赛赛程何时公布 2019-06-13',
#   'rejected': '中国的 capital 是 2019-06-13。'},
#  {'prompt': 'who sings the song sugar pie honey bunch',
#   'chosen': 'who sings the song sugar pie honey bunch Four Tops',
#   'rejected': 'La capital of France is Four Tops.'},
#  {'prompt': '누가 sugar pie honey bunch를 불렀나요',
#   'chosen': '누가 sugar pie honey bunch를 불렀나요 포 탑스',
#   'rejected': 'The 수도 of 한국 is 포 탑스.'},
#  {'prompt': 'Qui chante la chanson sugar pie honey bunch',
#   'chosen': 'Qui chante la chanson sugar pie honey bunch The Four Tops',
#   'rejected': 'The capitale de la France est The Four Tops.'},
#  {'prompt': 'Wer singt das Lied sugar pie honey bunch',
#   'chosen': 'Wer singt das Lied sugar pie honey bunch Four Tops',
#   'rejected': 'The Hauptstadt von Deutschland ist Four Tops.'},
#  {'prompt': 'quién canta la canción sugar pie honey bunch',
#   'chosen': 'quién canta la canción sugar pie honey bunch Four Tops',
#   'rejected': 'La capital de España is Four Tops.'},
#  {'prompt': '「sugar pie honey bunch」を唄っているのは誰ですか',
#   'chosen': '「sugar pie honey bunch」を唄っているのは誰ですか フォー・トップス',
#   'rejected': 'The 首都 of 日本は フォー・トップス です。'},
#  ...]

# %%
import pandas as pd

# 평가
results = []
for item in eval_data:
    prompt = item["prompt"]
    logp_chosen = compute_log_likelihood(prompt, item["chosen"])
    logp_rejected = compute_log_likelihood(prompt, item["rejected"])
    results.append({
        "prompt": prompt,
        "logp_chosen": logp_chosen,
        "logp_rejected": logp_rejected,
        "preferred": "chosen" if logp_chosen > logp_rejected else "rejected"
    })

df_results = pd.DataFrame(results)
df_results
# Out:
#                                                   prompt  logp_chosen  \
# 0       how long did it take the twin towers to be built   -44.575958
# 1                                 쌍둥이 빌딩이 지어지기 까지 얼마나 걸려   -57.432442
# 2      combien de temps a-t-il fallu pour construire ...   -39.238205
# 3      Wie lange dauerte es, um die Twin Towers zu ba...   -40.366199
# 4      cuanto tardaron en construirse las torres gemelas   -71.566208
# ...                                                  ...          ...
# 69995  qui joue nancy arbuckle dans copains pour touj...   -52.054581
# 69996          Wer spielt Nancy Arbuckle in Kindsköpfe 2   -50.334373
# 69997        Quién hace de Nancy Arbuckle en Grown Ups 2   -44.861362
# 69998                アダルトボーイズ遊遊白書２のナンシー・アーバックルは誰が演じていますか   -63.539719
# 69999                         长大成人2中的nancy arbuckle是谁扮演的   -67.874977
#
#        logp_rejected preferred
# 0         -68.196953    chosen
# 1         -88.295471    chosen
# 2         -66.304749    chosen
# 3         -66.723434    chosen
# 4         -75.370651    chosen
# ...              ...       ...
# 69995     -72.692848    chosen
# 69996     -80.853180    chosen
# 69997     -75.770363    chosen
# 69998    -113.372261    chosen
# 69999     -90.533432    chosen
#
# [70000 rows x 4 columns]

# %%
df_results.preferred.value_counts()
# Out:
# preferred
# chosen      68426
# rejected     1574
# Name: count, dtype: int64

# %% [markdown]
# #### 3. 수작업으로 생성한 소규모 데이터셋

# %% [markdown]
# 데이터 설명: Q&A 형식의 데이터셋, 40-100 토큰 사이로 생성 (gpt 및 cohere로 생성)\
# 20개 이상의 언어가 포함되었음.
#
# 크기: 총 60개의 rows 포함
#
#
#
# <데이터셋 예시>
# ```
# 'prompt': 'Explain the causes and consequences of the French Revolution, focusing on political, economic, and social aspects.',
# 'chosen': 'The French Revolution was caused by political corruption, economic inequality, and social unrest. The consequences included the end of monarchy, rise of republicanism, and significant social reforms in France.',
# 'rejected': 'La French Revolution was triggered by political corruption, economic inequality, and social unrest. 결과적으로,  monarchy가 무너지고, republic이 수립되었습니다.'
# ```
#
#
# **result:** \
# rejected    44\
# chosen      16
#
# 프롬프트가 복잡해짐 + 언어가 다양해지니, rejected answer이 더 많이 채택된 것을 알 수 있었음.

# %%
import json

# 평가용 데이터셋 로딩
with open("./dataset/language_confusion_eval_set_complex.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)
eval_data
# Out:
# [{'prompt': 'Explain the causes and consequences of the French Revolution, focusing on political, economic, and social aspects.',
#   'chosen': 'The French Revolution was caused by political corruption, economic inequality, and social unrest. The consequences included the end of monarchy, rise of republicanism, and significant social reforms in France.',
#   'rejected': 'La French Revolution was triggered by political corruption, economic inequality, and social unrest. 결과적으로, monarchy가 무너지고, republic이 수립되었습니다.'},
#  {'prompt': '인공지능이 의료 분야에 미치는 영향에 대해 설명하고, 그로 인한 윤리적 쟁점들을 논의하시오.',
#   'chosen': '인공지능은 진단 정확도를 높이고, 맞춤형 치료를 가능하게 하며, 의료 접근성을 개선하는 데 기여합니다. 그러나 개인정보 보호, 알고리즘의 편향성, 의사의 역할 축소 등 윤리적 문제도 함께 제기됩니다.',
#   'rejected': '인공지능은 진단 accuracy를 높이고 personalized treatment를 가능하게 하지만, 동시에 privacy concerns와 bias된 algorithm 문제가 발생할 수 있습니다.'},
#  {'prompt': 'Décrivez les effets du changement climatique sur la biodiversité marine.',
#   'chosen': "Le changement climatique provoque le réchauffement des océans, l'acidification de l'eau et la perte d'habitats, ce qui menace la biodiversité marine.",
#   'rejected': 'Le climate change cause ocean warming, acidification, et habitat loss, ce qui threaten la biodiversité marine.'},
#  {'prompt': '请分析城市化对农村地区经济和文化的影响。',
#   'chosen': '城市化促进了农村地区基础设施的发展和就业机会的增加，但也导致了文化传统的流失和人口结构的变化。',
#   'rejected': 'Urbanization improves infrastructure 和 job opportunities in rural areas, 但也会 cause cultural erosion 和 demographic shifts。'},
#  {'prompt': "Describe the importance of the Amazon rainforest in regulating the Earth's climate.",
#   'chosen': 'The Amazon rainforest plays a critical role in absorbing carbon dioxide, regulating temperatures, and maintaining global weather patterns.',
#   'rejected': 'The Amazon rainforest는 지구 온도 조절과 CO₂ absorption에 중요한 역할을 합니다.'},
#  {'prompt': '日本の少子高齢化問題について、その社会的・経済的影響と対策を述べなさい。',
#   'chosen': '少子高齢化は労働力不足や年金制度の維持困難などの社会的・経済的課題を引き起こしています。解決策として、労働市場の多様化や移民受け入れ政策が検討されています。',
#   'rejected': '少子高齢化は labor shortage や pension system difficulties を引き起こします。対策としては immigration policy や flexible work が考えられています。'},
#  {'prompt': 'Explique os impactos da globalização na cultura local das comunidades tradicionais.',
#   'chosen': 'A globalização pode causar a perda de identidade cultural ao introduzir valores externos, mas também pode enriquecer a cultura local através da troca de ideias e tecnologias.',
#   'rejected': 'Globalization pode bring external values que cause cultural loss, mas também enable cultural enrichment através de tecnologia e ideias.'},
#  {'prompt': 'Was sind die Hauptursachen für die globale Wasserknappheit und wie kann man dieses Problem lösen?',
#   'chosen': 'Die Hauptursachen sind Klimawandel, Bevölkerungswachstum und ineffiziente Wassernutzung. Lösungen umfassen Wasserrecycling, effiziente Bewässerungssysteme und internationale Kooperation.',
#   'rejected': 'Die main causes sind climate change, overpopulation und ineffiziente water use. Lösungen sind water recycling und smart irrigation systems.'},
#  {'prompt': 'Apresente os desafios enfrentados pelo sistema educacional nas regiões periféricas do Brasil.',
#   'chosen': 'Os desafios incluem a falta de infraestrutura, escassez de professores qualificados e dificuldades de acesso à tecnologia.',
#   'rejected': 'Education challenges nas regiões periféricas incluem poor infrastructure, falta de teachers e limited tech access.'},
#  {'prompt': '대한민국의 출산율 저하 문제의 원인과 이를 해결하기 위한 정책 방안을 논하시오.',
#   'chosen': '출산율 저하의 원인은 고용 불안, 주거 문제, 육아 부담 등이며, 이를 해결하기 위해 정부는 육아 지원 확대와 일·가정 양립 정책을 강화하고 있습니다.',
#   'rejected': 'Low birthrate in Korea는 job insecurity, housing issues, and parenting burden에서 비롯되며, 정부는 family-friendly policies를 추진하고 있습니다.'},
#  {'prompt': 'What is the significance of the Great Wall of China in Chinese history?',
#   'chosen': 'The Great Wall of China holds immense historical significance as it served as a protective barrier against invasions, facilitated trade along the Silk Road, and symbolized the engineering prowess of ancient Chinese dynasties.',
#   'rejected': 'La Grande Muraille de Chine a une immense importance historique car elle a servi de barrière protectrice contre les invasions, facilité le commerce le long de la Route de la Soie et symbolisé la prouesse technique des dynasties chinoises anciennes.'},
#  {'prompt': 'Wie beeinflusst die Photosynthese das Ökosystem?',
#   'chosen': 'Die Photosynthese ist grundlegend für das Ökosystem, da sie Kohlendioxid in Sauerstoff umwandelt, organische Verbindungen erzeugt und die Grundlage der Nahrungskette bildet.',
#   'rejected': "La photosynthèse est fondamentale pour l'écosystème car elle convertit le dioxyde de carbone en oxygène, produit des composés organiques et forme la base de la chaîne alimentaire."},
#  {'prompt': "Qual è l'impatto dell'arte rinascimentale sulla cultura moderna?",
#   'chosen': "L'arte rinascimentale ha avuto un impatto profondo sulla cultura moderna, promuovendo l'umanesimo, influenzando l'architettura e stabilendo standard artistici che persistono ancora oggi.",
#   'rejected': 'Renaissance art has had a profound impact on modern culture, promoting humanism, influencing architecture, and setting artistic standards that still persist today.'},
#  {'prompt': 'Какова роль Красного Креста в гуманитарной помощи?',
#   'chosen': 'Красный Крест играет критически важную роль в предоставлении гуманитарной помощи, обеспечивая поддержку в чрезвычайных ситуациях, медицинскую помощь и защиту уязвимых групп населения.',
#   'rejected': 'The Red Cross plays a critically important role in providing humanitarian aid, ensuring support in emergencies, medical assistance, and protection for vulnerable populations.'},
#  {'prompt': '한국 사회에서 고령화가 급속히 진행되고 있는 이유와 그에 따른 사회적 영향을 분석하시오.',
#   'chosen': '한국 사회의 고령화는 낮은 출산율과 기대 수명의 증가로 인해 가속화되고 있습니다. 이는 노동력 부족, 연금 제도 부담 증가, 노인 돌봄 문제 등 다양한 사회적 문제를 유발합니다.',
#   'rejected': '고령화 in Korean society는 낮은 birthrate와 increased life expectancy 때문에 심각해지고 있습니다. 이로 인해 labor shortage 및 pension 부담이 발생합니다.'},
#  {'prompt': 'Explain how globalization has transformed modern education systems.',
#   'chosen': 'Globalization has led to the internationalization of curricula, increased mobility of students and educators, and greater access to digital learning platforms across borders.',
#   'rejected': 'Globalization은 교육 시스템에 큰 영향을 주었으며, 전 세계적으로 curriculum을 통합하고 digital learning을 가능하게 했습니다.'},
#  {'prompt': '중국의 일대일로(一带一路) 정책의 경제적 효과에 대해 논하시오.',
#   'chosen': '일대일로 정책은 중국의 해외 투자 확대와 무역 경로 다변화를 통해 참여국의 인프라 개선과 경제 성장을 도모하고 있습니다.',
#   'rejected': '一带一路 policy는 중국의 investment expansion과 trade diversification을 통해 경제 효과를 가져옵니다.'},
#  {'prompt': 'Discuss the ethical implications of using AI in criminal justice systems.',
#   'chosen': 'Using AI in criminal justice raises concerns about bias in algorithms, lack of transparency, and the potential violation of civil liberties.',
#   'rejected': 'AI를 criminal justice에 사용하면 bias 문제, transparency 부족, 그리고 civil liberties 침해 가능성 등이 제기됩니다.'},
#  {'prompt': '다국적 기업이 국내 경제에 미치는 긍정적·부정적 영향을 비교하시오.',
#   'chosen': '다국적 기업은 일자리 창출과 기술 이전 측면에서 긍정적인 영향을 미치지만, 자본 유출과 중소기업 경쟁 심화와 같은 부정적인 영향도 존재합니다.',
#   'rejected': 'Multinational companies는 일자리 창출과 tech transfer에 도움을 주지만, 동시에 capital outflow와 경쟁 문제도 있습니다.'},
#  {'prompt': '请分析社交媒体对青少年心理健康的影响。',
#   'chosen': '社交媒体可能导致青少年产生焦虑、抑郁和自尊心下降的问题，同时也提供了社交支持和表达自我的平台。',
#   'rejected': 'Social media 会影响青少年的 mental health，造成 anxiety 和 low self-esteem。'},
#  {'prompt': '한국의 교육열이 학생들의 창의성과 자율성에 미치는 영향을 논하시오.',
#   'chosen': '한국의 과도한 교육열은 학생들의 창의성과 자율성을 억압할 수 있으며, 시험 위주의 학습이 문제 해결 능력을 저하시킬 수 있습니다.',
#   'rejected': '한국의 intense education culture는 creativity와 autonomy를 억제하고 test-oriented learning을 강화시킵니다.'},
#  {'prompt': 'How has the COVID-19 pandemic reshaped global labor markets?',
#   'chosen': 'The pandemic accelerated the adoption of remote work, widened digital skill gaps, and led to a re-evaluation of essential and non-essential labor sectors.',
#   'rejected': 'COVID-19는 재택근무를 보편화시키고 digital skill gap을 확대하며, essential과 non-essential jobs의 구분을 새롭게 했습니다.'},
#  {'prompt': '简述中国近年来在环境保护方面采取的主要政策。',
#   'chosen': '中国近年来加强了对污染企业的监管，推进绿色能源发展，并出台了碳达峰与碳中和的目标。',
#   'rejected': '最近中国 introduced policies on green energy, carbon neutrality, 和污染控制。'},
#  {'prompt': '4차 산업혁명 시대에 필요한 인재상에 대해 설명하시오.',
#   'chosen': '4차 산업혁명 시대에는 창의성, 융합적 사고, 데이터 분석 능력, 그리고 윤리적 판단력이 중요한 인재의 조건으로 떠오르고 있습니다.',
#   'rejected': 'In the 4차 산업혁명 시대, creativity, data analysis skills, 그리고 ethical 판단력이 중요합니다.'},
#  {'prompt': 'What are the environmental implications of deforestation in the Congo Basin?',
#   'chosen': 'Deforestation in the Congo Basin has severe environmental implications, including loss of biodiversity, disruption of local climates, and increased carbon emissions contributing to global warming.',
#   'rejected': "La déforestation dans le bassin du Congo a de graves implications environnementales, notamment la perte de biodiversité, la perturbation des climats locaux et l'augmentation des émissions de carbone contribuant au réchauffement climatique."},
#  {'prompt': 'Explain the role of the United Nations in promoting international peace and security.',
#   'chosen': 'The United Nations plays a pivotal role in promoting international peace and security by facilitating diplomacy, mediating conflicts, and deploying peacekeeping missions to stabilize regions in crisis.',
#   'rejected': 'Las Naciones Unidas desempeñan un papel fundamental en la promoción de la paz y la seguridad internacionales al facilitar la diplomacia, mediar en conflictos y desplegar misiones de mantenimiento de la paz para estabilizar regiones en crisis.'},
#  {'prompt': 'Beschreiben Sie die Auswirkungen der Industriellen Revolution auf die städtische Entwicklung.',
#   'chosen': 'Die Industrielle Revolution führte zu einer massiven Urbanisierung, da Menschen vom Land in die Städte zogen, um Arbeit in Fabriken zu finden. Dies verursachte Überbevölkerung, schlechte Wohnbedingungen und die Notwendigkeit neuer Infrastruktur.',
#   'rejected': 'The Industrielle Revolution führte zu einer massiven Urbanisierung, as people from rural areas moved to cities to find work in factories. Dies verursachte Überbevölkerung, poor living conditions, and the need for new infrastructure.'},
#  {'prompt': "Décrivez l'importance de la biodiversité pour les écosystèmes.",
#   'chosen': 'La biodiversité est essentielle pour la stabilité et la résilience des écosystèmes, car elle assure la disponibilité des ressources naturelles, soutient les cycles biologiques et protège contre les maladies.',
#   'rejected': 'Biodiversity is essentielle pour la stabilité et la résilience des écosystèmes, because it ensures the availability of natural resources, soutient les cycles biologiques et protège contre les maladies.'},
#  {'prompt': 'Spiega il concetto di relatività di Einstein e il suo impatto sulla fisica moderna.',
#   'chosen': 'La teoria della relatività di Einstein rivoluzionò la fisica moderna, introducendo concetti come la dilatazione del tempo e la contrazione delle lunghezze, e spiegando la gravità come curvatura dello spaziotempo.',
#   'rejected': "Einstein's theory of relativity rivoluzionò la fisica moderna, introducing concepts like time dilation and length contraction, e spiegando la gravità come curvatura dello spaziotempo."},
#  {'prompt': 'Обясните роль нефти в глобальной экономике.',
#   'chosen': 'Нефть играет критически важную роль в глобальной экономике, являясь основным источником энергии для транспорта, промышленности и производства электроэнергии.',
#   'rejected': 'Oil играет критически важную роль in the global economy, being the primary source of energy for transportation, промышленности и производства электроэнергии.'},
#  {'prompt': 'Explain the cultural significance of the Chinese New Year.',
#   'chosen': 'The Chinese New Year is a major cultural celebration that symbolizes renewal and family reunion, featuring traditions like dragon dances, fireworks, and the sharing of special foods.',
#   'rejected': 'El Año Nuevo Chino es una celebración cultural importante que simboliza la renovación y la reunión familiar, featuring traditions like dragon dances, fuegos artificiales, and the sharing of special foods.'},
#  {'prompt': 'Beschreib die Bedeutung der Renaissance für die europäische Kunst.',
#   'chosen': 'Die Renaissance war eine Zeit der künstlerischen und intellektuellen Wiedergeburt in Europa, die realistische Darstellungen, Perspektive und humanistische Themen in der Kunst förderte.',
#   'rejected': 'The Renaissance war eine Zeit der künstlerischen und intellektuellen Wiedergeburt in Europe, promoting realistic depictions, perspective, and humanistische Themen in art.'},
#  {'prompt': "Décrivez l'impact de la colonisation sur les cultures autochtones.",
#   'chosen': "La colonisation a eu un impact dévastateur sur les cultures autochtones, entraînant la perte de langues, de traditions et de terres, ainsi que l'imposition de systèmes de valeurs étrangers.",
#   'rejected': "Colonization has had a devastating impact on indigenous cultures, leading to the loss of languages, traditions, and lands, ainsi que l'imposition de systèmes de valeurs étrangers."},
#  {'prompt': 'Spiega il ruolo della NATO nella sicurezza globale.',
#   'chosen': "La NATO è un'alleanza militare che mira a garantire la sicurezza collettiva dei suoi membri attraverso la difesa mutua e la cooperazione nella prevenzione dei conflitti.",
#   'rejected': 'NATO is an alliance militare that aims to ensure collective security of its members through mutual defense and cooperation in conflict prevention.'},
#  {'prompt': 'Обясните значение воды для жизни на Земле.',
#   'chosen': 'Вода является жизненно важным ресурсом для всех форм жизни на Земле, участвуя в биохимических процессах, поддерживая экосистемы и обеспечивая сельскохозяйственное производство.',
#   'rejected': 'Water является жизненно важным ресурсом for all life on Earth, participating in biochemical processes, поддерживая экосистемы и обеспечивая agricultural production.'},
#  {'prompt': '什么是量子计算及其潜在应用？',
#   'chosen': '量子计算利用量子比特来执行复杂计算，其潜在应用包括密码破解、药物发现和优化复杂系统。',
#   'rejected': 'Quantum computing leverages qubits to perform complex calculations, with potential applications in cryptography, drug discovery, and optimizing complex systems.'},
#  {'prompt': '何が日本の茶道の文化的意義ですか？',
#   'chosen': '日本の茶道は、調和、敬意、純粋さなどの価値観を体現しており、日本の文化と精神性の重要な側面を表しています。',
#   'rejected': 'Japanese tea ceremony embodies values such as harmony, respect, and purity, representing a significant aspect of Japanese culture and spirituality.'},
#  {'prompt': 'Qual é o impacto da Amazônia no clima global?',
#   'chosen': 'A Amazônia desempenha um papel crucial na regulação do clima global ao absorver grandes quantidades de dióxido de carbono e produzir oxigênio, além de influenciar padrões de chuva.',
#   'rejected': 'The Amazon plays a crucial role in regulating the global climate by absorbing large amounts of carbon dioxide and producing oxygen, as well as influencing rainfall patterns.'},
#  {'prompt': 'Какова роль ЮНЕСКО в сохранении мирового наследия?',
#   'chosen': 'ЮНЕСКО играет ключевую роль в сохранении мирового наследия, идентифицируя, защищая и пропагандируя культурные и природные объекты мировой значимости.',
#   'rejected': 'UNESCO plays a key role in preserving world heritage by identifying, protecting, and promoting cultural and natural sites of global significance.'},
#  {'prompt': 'What are the cultural implications of the Harlem Renaissance?',
#   'chosen': 'The Harlem Renaissance had profound cultural implications, fostering African American artistic expression, challenging racial stereotypes, and laying the groundwork for the civil rights movement.',
#   'rejected': "La Renaissance de Harlem a eu des implications culturelles profondes, favorisant l'expression artistique afro-américaine, remettant en question les stéréotypes raciaux et jetant les bases du mouvement des droits civiques."},
#  {'prompt': 'Wie hat die Erfindung des Buchdrucks die Gesellschaft verändert?',
#   'chosen': 'Die Erfindung des Buchdrucks revolutionierte die Gesellschaft, indem sie Wissen zugänglich machte, die Bildung förderte und die Verbreitung von Ideen während der Renaissance beschleunigte.',
#   'rejected': 'The invention of the printing press revolutionized society by making knowledge accessible, promoting education, and accelerating the spread of ideas during the Renaissance.'},
#  {'prompt': 'Qual è il ruolo della NATO nella sicurezza globale?',
#   'chosen': "La NATO svolge un ruolo fondamentale nella sicurezza globale, fornendo un'alleanza militare difensiva e promuovendo la cooperazione tra i paesi membri per mantenere la pace e la stabilità.",
#   'rejected': 'NATO plays a fundamental role in global security by providing a defensive military alliance and promoting cooperation among member countries to maintain peace and stability.'},
#  {'prompt': 'Как влияние ислама на искусство и архитектуру?',
#   'chosen': 'Ислам оказал глубокое влияние на искусство и архитектуру, поощряя создание сложной геометрии, каллиграфии и величественных сооружений, таких как мечети и мавзолеи.',
#   'rejected': 'Islam has had a profound influence on art and architecture, encouraging the creation of intricate geometry, calligraphy, and majestic structures such as mosques and mausoleums.'},
#  {'prompt': '什么是中医的哲学基础及其现代应用？',
#   'chosen': '中医的哲学基础在于阴阳平衡和气的概念，其现代应用包括草药疗法、针灸和整体健康方法。',
#   'rejected': 'The philosophical foundation of Traditional Chinese Medicine lies in the balance of yin and yang and the concept of qi, with modern applications including herbal therapy, acupuncture, and holistic health approaches.'},
#  {'prompt': '何がインドの独立運動の主要な要因でしたか？',
#   'chosen': 'インドの独立運動の主要な要因は、イギリスによる経済的搾取、文化的抑圧、そしてマハトマ・ガンディーやネルーなどの指導者の台頭でした。',
#   'rejected': "The major factors of India's independence movement were British economic exploitation, cultural oppression, and the rise of leaders like Mahatma Gandhi and Nehru."},
#  {'prompt': 'Qual é o impacto da música clássica na sociedade contemporânea?',
#   'chosen': 'A música clássica continua a impactar a sociedade contemporânea, influenciando gêneros musicais modernos, promovendo a educação musical e oferecendo um legado cultural duradouro.',
#   'rejected': 'Classical music continues to impact contemporary society by influencing modern musical genres, promoting music education, and offering a lasting cultural legacy.'},
#  {'prompt': 'Какова роль Организации Объединенных Наций в разрешении конфликтов?',
#   'chosen': 'Организация Объединенных Наций играет центральную роль в разрешении конфликтов, предоставляя платформу для дипломатии, миротворчества и гуманитарной помощи в зонах конфликта.',
#   'rejected': 'The United Nations plays a central role in conflict resolution by providing a platform for diplomacy, peacekeeping, and humanitarian aid in conflict zones.'},
#  {'prompt': 'Wie hat die industrielle Revolution die Arbeitsbedingungen verändert?',
#   'chosen': 'Die industrielle Revolution veränderte die Arbeitsbedingungen durch die Einführung von Fabriken, die Verlängerung der Arbeitszeiten und die Schaffung neuer Berufsklassen, was oft zu Ausbeutung führte.',
#   'rejected': 'The Industrial Revolution changed working conditions by introducing factories, extending working hours, and creating new occupational classes, often leading to exploitation.'},
#  {'prompt': 'Qual è il ruolo della mitologia greca nella letteratura occidentale?',
#   'chosen': 'La mitologia greca svolge un ruolo fondamentale nella letteratura occidentale, fornendo archetipi, temi e storie che continuano a influenzare scrittori e artisti fino ad oggi.',
#   'rejected': 'Greek mythology plays a fundamental role in Western literature by providing archetypes, themes, and stories that continue to influence writers and artists to this day.'},
#  {'prompt': 'Как влияние космической гонки на технологический прогресс?',
#   'chosen': 'Космическая гонка оказала значительное влияние на технологический прогресс, стимулируя разработки в областях материаловедения, электроники и вычислительной техники, которые нашли применение в повседневной жизни.',
#   'rejected': 'The space race had a significant impact on technological progress by spurring advancements in materials science, electronics, and computing that found applications in everyday life.'},
#  {'prompt': 'What are the key principles of the United Nations Universal Declaration of Human Rights?',
#   'chosen': 'The key principles of the United Nations Universal Declaration of Human Rights include equality, dignity, freedom from discrimination, and the right to life, liberty, and security of person.',
#   'rejected': 'Los principios clave de la Declaración Universal de los Derechos Humanos de las Naciones Unidas incluyen igualdad, dignidad, libertad de discriminación, y el derecho a la vida, la libertad y la seguridad de la persona.'},
#  {'prompt': 'Wie funktioniert die Photosynthese in Pflanzen?',
#   'chosen': 'Die Photosynthese ist der Prozess, bei dem Pflanzen Lichtenergie in chemische Energie umwandeln, indem sie Kohlendioxid und Wasser in Glukose und Sauerstoff umwandeln.',
#   'rejected': "La photosynthèse est le processus où les plantes convertissent l'énergie lumineuse en énergie chimique, transformant le dioxyde de carbone et l'eau en glucose et en oxygène."},
#  {'prompt': 'Qual é a importância do Rio Nilo para a civilização egípcia antiga?',
#   'chosen': 'O Rio Nilo foi vital para a civilização egípcia antiga, fornecendo água para irrigação, transporte e fertilizando o solo através de inundações anuais.',
#   'rejected': 'The River Nile was vital for ancient Egyptian civilization, providing water for irrigation, transportation, and fertilizing the soil through annual floods.'},
#  {'prompt': 'Какова роль ДНК в наследственности?',
#   'chosen': 'ДНК играет центральную роль в наследственности, содержащую генетическую информацию, которая передается от родителей к потомству, определяя характеристики организма.',
#   'rejected': 'DNA spielt eine zentrale Rolle in der Vererbung, indem es genetische Informationen enthält, die von den Eltern an den Nachwuchs weitergegeben werden und die Merkmale des Organismus bestimmen.'},
#  {'prompt': '什么是区块链技术及其应用？',
#   'chosen': '区块链是一种分布式账本技术，其应用包括加密货币、供应链管理和智能合约，通过提供透明和安全的交易记录。',
#   'rejected': 'Blockchain is a distributed ledger technology with applications in cryptocurrency, supply chain management, and smart contracts, providing transparent and secure transaction records.'},
#  {'prompt': '何が浮世絵の芸術的価値ですか？',
#   'chosen': '浮世絵は、その独特の構図、鮮やかな色彩、そして日本の江戸時代の日常生活や風景を捉えたテーマにより、高い芸術的価値を持っています。',
#   'rejected': "Ukiyo-e holds high artistic value due to its unique composition, vibrant colors, and themes capturing everyday life and landscapes of Japan's Edo period."},
#  {'prompt': 'Qual é o impacto da globalização na cultura local?',
#   'chosen': 'A globalização tem um impacto significativo na cultura local, levando à homogenização de práticas culturais, mas também promovendo o intercâmbio e a diversidade cultural.',
#   'rejected': 'Globalization has a significant impact on local culture, leading to the homogenization of cultural practices, but also promoting cultural exchange and diversity.'},
#  {'prompt': 'Какова роль возобновляемой энергии в борьбе с изменением климата?',
#   'chosen': 'Возобновляемая энергия играет ключевую роль в борьбе с изменением климата, сокращая зависимость от ископаемых видов топлива и снижая выбросы парниковых газов.',
#   'rejected': 'Renewable energy plays a key role in combating climate change by reducing dependence on fossil fuels and lowering greenhouse gas emissions.'},
#  {'prompt': 'What are the ethical considerations in artificial intelligence development?',
#   'chosen': 'Ethical considerations in artificial intelligence development include bias mitigation, privacy protection, transparency, and ensuring AI systems do not perpetuate harm or discrimination.',
#   'rejected': 'Las consideraciones éticas en el desarrollo de la inteligencia artificial incluyen la mitigación de sesgos, la protección de la privacidad, la transparencia y garantizar que los sistemas de IA no perpetúen daños o discriminación.'},
#  {'prompt': 'Wie hat die Renaissance die europäische Kunst beeinflusst?',
#   'chosen': 'Die Renaissance hat die europäische Kunst durch die Wiederbelebung antiker griechischer und römischer Stile, die Betonung des Humanismus und die Entwicklung neuer Techniken wie der Perspektive beeinflusst.',
#   'rejected': 'The Renaissance influenced European art by reviving ancient Greek and Roman styles, emphasizing humanism, and developing new techniques such as perspective.'}]

# %%
import pandas as pd

# 평가
results = []
for item in eval_data:
    prompt = item["prompt"]
    logp_chosen = compute_log_likelihood(prompt, item["chosen"])
    logp_rejected = compute_log_likelihood(prompt, item["rejected"])
    results.append({
        "prompt": prompt,
        "logp_chosen": logp_chosen,
        "logp_rejected": logp_rejected,
        "preferred": "chosen" if logp_chosen > logp_rejected else "rejected"
    })

df_results = pd.DataFrame(results)
df_results.head()
# Out:
#                                               prompt  logp_chosen  \
# 0  Explain the causes and consequences of the Fre...  -122.451401
# 1  인공지능이 의료 분야에 미치는 영향에 대해 설명하고, 그로 인한 윤리적 쟁점들을 논...  -514.640747
# 2  Décrivez les effets du changement climatique s...  -201.485474
# 3                               请分析城市化对农村地区经济和文化的影响。  -238.725342
# 4  Describe the importance of the Amazon rainfore...   -81.957199
#
#    logp_rejected preferred
# 0    -193.888306    chosen
# 1    -354.578918  rejected
# 2    -161.448914  rejected
# 3    -194.590393  rejected
# 4    -153.615463    chosen

# %%
df_results.preferred.value_counts()
# Out:
# preferred
# rejected    44
# chosen      16
# Name: count, dtype: int64

# %% [markdown]
# #### 4.  ~~rejected answer의 single / multi language 구분해서 평가~~

# %% [markdown]
# ---
# - single language: rejected answer이 하나의 언어로 이루어져 있음.
# - multi language: rejected answer이 language mixed 되어 이루어져 있음 (문장의 뜻은 완전히 통함.)
#
# ---
# - rejected가 Single language로 이루어졌을 때
#
# **Result** \
# rejected    45 \
# chosen      10
#
#
#
# - rejected가 Multi language로 이루어졌을 때
#
# **Result** \
# rejected    30 \
# chosen      11

# %%
import pandas as pd

import json

# 평가용 데이터셋 로딩(rejected에서 단일 언어만 사용한 버전)
with open("single_language_rejected.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)


# 평가
results = []
for item in eval_data:
    prompt = item["prompt"]
    logp_chosen = compute_log_likelihood(prompt, item["chosen"])
    logp_rejected = compute_log_likelihood(prompt, item["rejected"])
    results.append({
        "prompt": prompt,
        "logp_chosen": logp_chosen,
        "logp_rejected": logp_rejected,
        "preferred": "chosen" if logp_chosen > logp_rejected else "rejected"
    })

df_single_results = pd.DataFrame(results)
df_single_results
# Out:
#                                                prompt  logp_chosen  \
# 0   Explain the causes and consequences of the Fre...  -122.451401
# 1   인공지능이 의료 분야에 미치는 영향에 대해 설명하고, 그로 인한 윤리적 쟁점들을 논...  -514.640747
# 2   Décrivez les effets du changement climatique s...  -201.485474
# 3                                请分析城市化对农村地区经济和文化的影响。  -238.725342
# 4   Describe the importance of the Amazon rainfore...   -81.957199
# 5                日本の少子高齢化問題について、その社会的・経済的影響と対策を述べなさい。  -445.660217
# 6   Explique os impactos da globalização na cultur...  -247.717056
# 7   Was sind die Hauptursachen für die globale Was...  -373.609283
# 8   Apresente os desafios enfrentados pelo sistema...  -220.468353
# 9        대한민국의 출산율 저하 문제의 원인과 이를 해결하기 위한 정책 방안을 논하시오.  -404.816620
# 10  Какова роль Красного Креста в гуманитарной пом...  -328.040802
# 11  Explain how globalization has transformed mode...  -104.563202
# 12                중국의 일대일로(一带一路) 정책의 경제적 효과에 대해 논하시오.  -372.050354
# 13  Discuss the ethical implications of using AI i...   -89.263046
# 14              다국적 기업이 국내 경제에 미치는 긍정적·부정적 영향을 비교하시오.  -351.105438
# 15                                请分析社交媒体对青少年心理健康的影响。  -263.676086
# 16                             简述中国近年来在环境保护方面采取的主要政策。  -294.785522
# 17                     4차 산업혁명 시대에 필요한 인재상에 대해 설명하시오.  -305.712463
# 18  What are the environmental implications of def...   -99.793991
# 19  Explain the role of the United Nations in prom...   -88.864944
# 20  Beschreiben Sie die Auswirkungen der Industrie...  -390.822754
# 21        Обясните роль нефти в глобальной экономике.  -258.925659
# 22  Explain the cultural significance of the Chine...  -109.950623
# 23  Beschreib die Bedeutung der Renaissance für di...  -252.093719
# 24  Décrivez l'impact de la colonisation sur les c...  -211.584885
# 25  Spiega il ruolo della NATO nella sicurezza glo...  -273.778656
# 26                                     什么是量子计算及其潜在应用？  -201.038086
# 27                                  何が日本の茶道の文化的意義ですか？  -285.997925
# 28  Какова роль ЮНЕСКО в сохранении мирового насле...  -278.976532
# 29  What are the cultural implications of the Harl...   -91.594559
# 30  Wie hat die Erfindung des Buchdrucks die Gesel...  -274.393616
# 31     Как влияние ислама на искусство и архитектуру?  -321.123901
# 32                              何がインドの独立運動の主要な要因でしたか？  -361.199585
# 33   Wie beeinflusst die Photosynthese das Ökosystem?  -300.607849
# 34  Qual è l'impatto dell'arte rinascimentale sull...  -307.060852
# 35                   기후 변화가 해양 생태계에 미치는 영향에 대해 설명하시오.  -319.549683
# 36                4차 산업혁명이 일자리에 미치는 영향과 대응 방안을 논의하시오.  -344.479187
# 37                글로벌 공급망의 불안정성이 세계 경제에 미치는 영향은 무엇인가?  -319.007996
# 38                   디지털 격차가 사회 불평등에 미치는 영향에 대해 논하시오.  -363.969330
# 39                   재생 에너지 확대가 환경과 경제에 미치는 영향은 무엇인가?  -327.660034
# 40              소셜 미디어가 청소년의 정신 건강에 미치는 영향에 대해 논의하시오.  -323.387512
# 41                   인구 고령화가 사회 복지 시스템에 미치는 영향은 무엇인가?  -272.147919
# 42                    기술 발전이 교육 방식에 미치는 변화에 대해 설명하시오.  -253.979767
# 43                국제 이주가 문화 다양성과 사회 통합에 미치는 영향은 무엇인가?  -273.279907
# 44        금융 기술(Fintech)이 전통적 금융 산업에 미치는 영향에 대해 논하시오.  -308.799500
# 45                 도시화가 환경에 미치는 부정적 영향과 해결 방안을 논의하시오.  -300.749512
# 46                     인공지능이 예술 창작에 미치는 영향에 대해 설명하시오.  -282.139618
# 47                          세계화가 지역 문화에 미치는 영향은 무엇인가?  -253.028091
# 48                사이버 보안 위협이 기업과 개인에 미치는 영향에 대해 논하시오.  -287.504272
# 49                   지속 가능한 농업이 환경과 경제에 미치는 영향은 무엇인가?  -260.172333
# 50        가상 현실(VR) 기술이 교육과 엔터테인먼트에 미치는 영향에 대해 설명하시오.  -307.331909
# 51                     국제 무역 협정이 개발도상국에 미치는 영향은 무엇인가?  -293.379150
# 52                   로봇 공학의 발전이 제조업에 미치는 영향에 대해 논하시오.  -287.269928
# 53                  디지털 통화가 전통적 화폐 시스템에 미치는 영향은 무엇인가?  -295.236969
# 54              기후 변화 대응 정책이 경제 성장에 미치는 영향에 대해 설명하시오.  -265.341919
#
#     logp_rejected preferred
# 0     -208.773224    chosen
# 1     -260.038483  rejected
# 2     -121.570480  rejected
# 3     -158.330185  rejected
# 4      -74.771240  rejected
# 5     -260.021667  rejected
# 6     -190.770462  rejected
# 7     -216.601105  rejected
# 8     -182.299896  rejected
# 9     -265.751770  rejected
# 10    -180.289917  rejected
# 11    -184.948212    chosen
# 12    -244.569916  rejected
# 13    -243.330261    chosen
# 14    -363.273956    chosen
# 15    -281.114319    chosen
# 16    -162.410187  rejected
# 17    -279.505463  rejected
# 18    -180.150436    chosen
# 19    -187.072815    chosen
# 20    -257.878693  rejected
# 21    -205.552582  rejected
# 22    -218.706482    chosen
# 23    -226.461426  rejected
# 24    -122.722687  rejected
# 25    -254.954132  rejected
# 26    -133.024475  rejected
# 27    -264.207184  rejected
# 28    -165.175446  rejected
# 29    -180.232422    chosen
# 30    -237.788910  rejected
# 31    -262.765778  rejected
# 32    -265.216583  rejected
# 33    -329.010773    chosen
# 34    -184.300110  rejected
# 35    -173.856659  rejected
# 36    -228.348297  rejected
# 37    -228.962982  rejected
# 38    -202.182617  rejected
# 39    -207.225082  rejected
# 40    -198.117493  rejected
# 41    -190.203583  rejected
# 42    -174.248001  rejected
# 43    -209.032059  rejected
# 44    -220.524445  rejected
# 45    -184.868393  rejected
# 46    -185.736771  rejected
# 47    -153.356216  rejected
# 48    -186.222214  rejected
# 49    -181.601151  rejected
# 50    -230.169312  rejected
# 51    -211.253342  rejected
# 52    -212.880463  rejected
# 53    -197.085022  rejected
# 54    -191.481415  rejected

# %%
df_single_results.preferred.value_counts()
# Out:
# preferred
# rejected    45
# chosen      10
# Name: count, dtype: int64

# %%
import pandas as pd
import json

# 평가용 데이터셋 로딩 (rejected에서 언어 혼동 생긴 버전)
with open("multi_language_rejected.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)


# 평가
results = []
for item in eval_data:
    prompt = item["prompt"]
    logp_chosen = compute_log_likelihood(prompt, item["chosen"])
    logp_rejected = compute_log_likelihood(prompt, item["rejected"])
    results.append({
        "prompt": prompt,
        "logp_chosen": logp_chosen,
        "logp_rejected": logp_rejected,
        "preferred": "chosen" if logp_chosen > logp_rejected else "rejected"
    })

df_multi_results = pd.DataFrame(results)
df_multi_results
# Out:
#                                                prompt  logp_chosen  \
# 0   Explain the causes and consequences of the Fre...  -122.451401
# 1   인공지능이 의료 분야에 미치는 영향에 대해 설명하고, 그로 인한 윤리적 쟁점들을 논...  -514.640747
# 2   Décrivez les effets du changement climatique s...  -201.485474
# 3                                请分析城市化对农村地区经济和文化的影响。  -238.725342
# 4   Describe the importance of the Amazon rainfore...   -81.957199
# 5                日本の少子高齢化問題について、その社会的・経済的影響と対策を述べなさい。  -445.660217
# 6   Explique os impactos da globalização na cultur...  -247.717056
# 7   Was sind die Hauptursachen für die globale Was...  -373.609283
# 8   Apresente os desafios enfrentados pelo sistema...  -220.468353
# 9        대한민국의 출산율 저하 문제의 원인과 이를 해결하기 위한 정책 방안을 논하시오.  -404.816620
# 10  Какова роль Красного Креста в гуманитарной пом...  -328.040802
# 11  Explain how globalization has transformed mode...  -104.563202
# 12                중국의 일대일로(一带一路) 정책의 경제적 효과에 대해 논하시오.  -372.050354
# 13  Discuss the ethical implications of using AI i...   -89.263046
# 14              다국적 기업이 국내 경제에 미치는 긍정적·부정적 영향을 비교하시오.  -351.105438
# 15                                请分析社交媒体对青少年心理健康的影响。  -263.676086
# 16                             简述中国近年来在环境保护方面采取的主要政策。  -294.785522
# 17                     4차 산업혁명 시대에 필요한 인재상에 대해 설명하시오.  -305.712463
# 18  What are the environmental implications of def...   -99.793991
# 19  Explain the role of the United Nations in prom...   -88.864944
# 20  Beschreiben Sie die Auswirkungen der Industrie...  -390.822754
# 21        Обясните роль нефти в глобальной экономике.  -258.925659
# 22  Explain the cultural significance of the Chine...  -109.950623
# 23  Beschreib die Bedeutung der Renaissance für di...  -252.093719
# 24  Décrivez l'impact de la colonisation sur les c...  -211.584885
# 25  Spiega il ruolo della NATO nella sicurezza glo...  -273.778656
# 26                                     什么是量子计算及其潜在应用？  -201.038086
# 27                                  何が日本の茶道の文化的意義ですか？  -285.997925
# 28  Какова роль ЮНЕСКО в сохранении мирового насле...  -278.976532
# 29  What are the cultural implications of the Harl...   -91.594559
# 30  Wie hat die Erfindung des Buchdrucks die Gesel...  -274.393616
# 31     Как влияние ислама на искусство и архитектуру?  -321.123901
# 32                              何がインドの独立運動の主要な要因でしたか？  -361.199585
# 33   Wie beeinflusst die Photosynthese das Ökosystem?  -300.607849
# 34  Qual è l'impatto dell'arte rinascimentale sull...  -307.060852
# 35  한국 사회에서 고령화가 급속히 진행되고 있는 이유와 그에 따른 사회적 영향을 분석하시오.  -455.899689
# 36              한국의 교육열이 학생들의 창의성과 자율성에 미치는 영향을 논하시오.  -302.219208
# 37  How has the COVID-19 pandemic reshaped global ...  -113.842491
# 38  Spiega il concetto di relatività di Einstein e...  -358.020813
# 39         Обясните значение воды для жизни на Земле.  -305.680725
# 40      Qual é o impacto da Amazônia no clima global?  -300.713074
#
#     logp_rejected preferred
# 0     -193.888306    chosen
# 1     -354.578918  rejected
# 2     -161.448914  rejected
# 3     -194.590393  rejected
# 4     -153.615463    chosen
# 5     -325.097717  rejected
# 6     -242.684540  rejected
# 7     -291.581543  rejected
# 8     -227.033783    chosen
# 9     -323.328217  rejected
# 10    -194.432770  rejected
# 11    -199.760559    chosen
# 12    -269.272461  rejected
# 13    -192.725922    chosen
# 14    -312.754852  rejected
# 15    -174.072769  rejected
# 16    -195.473450  rejected
# 17    -245.987915  rejected
# 18    -262.287354    chosen
# 19    -288.086853    chosen
# 20    -304.446198  rejected
# 21    -258.090576  rejected
# 22    -214.191391    chosen
# 23    -254.539825    chosen
# 24    -192.750580  rejected
# 25    -178.200043  rejected
# 26    -143.514618  rejected
# 27    -148.912094  rejected
# 28    -170.756149  rejected
# 29    -269.226349    chosen
# 30    -161.354507  rejected
# 31    -178.108368  rejected
# 32    -190.017212  rejected
# 33    -298.556274  rejected
# 34    -259.479980  rejected
# 35    -266.651062  rejected
# 36    -239.817627  rejected
# 37    -157.174042    chosen
# 38    -187.205002  rejected
# 39    -185.628815  rejected
# 40    -180.793243  rejected

# %%
df_multi_results.preferred.value_counts()
# Out:
# preferred
# rejected    30
# chosen      11
# Name: count, dtype: int64

# %% [markdown]
# 영어랑 독일어? 에 대해서는 안정적으로 잘 판단하는 것 같음.
