# %% [markdown]
# 해당 코드에서 진행한 것:
#
# 1. log likelihood 함수 구현
# 2. 모델별로 test dataset에 대해 log likelihood를 어떻게 평가하는지 알아봄
# 3. wpr / lpr 구하는 함수 구현 (fasttext 이용) -> 아직 작동은 잘 안됨..
# 4. orpo fine tuning 함수 구현 (fine tuning 전 후 결과 평가)\
# -> log likelihood로 평가했을 땐 유의미한 개선점이 있었음 !!!

# %% [markdown]
# log likelihood 계산 함수 (orpo 학습지표)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import torch.nn.functional as F
import json

def compute_log_likelihood(prompt, response, model, tokenizer, device):
    
    prompt_ids = tokenizer(prompt, return_tensors="pt", add_special_tokens=False).input_ids.to(device)
    response_ids = tokenizer(response, return_tensors="pt", add_special_tokens=False).input_ids.to(device)

    input_ids = torch.cat([prompt_ids, response_ids], dim=1)

    with torch.no_grad():
        outputs = model(input_ids=input_ids)
        logits = outputs.logits

    shift_logits = logits[:, :-1, :].contiguous()
    shift_labels = input_ids[:, 1:].contiguous()

    # 📌 mask
    mask = torch.zeros_like(shift_labels)
    mask[:, prompt_ids.size(1) - 1:] = 1

    # 📌 loss
    loss = F.cross_entropy(
        shift_logits.view(-1, shift_logits.size(-1)),
        shift_labels.view(-1),
        reduction='none'
    ).view(shift_labels.size())

    log_prob = -(loss * mask).sum().item()
    return log_prob

# %%
import pandas as pd

def evaluate_orpo_loglikelihood(data, model, tokenizer, device):
    """
    Returns:
        pd.DataFrame: task, lang, log-likelihood, prefer 결과를 담은 DataFrame
    """

    results = []

    for row in data:
        prompt = row["input"]
        chosen = row["chosen"]
        rejected = row["rejected"]

        chosen_ll = compute_log_likelihood(prompt, chosen, model, tokenizer, device)
        rejected_ll = compute_log_likelihood(prompt, rejected, model, tokenizer, device)
        delta_ll = chosen_ll - rejected_ll
        prefer = 1 if delta_ll > 0 else 0

        results.append({
            "task": row["task"],
            "input_lang": row["input_lang"],
            "expected_lang": row["expected_lang"],
            "chosen_ll": chosen_ll,
            "rejected_ll": rejected_ll,
            "delta_ll": delta_ll,
            "prefer": prefer
        })

    return pd.DataFrame(results)

# %% [markdown]
# ### 모델 (baseline)

# %%
# 모델 로딩
checkpoint = "HuggingFaceTB/SmolLM2-135M-intermediate-checkpoints"
revision = "step-240000"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained(checkpoint, revision=revision)
base_model = AutoModelForCausalLM.from_pretrained(checkpoint, revision=revision).to(device)

# %% [markdown]
# #### baseline 평가 (log probability)

# %% [markdown]
# 사용 데이터셋: chatgpt로 수작업 생성한 데이터셋. \
# 컬럼명: input, chosen, rejected, preferred, input_lang, expected_lang, task

# %%
with open("orpo_train_data.json", "r", encoding="utf-8") as f:
    orpo_data = json.load(f)
orpo_data
# Out:
# [{'input': "Was bedeutet 'Realität' in der Philosophie?",
#   'chosen': 'Realität ist das, was unabhängig von Wahrnehmung oder Meinungen existiert.',
#   'rejected': 'Reality ist was 존재해 regardless of perception or 의견.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': "Summarize this passage: 'Plants produce oxygen through photosynthesis. This process is vital for all aerobic life.'",
#   'chosen': 'Plants make oxygen via photosynthesis, which is essential for life that needs air.',
#   'rejected': '식물은 광합성을 통해 oxygen을 만들고, 이것은 생명체에 중요해.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "请翻译：'Time is money.'",
#   'chosen': '时间就是金钱。',
#   'rejected': 'Time 就是 money.',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': "Traduire en français : 'Honesty is the best policy.'",
#   'chosen': "L'honnêteté est la meilleure politique.",
#   'rejected': "L'honnêteté est the best policy.",
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': "Summarize: 'Batteries store energy chemically and release it as electricity. They are essential in many modern devices.'",
#   'chosen': 'Batteries store chemical energy and provide electricity, essential in modern tech.',
#   'rejected': 'Batteries는 에너지를 저장하고 전기를 release합니다. 이것은 modern devices에 중요해.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': '¿Cuál es el objetivo del método científico?',
#   'chosen': 'El método científico busca explicar fenómenos a través de observación, hipótesis y experimentación.',
#   'rejected': 'Scientific método tries to 설명 phenomena through observation y testing.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Korean: 'The weather is nice today.'",
#   'chosen': '오늘 날씨가 좋습니다.',
#   'rejected': '오늘 the 날씨 is good.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'translation'},
#  {'input': "Summarize this passage in Japanese: 'Recycling helps reduce waste. It also saves resources and energy.'",
#   'chosen': 'リサイクルは廃棄物を減らし、資源とエネルギーを節約します。',
#   'rejected': 'Recyclingは waste를 줄이고, resource와 energy를 節約します。',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ja',
#   'task': 'summary'},
#  {'input': "Traduza para o português: 'She is a brilliant scientist.'",
#   'chosen': 'Ela é uma cientista brilhante.',
#   'rejected': 'Ela é a brilliant cientista.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'pt',
#   'task': 'translation'},
#  {'input': '답변해주세요: 지구는 태양 주위를 도는가요?',
#   'chosen': '네, 지구는 태양 주위를 공전합니다.',
#   'rejected': 'Yes, the 지구 orbits the sun.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Was ist eine Demokratie?',
#   'chosen': 'Demokratie ist eine Regierungsform, in der das Volk Macht durch Wahlen ausübt.',
#   'rejected': 'Democracy는 a government system where 국민이 power를 사용한다.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': "Summarize: 'Vaccinations help protect against diseases. They also contribute to herd immunity.'",
#   'chosen': 'Vaccines protect from disease and help achieve herd immunity.',
#   'rejected': 'Vaccines은 disease를 예방하고 herd 면역에 도움이 돼.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "请翻译：'Books are windows to the world.'",
#   'chosen': '书籍是通向世界的窗户。',
#   'rejected': 'Books 是世界的 windows。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': "Traduire en français : 'He speaks multiple languages fluently.'",
#   'chosen': 'Il parle plusieurs langues couramment.',
#   'rejected': 'Il parle 여러 languages fluently.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': "Summarize: 'Economic growth can lead to better living standards. However it may increase inequality.'",
#   'chosen': 'Economic growth improves lives but can raise inequality.',
#   'rejected': '경제 성장은 생활 수준을 향상시키지만 불평등을 increase할 수 있다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': '¿Qué es una célula?',
#   'chosen': 'Una célula es la unidad básica de vida en los organismos.',
#   'rejected': 'A célula es basic life unit en los organisms.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Japanese: 'The city is quiet at night.'",
#   'chosen': '夜の街は静かです。',
#   'rejected': 'The 도시는 quiet입니다 at 夜。',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ja',
#   'task': 'translation'},
#  {'input': "Summarize this passage in Korean: 'Space exploration leads to technological advances. It also inspires scientific curiosity.'",
#   'chosen': '우주 탐사는 기술 발전을 이끌며, 과학적 호기심을 자극합니다.',
#   'rejected': 'Space exploration은 기술 발전을 유도하고 호기심을 inspire합니다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': "Traduza para o português: 'The sun sets in the west.'",
#   'chosen': 'O sol se põe no oeste.',
#   'rejected': 'The sol se põe in the west.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'pt',
#   'task': 'translation'},
#  {'input': '답변해주세요: 물은 왜 끓나요?',
#   'chosen': '물이 끓는 이유는 열에너지가 분자를 빠르게 움직이게 하기 때문입니다.',
#   'rejected': '물 boils because 열 energy makes molecules move fast.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Wie funktioniert ein Verbrennungsmotor?',
#   'chosen': 'Ein Verbrennungsmotor erzeugt Energie durch die Verbrennung von Kraftstoff mit Luft.',
#   'rejected': 'A combustion 모터 works by burning 연료 with air.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': "Summarize: 'Mountains can affect weather patterns. They block air masses and create rainfall.'",
#   'chosen': 'Mountains influence weather by blocking air and causing rain.',
#   'rejected': '산맥은 기후를 바꾸고 air masses를 막아 비를 만든다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': '请总结以下内容：狗是忠诚的动物，能保护主人。它们也常被用于搜救任务。',
#   'chosen': '狗不仅忠诚，还能保护人类并参与搜救任务。',
#   'rejected': 'Dogs are 충성스러운 동물이며 rescue 작업에 사용됩니다。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': "Traduire: 'She always arrives on time.'",
#   'chosen': "Elle arrive toujours à l'heure.",
#   'rejected': 'She arrive toujours on time.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': '¿Cómo se forma un arco iris?',
#   'chosen': 'Un arco iris se forma cuando la luz se refracta y se dispersa en gotas de agua.',
#   'rejected': 'Un rainbow se forma cuando la luz se refracta en 물방울.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Korean: 'My phone battery is low.'",
#   'chosen': '내 휴대폰 배터리가 거의 없습니다.',
#   'rejected': '내 phone 배터리 is 낮음.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'translation'},
#  {'input': "Summarize this in Russian: 'Cats are independent animals. They require less attention than dogs.'",
#   'chosen': 'Кошки — независимые животные, требующие меньше внимания, чем собаки.',
#   'rejected': 'Cats — независимые, need less внимание чем dogs.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ru',
#   'task': 'summary'},
#  {'input': 'Was ist ein schwarzes Loch?',
#   'chosen': 'Ein schwarzes Loch ist ein Bereich im Raum, in dem die Gravitation so stark ist, dass nicht einmal Licht entkommen kann.',
#   'rejected': 'A black hole ist ein Bereich где свет не может выйти.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': "请翻译这句话：'The library is open until 8 PM.'",
#   'chosen': '图书馆营业到晚上八点。',
#   'rejected': '图书馆 is open until 晚上八点。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': '답해주세요: 태풍과 허리케인의 차이는 무엇인가요?',
#   'chosen': '태풍과 허리케인은 같은 현상이지만 발생 지역에 따라 이름이 다릅니다.',
#   'rejected': 'Typhoon and hurricane은 같은 phenomenon인데 지역에 따라 이름이 다릅니다.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': '¿Qué causa el cambio climático?',
#   'chosen': 'El cambio climático es causado principalmente por las emisiones de gases de efecto invernadero.',
#   'rejected': 'Climate change es causado por gases del greenhouse.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Summarize: 'Bees are important pollinators. They help plants reproduce and support ecosystems.'",
#   'chosen': 'Bees pollinate plants and support ecosystems.',
#   'rejected': 'Bees는 식물을 돕고 생태계를 help합니다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "请翻译：'Children need love and support to grow well.'",
#   'chosen': '孩子们需要爱和支持才能健康成长。',
#   'rejected': 'Children 需要 love 和 support 来 grow.',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': "Traduire en français : 'The meeting starts at 10 AM.'",
#   'chosen': 'La réunion commence à 10 heures.',
#   'rejected': 'La meeting commence à dix heures.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': "Summarize: 'The internet has changed how people communicate. It allows instant sharing of information.'",
#   'chosen': 'The internet transformed communication and enables instant info sharing.',
#   'rejected': '인터넷은 communication 방식을 바꾸고 정보를 즉시 공유할 수 있다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': 'Was ist die Hauptstadt von Österreich?',
#   'chosen': 'Die Hauptstadt von Österreich ist Wien.',
#   'rejected': 'The Hauptstadt von Austria ist Vienna.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Arabic: 'This dish is very spicy.'",
#   'chosen': 'هذا الطبق حار جدًا.',
#   'rejected': 'This الطبق is very hot.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ar',
#   'task': 'translation'},
#  {'input': "Summarize this in Japanese: 'Libraries offer free access to knowledge. They are vital for education.'",
#   'chosen': '図書館は知識への無料アクセスを提供し、教育に不可欠です。',
#   'rejected': 'Libraries는 知識을 무료로 제공하고 교육에 필요합니다。',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ja',
#   'task': 'summary'},
#  {'input': '¿Cuál es la función de los pulmones?',
#   'chosen': 'Los pulmones permiten el intercambio de oxígeno y dióxido de carbono en el cuerpo.',
#   'rejected': 'Los lungs ayudan con el exchange de gases.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Korean: 'I forgot my umbrella at home.'",
#   'chosen': '집에 우산을 두고 왔어요.',
#   'rejected': 'I 우산을 집에 forgot 했어요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'translation'},
#  {'input': 'Was ist ein Algorithmus?',
#   'chosen': 'Ein Algorithmus ist eine Abfolge von Anweisungen zur Lösung eines Problems.',
#   'rejected': 'Algorithmus ist steps zur Lösung a 문제.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': "Summarize this in Russian: 'The brain controls the body's functions. It also processes information from the senses.'",
#   'chosen': 'Мозг управляет функциями тела и обрабатывает сенсорную информацию.',
#   'rejected': 'Мозг controls тело и processes sensory 정보.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ru',
#   'task': 'summary'},
#  {'input': "请翻译：'He lives on the third floor.'",
#   'chosen': '他住在三楼。',
#   'rejected': 'He 住在 the 三楼。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': "Traduire: 'We have a lot of work to do today.'",
#   'chosen': "Nous avons beaucoup de travail à faire aujourd'hui.",
#   'rejected': 'Nous avons many travail today.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': '¿Cómo funciona un imán?',
#   'chosen': 'Un imán atrae objetos hechos de ciertos metales mediante campos magnéticos.',
#   'rejected': 'Un magnet atrae objetos con magnetic campos.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Portuguese: 'I need to charge my laptop.'",
#   'chosen': 'Preciso carregar meu laptop.',
#   'rejected': 'Eu preciso charge meu laptop.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'pt',
#   'task': 'translation'},
#  {'input': "Summarize in Korean: 'Volcanoes can create new land. They also release gases into the atmosphere.'",
#   'chosen': '화산은 새로운 지형을 만들고 대기 중에 가스를 방출합니다.',
#   'rejected': 'Volcano는 새 땅을 만들고 atmosphere에 가스를 release합니다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'Wie nennt man ein Tier, das nur Pflanzen frisst?',
#   'chosen': 'Ein solches Tier nennt man Pflanzenfresser oder Herbivor.',
#   'rejected': 'Das Tier ist a plant eater 혹은 Herbivore.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': '请总结：太阳为地球提供光和热，是生命存在的关键因素。它的活动也会影响地球的气候。',
#   'chosen': '太阳提供光和热，并影响气候，是生命的重要来源。',
#   'rejected': 'The sun 提供 光 和 heat，并对 climate 有影响。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': "Traduire: 'This room is too small for a party.'",
#   'chosen': 'Cette pièce est trop petite pour une fête.',
#   'rejected': 'Cette room est very petite pour party.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': '¿Qué hace un médico?',
#   'chosen': 'Un médico diagnostica y trata enfermedades para mejorar la salud del paciente.',
#   'rejected': 'Un doctor cura enfermedades y patient health mejora.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Japanese: 'He bought a new car yesterday.'",
#   'chosen': '彼は昨日新しい車を買いました。',
#   'rejected': 'He は昨日 new 車를 買いました。',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ja',
#   'task': 'translation'},
#  {'input': "Summarize: 'Forests absorb carbon dioxide. They play a key role in fighting climate change.'",
#   'chosen': 'Forests absorb CO2 and help combat climate change.',
#   'rejected': 'Forests는 CO2를 흡수하고 기후변화에 도움이 된다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': 'Was ist ein Atom?',
#   'chosen': 'Ein Atom ist die kleinste Einheit der Materie, die chemische Eigenschaften besitzt.',
#   'rejected': 'Ein Atom ist klein Teilchen mit chemischen properties.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': "请翻译：'I will call you later.'",
#   'chosen': '我稍后会给你打电话。',
#   'rejected': '我 will 给你 call later。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': "Translate into Arabic: 'My brother is a teacher.'",
#   'chosen': 'أخي معلم.',
#   'rejected': 'My أخ هو teacher.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ar',
#   'task': 'translation'},
#  {'input': "Summarize this in Korean: 'Rain helps water the crops. It is essential for agriculture.'",
#   'chosen': '비는 작물을 자라게 하며 농업에 필수적입니다.',
#   'rejected': '비는 crops에 도움이 되고 agriculture에 중요하다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': '¿Qué estudia la biología?',
#   'chosen': 'La biología estudia los seres vivos y sus procesos vitales.',
#   'rejected': 'Biología estudia living things y how they function.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Traduza para o português: 'This book is interesting.'",
#   'chosen': 'Este livro é interessante.',
#   'rejected': 'Este book é very interessante.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'pt',
#   'task': 'translation'},
#  {'input': "Summarize: 'Exercise improves physical health. It also boosts mental well-being.'",
#   'chosen': 'Exercise benefits both body and mind.',
#   'rejected': 'Exercise는 몸과 정신에 good하다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': 'Wie funktioniert ein Magnet?',
#   'chosen': 'Ein Magnet erzeugt ein unsichtbares Kraftfeld, das bestimmte Materialien anzieht.',
#   'rejected': 'A Magnet creates an invisible 힘 field that pulls 물질.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': 'Describe what makes elephants unique among animals.',
#   'chosen': 'Elephants are known for their intelligence, memory, and long trunks.',
#   'rejected': 'Elephants는 똑똑하고 기억력이 좋고 trunk가 길다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '请解释什么是气候变化。',
#   'chosen': '气候变化是指全球气温和天气模式的长期变化。',
#   'rejected': 'Climate change 是全球温度和 weather pattern 的变动。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Expliquez pourquoi les feuilles changent de couleur en automne.',
#   'chosen': 'Les feuilles changent de couleur à cause de la réduction de la lumière du jour et des températures plus basses.',
#   'rejected': 'Leaves changent de couleur parce que lumière et temps froid.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': 'Elabora brevemente sobre la importancia del agua potable.',
#   'chosen': 'El agua potable es esencial para la salud humana y previene enfermedades.',
#   'rejected': 'Potable water es importante para salud y prevenir illness.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': '오늘의 날씨에 대해 알려줘.',
#   'chosen': '오늘은 맑고 기온은 약 22도입니다.',
#   'rejected': 'Today 날씨는 clear하고 temperature는 around 22도야.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'What is the role of mitochondria in a cell?',
#   'chosen': 'Mitochondria produce energy by converting nutrients into ATP.',
#   'rejected': 'Mitochondria는 영양소를 ATP로 convert해서 energy를 만든다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': 'Warum ist Recycling wichtig?',
#   'chosen': 'Recycling hilft, Ressourcen zu schonen und Abfall zu reduzieren.',
#   'rejected': 'Recycling hilft to save 자원 und reduce 쓰레기.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': '당신의 취미는 무엇인가요?',
#   'chosen': '저는 독서와 산책을 즐깁니다.',
#   'rejected': 'I enjoy reading하고 걷는 걸 좋아해요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': '¿Por qué necesitamos dormir?',
#   'chosen': 'Dormir es esencial para la recuperación física y mental.',
#   'rejected': 'Sleep es importante para cuerpo y mente recuperar.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': 'Describe the main causes of traffic congestion.',
#   'chosen': 'Traffic congestion is caused by high vehicle volume, accidents, and poor traffic management.',
#   'rejected': '교통 체증은 자동차가 많고 사고와 traffic 관리 부족 때문에 생긴다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': "Explique ce qu'est une étoile filante.",
#   'chosen': "Une étoile filante est un météore qui brûle en entrant dans l'atmosphère terrestre.",
#   'rejected': 'A shooting star est un meteor que brille en atmosphere.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': '请问海洋对地球有什么重要作用？',
#   'chosen': '海洋调节气候，提供氧气，并支持海洋生物的多样性。',
#   'rejected': 'Ocean 调节 climate 和 support 생물 diversity。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Apakah manfaat olahraga bagi kesehatan?',
#   'chosen': 'Olahraga meningkatkan kebugaran tubuh dan kesehatan mental.',
#   'rejected': 'Exercise membantu tubuh 건강 dan mental menjadi baik.',
#   'preferred': 1,
#   'input_lang': 'id',
#   'expected_lang': 'id',
#   'task': 'single_language_qa'},
#  {'input': "Translate 'My favorite food is pizza' to Korean.",
#   'chosen': '내가 가장 좋아하는 음식은 피자야.',
#   'rejected': 'My favorite 음식은 피자입니다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'translation'},
#  {'input': '她每天早上都去跑步。请把这句话翻成英文。',
#   'chosen': 'She goes jogging every morning.',
#   'rejected': 'She 每天 morning 跑步。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'en',
#   'task': 'translation'},
#  {'input': 'Quelle heure est-il maintenant? Répondez en allemand.',
#   'chosen': 'Es ist jetzt drei Uhr nachmittags.',
#   'rejected': 'It is drei Uhr jetzt.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'de',
#   'task': 'translation'},
#  {'input': '나는 매주 금요일에 친구들과 영화를 봐. 영어로 번역해줘.',
#   'chosen': 'I watch movies with my friends every Friday.',
#   'rejected': 'I 매주 Friday에 친구들과 영화 봐요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'en',
#   'task': 'translation'},
#  {'input': 'Me gusta leer novelas históricas. Traduce esto al francés.',
#   'chosen': "J'aime lire des romans historiques.",
#   'rejected': "J'aime lire historical novels.",
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': "Summarize this: 'Birds migrate in response to seasonal changes. Migration helps them find food and better living conditions.'",
#   'chosen': 'Birds migrate due to seasons to find food and better habitats.',
#   'rejected': '새들은 계절 변화에 따라 이동하며 food와 habitat을 찾는다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': '总结以下内容：许多动物在夜间活动，以避开白天的高温和捕食者。',
#   'chosen': '一些动物为了躲避高温和天敌，会在夜间出来活动。',
#   'rejected': 'Animals 활동 at night to avoid hot weather와 predators。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': "Les volcans peuvent causer des dommages considérables lorsqu'ils entrent en éruption. Ils peuvent également enrichir les sols.",
#   'chosen': 'Les volcans peuvent être destructeurs mais enrichissent aussi les sols.',
#   'rejected': 'Volcanoes sont destructifs mais make les sols meilleurs.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'summary'},
#  {'input': 'Describe what happens when water boils and turns into steam.',
#   'chosen': 'When water boils, it changes from liquid to gas, forming steam.',
#   'rejected': '물이 끓으면 물이 gas로 change되고 steam이 생긴다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "요약해줘: '사막은 낮에는 매우 덥고, 밤에는 매우 추운 기후를 가진다. 물의 저장과 생존이 어려운 환경이다.'",
#   'chosen': '사막은 기온 차가 크고, 생존에 어려운 환경이다.',
#   'rejected': 'Desert는 hot하고 cold하고 물이 부족한 환경이야.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': "요약: '태풍은 강한 바람과 비를 동반하며, 큰 피해를 줄 수 있다. 해안 지역에서 특히 위험하다.'",
#   'chosen': '태풍은 강풍과 폭우로 인해 해안 지역에 큰 피해를 줄 수 있다.',
#   'rejected': 'Typhoon은 big damage를 줄 수 있고 특히 coastal area에서 위험해.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'Los plásticos de un solo uso están contaminando los océanos. Muchos animales marinos los confunden con comida.',
#   'chosen': 'Los plásticos causan gran daño a los océanos y la vida marina.',
#   'rejected': "Plastic hace daño al océano y animales think it's comida.",
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'summary'},
#  {'input': 'Explain how the digestive system works in simple terms.',
#   'chosen': 'The digestive system breaks down food and absorbs nutrients into the body.',
#   'rejected': '소화기관은 음식물을 breakdown하고 영양소를 absorb한다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "请你用中文概括以下内容：'全球变暖会导致海平面上升，影响沿海城市的安全。'",
#   'chosen': '全球变暖会使海平面上升，威胁沿海城市。',
#   'rejected': 'Global warming 导致海平面上升和 coastal cities 危险。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': 'Pourquoi est-ce que les gens voyagent ?',
#   'chosen': 'Les gens voyagent pour découvrir de nouvelles cultures, se détendre ou travailler.',
#   'rejected': 'People voyagent to relax, explore cultures, ou work.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': '너는 왜 수면이 중요한지 설명할 수 있어?',
#   'chosen': '수면은 신체 회복과 두뇌 기능 향상에 필수적입니다.',
#   'rejected': 'Sleep은 body 회복과 brain function 향상에 좋아요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Wie beeinflusst Musik unsere Emotionen?',
#   'chosen': 'Musik kann starke emotionale Reaktionen hervorrufen, wie Freude oder Traurigkeit.',
#   'rejected': 'Musik makes Leute feel 기쁨 또는 sadness emotions.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': 'Explain why rainbows form in the sky.',
#   'chosen': 'Rainbows form when sunlight refracts and reflects through water droplets.',
#   'rejected': '무지개는 빛이 water droplets를 통과할 때 생기고 reflect도 한다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '请问狗为什么会摇尾巴？',
#   'chosen': '狗摇尾巴是为了表达情绪，比如快乐或激动。',
#   'rejected': 'Dogs 摇尾巴 when they feel happy或者 excited。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Pourquoi les feuilles tombent-elles en automne ?',
#   'chosen': 'Les feuilles tombent en automne à cause de la réduction de la lumière et des températures.',
#   'rejected': 'Leaves tombent à cause de moins light et cold temps.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': 'El agua hierve a 100 grados Celsius. ¿Esto es cierto?',
#   'chosen': 'Sí, el agua hierve a 100 grados Celsius a nivel del mar.',
#   'rejected': 'Yes, agua boils at 백도 when at sea level.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': '오늘 하루 중 가장 좋아하는 시간대는 언제인가요?',
#   'chosen': '저는 해 질 무렵이 가장 좋아요. 하루가 차분해지거든요.',
#   'rejected': 'I like 저녁 때 the best because 하루가 calm해요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Why is the ocean salty?',
#   'chosen': 'Salt in the ocean comes from rocks on land and underwater volcanic activity.',
#   'rejected': 'Ocean은 salt를 포함하는데 그것은 rocks와 화산에서 나와요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': 'Was ist die Funktion eines Blattes bei einer Pflanze?',
#   'chosen': 'Blätter betreiben Photosynthese und versorgen die Pflanze mit Energie.',
#   'rejected': 'Leaves machen Photosynthese und give 에너지 to the plant.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': '你平常喜欢做什么活动来放松？',
#   'chosen': '我喜欢听音乐和散步来放松自己。',
#   'rejected': 'I 放松 by 음악 듣고 산책하기。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Pourquoi les gens ont-ils besoin d’amis ?',
#   'chosen': 'Les amis offrent du soutien émotionnel et rendent la vie plus agréable.',
#   'rejected': 'Friends provide 감정 support et la vie est plus happy.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Korean: 'She studies hard every day.'",
#   'chosen': '그녀는 매일 열심히 공부해요.',
#   'rejected': 'She 매일 열심히 study합니다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'translation'},
#  {'input': "Traduz isto para espanhol: 'We are going to the beach tomorrow.'",
#   'chosen': 'Vamos a la playa mañana.',
#   'rejected': 'We vamos to playa mañana.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'es',
#   'task': 'translation'},
#  {'input': "Bitte übersetzen Sie ins Französische: 'My house is near the park.'",
#   'chosen': 'Ma maison est près du parc.',
#   'rejected': 'My maison est near le parc.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': "Traduza para o português: 'The children are playing in the garden.'",
#   'chosen': 'As crianças estão brincando no jardim.',
#   'rejected': 'The crianças estão playing no jardim.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'pt',
#   'task': 'translation'},
#  {'input': "Traduire en japonais : 'It’s a beautiful day today.'",
#   'chosen': '今日はとてもいい天気です。',
#   'rejected': 'Today は beautiful 날입니다。',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'ja',
#   'task': 'translation'},
#  {'input': '영어로 번역해줘: 나는 자전거 타는 걸 좋아해.',
#   'chosen': 'I like riding my bicycle.',
#   'rejected': 'I 자전거 타는 걸 like해요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'en',
#   'task': 'translation'},
#  {'input': '请把这句话翻成英文：我正在写作业。',
#   'chosen': 'I am doing my homework.',
#   'rejected': 'I 正在 write homework。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'en',
#   'task': 'translation'},
#  {'input': "Übersetze ins Deutsche: 'He always helps his friends.'",
#   'chosen': 'Er hilft seinen Freunden immer.',
#   'rejected': 'He hilft seinen 친구들 항상.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'de',
#   'task': 'translation'},
#  {'input': "En français, s’il vous plaît : 'The coffee is too hot.'",
#   'chosen': 'Le café est trop chaud.',
#   'rejected': 'Le coffee est très hot.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': 'Summarize the paragraph about how forests contribute to the ecosystem.',
#   'chosen': 'Forests support biodiversity and regulate climate by storing carbon.',
#   'rejected': '숲은 다양성과 기후를 support하고 carbon을 저장해요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "다음 글의 요점을 말해줘: '도시는 많은 사람들의 삶의 터전이자 문화의 중심지이다.'",
#   'chosen': '도시는 인구가 밀집된 생활 및 문화 중심지다.',
#   'rejected': 'The city is a life place and 문화 center이다.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'Resuma brevemente el texto sobre la importancia de reciclar.',
#   'chosen': 'El reciclaje reduce la contaminación y conserva recursos naturales.',
#   'rejected': 'Reciclar ayuda con pollution y save materiales naturales.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'summary'},
#  {'input': 'Expliquez l’idée principale de ce texte sur les énergies renouvelables.',
#   'chosen': 'Les énergies renouvelables sont essentielles pour réduire les émissions et préserver l’environnement.',
#   'rejected': 'Renewable energy aide à réduire émissions et sauver la planète.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'summary'},
#  {'input': '请你总结一下这篇关于空气污染的文章。',
#   'chosen': '空气污染对健康有害，应采取措施减少排放。',
#   'rejected': 'Air pollution 是不好 for 건강，所以 need 减少 it。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': "Summarize the following: 'Space exploration leads to scientific discoveries and inspires innovation in technology.'",
#   'chosen': 'Space exploration drives science and technology innovation.',
#   'rejected': 'Space 연구는 tech과 science에 inspiration을 줘요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': 'Por favor, resuma o trecho sobre a história da fotografia.',
#   'chosen': 'A fotografia evoluiu de técnicas simples para métodos digitais modernos.',
#   'rejected': 'Photography 시작했다 simple e now é muito digitalizado.',
#   'preferred': 1,
#   'input_lang': 'pt',
#   'expected_lang': 'pt',
#   'task': 'summary'},
#  {'input': 'Was können wir aus dem Text über soziale Medien lernen?',
#   'chosen': 'Soziale Medien verändern Kommunikation und beeinflussen Meinungen.',
#   'rejected': "Social media change communication und people's 생각에 영향 줘요.",
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'summary'},
#  {'input': 'Summarize the text about animal migration.',
#   'chosen': 'Animal migration happens due to food needs or climate changes.',
#   'rejected': '동물은 음식 찾거나 기후 변화 때문에 이동해요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': '请简述这篇关于地震预警系统的内容。',
#   'chosen': '地震预警系统能提前几秒提醒人们避难，减少伤亡。',
#   'rejected': 'Earthquake warning 给人们几秒来 escape 和 protect自己。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': "Translate to Arabic: 'The train arrives at 6 PM.'",
#   'chosen': 'يصل القطار في الساعة السادسة مساءً.',
#   'rejected': 'The القطار arrives at ستة PM.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ar',
#   'task': 'translation'},
#  {'input': "请把 'I miss my hometown' 翻译成中文。",
#   'chosen': '我想念我的家乡。',
#   'rejected': 'I 想念 my 家乡。',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': "Traduisez ceci en italien : 'We met at the museum last weekend.'",
#   'chosen': 'Ci siamo incontrati al museo lo scorso fine settimana.',
#   'rejected': 'We abbiamo incontrato al museum la scorsa week.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'it',
#   'task': 'translation'},
#  {'input': "Traduza esta frase para o espanhol: 'My suitcase is heavy.'",
#   'chosen': 'Mi maleta es pesada.',
#   'rejected': 'Minha suitcase es pesada.',
#   'preferred': 1,
#   'input_lang': 'pt',
#   'expected_lang': 'es',
#   'task': 'translation'},
#  {'input': 'Ich möchte wissen, wie Pflanzen wachsen.',
#   'chosen': 'Pflanzen wachsen durch Photosynthese, Wasser und Sonnenlicht.',
#   'rejected': 'Plants wachsen with 물, sun, und Photosynthese.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': '당신의 집은 어떤 모습인가요?',
#   'chosen': '제 집은 작지만 아늑하고 창문이 많아요.',
#   'rejected': 'My 집은 small하고 cozy하고 창문이 많아.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Comment fonctionne un panneau solaire ?',
#   'chosen': 'Un panneau solaire convertit la lumière du soleil en électricité.',
#   'rejected': 'Solar panel fait le sun en électricité.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': '请问猫晚上为什么更活跃？',
#   'chosen': '猫在晚上更活跃是因为它们是夜行性动物。',
#   'rejected': 'Cats 在晚上 active 因为 night animals。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Why do leaves turn red and yellow in autumn?',
#   'chosen': 'Leaves change color due to the breakdown of chlorophyll and the presence of other pigments.',
#   'rejected': '잎은 green 색이 없어지고 다른 pigment 때문에 노랗고 빨개진다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '¿Cómo afecta la contaminación del aire a los seres humanos?',
#   'chosen': 'Puede causar problemas respiratorios y enfermedades cardiovasculares.',
#   'rejected': 'Aire pollution causa lung issues y enfermedades en el corazón.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': '오늘 날씨는 어때요?',
#   'chosen': '오늘은 흐리고 비가 조금 올 예정이에요.',
#   'rejected': 'Today는 cloudy하고 비 a little 올 거예요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Explain what gravity is in simple terms.',
#   'chosen': 'Gravity is the force that pulls objects toward each other.',
#   'rejected': 'Gravity는 things를 서로 끌어당기는 force야.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': 'Pourquoi la mer est-elle bleue ?',
#   'chosen': "La mer est bleue car elle reflète la couleur du ciel et absorbe d'autres longueurs d'onde.",
#   'rejected': 'Mer est bleue parce que sky 색깔 est réfléchie.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': '请用英文解释一下长颈鹿为什么有长脖子。',
#   'chosen': 'Giraffes have long necks to reach leaves on tall trees.',
#   'rejected': 'Giraffes의 long necks는 tall trees의 leaves를 reach하기 위해서이다。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': 'Wie entsteht ein Erdbeben?',
#   'chosen': 'Ein Erdbeben entsteht durch plötzliche Bewegungen der Erdplatten.',
#   'rejected': 'Earthquake entsteht wenn Erde plates suddenly move.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': '당신이 좋아하는 계절은 무엇인가요?',
#   'chosen': '저는 봄을 가장 좋아해요. 날씨가 따뜻하고 꽃이 피니까요.',
#   'rejected': 'I like 봄 the best because 날씨가 따뜻하고 flowers bloom해요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Wie beeinflusst der Klimawandel die globale Landwirtschaft langfristig?',
#   'chosen': 'Der Klimawandel kann Ernteausfälle verursachen und landwirtschaftliche Zonen verändern.',
#   'rejected': 'Climate change macht farming areas move und crops failen manchmal.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': 'What is the function of neurons in the human nervous system?',
#   'chosen': 'Neurons transmit electrical signals throughout the body to coordinate functions.',
#   'rejected': '뉴런은 전기 신호를 body 전체로 보내서 움직임을 coordinate한다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '请解释基因突变对生物体可能产生的影响。',
#   'chosen': '基因突变可能导致性状变化，有时还会引发疾病。',
#   'rejected': 'Gene mutation 会导致 trait 变化，或者 illness 出现。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Pourquoi la biodiversité est-elle cruciale pour les écosystèmes ?',
#   'chosen': "La biodiversité maintient l'équilibre écologique et renforce la résilience des écosystèmes.",
#   'rejected': 'Biodiversité aide balance et ecosystems deviennent plus strong.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': '¿Qué función cumplen los anticuerpos en el sistema inmunológico?',
#   'chosen': 'Los anticuerpos reconocen y neutralizan agentes patógenos como virus y bacterias.',
#   'rejected': 'Anticuerpos detect virus y bacteria y fight con ellos.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': '최근 등장한 인공지능 언어모델은 어떻게 작동하나요?',
#   'chosen': '언어모델은 대규모 텍스트 데이터를 학습해 문맥을 이해하고 문장을 생성합니다.',
#   'rejected': 'Language 모델은 text를 많이 보고 문장을 make할 수 있게 된다.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'single_language_qa'},
#  {'input': 'Explain how photosynthesis contributes to the carbon cycle.',
#   'chosen': 'Photosynthesis absorbs carbon dioxide and converts it into organic compounds in plants.',
#   'rejected': '광합성은 CO2를 흡수하고 식물 안에서 carbon을 organic things로 만든다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': 'Was versteht man unter einem schwarzen Loch in der Astrophysik?',
#   'chosen': 'Ein schwarzes Loch ist ein Objekt mit extrem starker Gravitation, aus dem nichts entweichen kann.',
#   'rejected': 'A black Loch ist so strong, dass light도 나갈 수 없어.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': '请问什么是人工智能中的深度学习？',
#   'chosen': '深度学习是一种使用多层神经网络来自动提取数据特征的人工智能方法。',
#   'rejected': 'Deep learning 是用很多 neural network 层来学习的 AI 技术。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Comment fonctionne le système digestif humain ?',
#   'chosen': 'Le système digestif décompose les aliments pour absorber les nutriments nécessaires au corps.',
#   'rejected': 'Système digestif fait food en petits morceaux pour nutrition.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Korean: 'She conducted an experiment to test her hypothesis.'",
#   'chosen': '그녀는 자신의 가설을 검증하기 위해 실험을 진행했어요.',
#   'rejected': 'She 가설을 test하기 위해 experiment을 했어요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ko',
#   'task': 'translation'},
#  {'input': "Traduz esta frase para o espanhol: 'This algorithm improves the model’s accuracy.'",
#   'chosen': 'Este algoritmo mejora la precisión del modelo.',
#   'rejected': 'Este algorithm hace el model más 정확.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'es',
#   'task': 'translation'},
#  {'input': "Übersetze ins Französische: 'The vaccine was developed after several clinical trials.'",
#   'chosen': 'Le vaccin a été développé après plusieurs essais cliniques.',
#   'rejected': 'Le vaccine est fait après clinical tests.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': "Traduza para o português: 'Digital currencies are reshaping the global economy.'",
#   'chosen': 'As moedas digitais estão transformando a economia global.',
#   'rejected': 'Digital currencies mudam a economia do mundo.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'pt',
#   'task': 'translation'},
#  {'input': "Traduisez cette phrase en japonais : 'Cell division is essential for growth and repair.'",
#   'chosen': '細胞分裂は成長と修復に不可欠です。',
#   'rejected': 'Cell 분열은 grow와 fix 위해 중요합니다。',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'ja',
#   'task': 'translation'},
#  {'input': '영어로 번역해줘: 인간의 뇌는 약 천억 개의 뉴런으로 이루어져 있어.',
#   'chosen': 'The human brain is made up of about 100 billion neurons.',
#   'rejected': 'Human brain은 약 백 billion 뉴런으로 구성돼.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'en',
#   'task': 'translation'},
#  {'input': "请将这句话翻译成英文：'科学技术不断推动社会进步。'",
#   'chosen': 'Science and technology continuously drive societal progress.',
#   'rejected': 'Science와 기술은 사회를 계속 발전시킨다。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'en',
#   'task': 'translation'},
#  {'input': "Traduzir para o alemão: 'The internet allows for instant global communication.'",
#   'chosen': 'Das Internet ermöglicht sofortige weltweite Kommunikation.',
#   'rejected': 'Internet macht sofort globalen 커뮤니케이션 möglich.',
#   'preferred': 1,
#   'input_lang': 'pt',
#   'expected_lang': 'de',
#   'task': 'translation'},
#  {'input': "Traduisez en français : 'Artificial intelligence is advancing rapidly.'",
#   'chosen': "L'intelligence artificielle progresse rapidement.",
#   'rejected': 'AI avance très fast maintenant.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': 'Summarize the article about renewable energy innovations.',
#   'chosen': 'The article explains recent advances in solar and wind technologies to promote sustainability.',
#   'rejected': '이 글은 태양광과 풍력의 new 기술이 환경에 좋은 걸 설명한다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "다음 글에서 핵심 내용을 정리해줘: '기후 변화는 해수면 상승, 생태계 변화, 그리고 극한 기상 현상의 증가를 초래하고 있다.'",
#   'chosen': '기후 변화는 해수면 상승과 극단적 기후 현상을 유발한다.',
#   'rejected': '기후 변화는 바다 높아지고 날씨 extreme해진다.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'Por favor, resuma o trecho sobre os benefícios da leitura frequente.',
#   'chosen': 'A leitura frequente melhora o vocabulário, a concentração e o pensamento crítico.',
#   'rejected': 'Reading 많이 ajuda palavra 늘리고 생각 잘하게 된다.',
#   'preferred': 1,
#   'input_lang': 'pt',
#   'expected_lang': 'pt',
#   'task': 'summary'},
#  {'input': '请总结本文关于5G技术对社会的影响。',
#   'chosen': '5G技术提升通信速度，并推动远程医疗和智慧城市发展。',
#   'rejected': '5G 让网络快而且对 medical 和 city 有帮助。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': 'Faites un résumé du texte sur les conséquences de la pollution plastique.',
#   'chosen': 'La pollution plastique nuit aux océans, à la faune et à la santé humaine.',
#   'rejected': 'Pollution plastique hurt ocean, animaux et health des gens.',
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'summary'},
#  {'input': 'Summarize the passage discussing blockchain applications in finance.',
#   'chosen': 'Blockchain enhances transparency, reduces fraud, and improves transaction efficiency.',
#   'rejected': '블록체인은 거래를 빠르고 안전하게 만들며 투명성을 높여준다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': "요약해줘: '인공지능은 진단 정확도를 높이고 환자 맞춤 치료를 가능하게 한다.'",
#   'chosen': 'AI는 의료의 정밀성과 개인화된 치료를 향상시킨다.',
#   'rejected': 'AI는 treatment 맞춤화와 정확한 진단을 가능하게 한다.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'Bitte fassen Sie den Text über erneuerbare Energiequellen zusammen.',
#   'chosen': 'Erneuerbare Energien sind sauber, nachhaltig und wichtig für die Zukunft.',
#   'rejected': 'Renewable energy ist sauber und für unsere future sehr wichtig.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'summary'},
#  {'input': '请你简要总结该文章对人工智能伦理的讨论。',
#   'chosen': '文章讨论了AI决策透明性、公平性和数据隐私的重要性。',
#   'rejected': 'AI文章讲了 fairness, 투명도 和 프라이버시的问题。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': 'Explain why quantum computing is considered revolutionary in tech.',
#   'chosen': 'Quantum computing enables solving complex problems much faster than classical computers.',
#   'rejected': '양자컴퓨팅은 문제를 classical보다 훨씬 빠르게 푸는 기술이다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '请问DNA是如何在细胞中复制的？',
#   'chosen': 'DNA复制通过酶的作用将双链分开并形成新链。',
#   'rejected': 'DNA 복제是 두 줄 split 并 build new line with enzymes。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'What is the difference between supervised and unsupervised learning in AI?',
#   'chosen': 'Supervised learning uses labeled data, while unsupervised learning identifies patterns in unlabeled data.',
#   'rejected': 'Supervised는 라벨된 데이터로 학습하고 unsupervised는 패턴을 찾는다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': 'Explain how convolutional neural networks process visual data.',
#   'chosen': 'Convolutional neural networks detect patterns in images through layers of filters and pooling.',
#   'rejected': 'CNN은 image에서 패턴을 찾기 위해 필터와 풀링을 사용한다.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '请解释什么是强化学习。',
#   'chosen': '强化学习是一种通过奖励机制来训练智能体优化行为的机器学习方法。',
#   'rejected': 'Reinforcement learning 是 AI 学习好行为通过 rewards。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': 'Wie funktionieren Neuronen in künstlichen neuronalen Netzwerken?',
#   'chosen': 'Künstliche Neuronen empfangen Eingaben, berechnen eine gewichtete Summe und geben ein Signal weiter.',
#   'rejected': 'Neurons in AI bekommen input, 계산하고 send signal.',
#   'preferred': 1,
#   'input_lang': 'de',
#   'expected_lang': 'de',
#   'task': 'single_language_qa'},
#  {'input': 'Apakah perbedaan antara blockchain dan database tradisional?',
#   'chosen': 'Blockchain bersifat terdesentralisasi dan data disimpan dalam blok yang saling terhubung.',
#   'rejected': 'Blockchain tidak seperti 일반 database, data ada di 블록 dan 공유된다.',
#   'preferred': 1,
#   'input_lang': 'id',
#   'expected_lang': 'id',
#   'task': 'single_language_qa'},
# ...
#   'rejected': "L'utilisation excessive des réseaux sociaux peut entraîner de l'anxiété, de la dépression et une faible estime de soi. Pour atténuer ces effets, il faut limiter l'utilisation, s'engager dans des activités hors ligne et pratiquer la pleine conscience.",
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': "请翻译：'The philosophy of existentialism emphasizes individual freedom and the search for meaning in life.'",
#   'chosen': '存在主义哲学强调个人的自由和对生命意义的探索.',
#   'rejected': "La philosophie de l'existentialisme met l'accent sur la liberté individuelle et la recherche de sens dans la vie.",
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'zh',
#   'task': 'translation'},
#  {'input': '¿Cuál es el impacto de la globalización en las economías locales, y cómo pueden las comunidades adaptarse a estos cambios?',
#   'chosen': 'La globalización puede beneficiar a las economías locales al abrir nuevos mercados, pero también puede desplazar industrias tradicionales. Las comunidades pueden adaptarse diversificando sus economías, invirtiendo en educación y promoviendo empresas locales.',
#   'rejected': 'Globalization can benefit local economies by opening new markets, but it can also displace traditional industries. Communities can adapt by diversifying their economies, investing in education, and promoting local businesses.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Summarize this: 'The study of neuroscience has revealed how the brain processes emotions, makes decisions, and forms memories. This knowledge has applications in psychology, medicine, and artificial intelligence.'",
#   'chosen': 'Neuroscience research has shown how the brain processes emotions, makes decisions, and forms memories, with applications in psychology, medicine, and AI.',
#   'rejected': 'La recherche en neurosciences a révélé comment le cerveau traite les émotions, prend des décisions et forme des souvenirs, avec des applications en psychologie, médecine et IA.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'summary'},
#  {'input': '请问什么是可持续发展，它为什么重要？',
#   'chosen': '可持续发展是指在满足当前需求的同时，不损害未来世代满足其需求的能力. 它通过平衡经济、社会和环境目标，确保长期繁荣和生态健康.',
#   'rejected': 'Sustainable development meets current needs without compromising the ability of future generations to meet theirs. It balances economic, social, and environmental goals to ensure long-term prosperity and ecological health.',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'single_language_qa'},
#  {'input': "Translate into French: 'He is passionate about environmental conservation and volunteers at local clean-up events.'",
#   'chosen': "Il est passionné par la conservation de l'environnement et participe à des événements de nettoyage locaux.",
#   'rejected': 'Er ist leidenschaftlich für Umweltschutz und volontiert bei lokalen Aufräumaktionen.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': '요약해줘: 인공지능은 교육 분야에서 개인 맞춤형 학습 경험을 제공하고, 학생들의 학습 속도와 스타일에 맞춰 콘텐츠를 조정한다. 그러나 데이터 프라이버시와 알고리즘 편향 등 윤리적 문제도 존재한다.',
#   'chosen': '인공지능은 교육에서 개인 맞춤형 학습 경험을 제공하고 학생들의 학습 속도와 스타일에 맞춰 콘텐츠를 조정한다. 그러나 데이터 프라이버시와 알고리즘 편향 등 윤리적 문제가 존재한다.',
#   'rejected': "AI provides personalized learning experiences in education, adjusting content to students' pace and style. However, it raises ethical issues like data privacy and algorithmic bias.",
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'What are the benefits of practicing mindfulness, and how can one incorporate it into daily life?',
#   'chosen': 'Mindfulness reduces stress, improves focus, and enhances emotional well-being. It can be incorporated into daily life through activities like meditation, deep breathing exercises, and mindful walking.',
#   'rejected': 'La pleine conscience réduit le stress, améliore la concentration et renforce le bien-être émotionnel. Elle peut être intégrée à la vie quotidienne par la méditation, la respiration profonde et la marche consciente.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '¿Cuáles son los efectos de la deforestación en la biodiversidad, y qué medidas se pueden tomar para proteger los bosques?',
#   'chosen': 'La deforestación reduce la biodiversidad al destruir hábitats y aumentar la extinción de especies. Para proteger los bosques, se pueden implementar políticas de conservación, promover la reforestación y apoyar prácticas sostenibles de uso de la tierra.',
#   'rejected': 'Deforestation reduces biodiversity by destroying habitats and increasing species extinction. Measures include conservation policies, reforestation, and sustainable land use practices.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': "Translate into German: 'She enjoys cooking and often experiments with new recipes.'",
#   'chosen': 'Sie genießt es, zu kochen und probiert oft neue Rezepte aus.',
#   'rejected': 'Elle aime cuisiner et essaie souvent de nouvelles recettes.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'de',
#   'task': 'translation'},
#  {'input': '요약해줘: 태양광 발전은 재생 가능한 에너지원으로, 환경에 미치는 영향이 적고 지속 가능한 에너지 공급을 가능하게 한다. 그러나 초기 설치 비용이 높고, 날씨에 의존적이라는 단점도 존재한다.',
#   'chosen': '태양광 발전은 재생 가능하며 환경 친화적이고 지속 가능한 에너지 공급을 제공한다. 그러나 초기 설치 비용이 높고 날씨에 의존적이라는 단점이 있다.',
#   'rejected': 'Solar power is renewable, environmentally friendly, and provides sustainable energy. However, it has high initial installation costs and is weather-dependent.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'What are the ethical implications of using AI in hiring processes, and how can they be addressed?',
#   'chosen': 'Using AI in hiring raises ethical concerns about bias, transparency, and privacy. These can be addressed through rigorous testing for fairness, clear explanations of AI decisions, and strong data protection measures.',
#   'rejected': "L'utilisation de l'IA dans le recrutement soulève des questions éthiques sur les biais, la transparence et la vie privée. Ces problèmes peuvent être résolus par des tests rigoureux, des explications claires et des mesures de protection des données.",
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '¿Cuál es el impacto de la educación en la reducción de la pobreza, y qué estrategias pueden implementarse para mejorar el acceso a la educación de calidad?',
#   'chosen': 'La educación reduce la pobreza al proporcionar habilidades y oportunidades económicas. Estrategias para mejorar el acceso incluyen aumentar la financiación pública, implementar programas de becas y promover la educación inclusiva.',
#   'rejected': 'Education reduces poverty by providing skills and economic opportunities. Strategies include increasing public funding, implementing scholarship programs, and promoting inclusive education.',
#   'preferred': 1,
#   'input_lang': 'es',
#   'expected_lang': 'es',
#   'task': 'single_language_qa'},
#  {'input': 'Explain how investment in early childhood education contributes to long-term social and economic development, particularly in low-income communities where educational access may be limited.',
#   'chosen': 'Investment in early childhood education enhances cognitive development, reduces future inequality, and builds a stronger workforce, especially in disadvantaged communities.',
#   'rejected': 'When kids get 교육 early, they grow better and the economy 좋아져요 later.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': '请总结：面对快速城市化和人口增长，交通拥堵问题日益严重，城市需要采取绿色出行和智能交通系统等解决方案。',
#   'chosen': '城市化加剧交通拥堵，应推动绿色出行和智能交通系统以缓解问题。',
#   'rejected': '城市有很多车，所以用 smart systems 和绿色交通比较好。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': "Translate to French: 'In response to global water shortages, many countries are investing in desalination technologies and promoting efficient water use in agriculture and households.'",
#   'chosen': "En réponse à la pénurie mondiale d'eau, de nombreux pays investissent dans le dessalement et encouragent une utilisation efficace de l'eau en agriculture et à domicile.",
#   'rejected': 'Desalination est utilisé dans beaucoup de pays pour économiser l’eau in maisons et farms.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'fr',
#   'task': 'translation'},
#  {'input': '요약해줘: 기후 재난의 증가로 인해 정부는 긴급 대응 체계 개선과 재난 대비 교육을 강화하고 있으며, 국제 협력 또한 필수적이다.',
#   'chosen': '기후 재난이 증가함에 따라 정부는 대응 체계를 개선하고 국제 협력이 강조되고 있다.',
#   'rejected': '요즘 기후 재난 많아서 정부가 대책도 하고 국제로 같이 해야 해요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': "Expliquez pourquoi il est crucial de préserver les langues minoritaires pour la diversité culturelle et le patrimoine immatériel de l'humanité.",
#   'chosen': 'Préserver les langues minoritaires protège la diversité culturelle et maintient les connaissances traditionnelles transmises oralement.',
#   'rejected': "Les langues petites sont aussi importantes pour culture et shouldn't disappear comme ça.",
#   'preferred': 1,
#   'input_lang': 'fr',
#   'expected_lang': 'fr',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Japanese: 'To mitigate urban heat island effects, cities are incorporating green rooftops, increasing tree cover, and adopting reflective building materials.'",
#   'chosen': '都市のヒートアイランド現象を緩和するために、緑の屋上や樹木の植栽、反射性の高い建材が導入されている。',
#   'rejected': 'ヒートアイランド問題のために、green rooftop や reflective materials を都市が使っている。',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'ja',
#   'task': 'translation'},
#  {'input': '요약해줘: 저소득층 청소년을 대상으로 하는 예술 교육은 자아 존중감 향상과 사회적 포용에 긍정적인 영향을 미치며, 장기적으로 지역사회 통합에도 기여한다.',
#   'chosen': '예술 교육은 저소득층 청소년의 자존감과 사회 통합에 긍정적인 영향을 준다.',
#   'rejected': '가난한 청소년이 예술 배우면 자존감이 올라가고 사회에서 더 받아들여진다.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'What are the advantages and ethical considerations of using autonomous drones for disaster response in areas that are difficult to access by ground teams?',
#   'chosen': 'Autonomous drones provide rapid assessment and aid delivery in remote disaster zones, but raise concerns about data privacy and decision-making transparency.',
#   'rejected': 'Drones are helpful in 위험지역, but maybe privacy 문제가 생길 수 있어요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': "Translate to Spanish: 'While technological innovation is essential for economic growth, it must be accompanied by policies that ensure equitable access and minimize job displacement.'",
#   'chosen': 'Si bien la innovación tecnológica es clave para el crecimiento económico, debe estar acompañada de políticas que garanticen el acceso equitativo y minimicen la pérdida de empleos.',
#   'rejected': 'Tecnología es buena para la economía, pero también necesita políticas justas para no quitar trabajos.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'es',
#   'task': 'translation'},
#  {'input': '请总结：随着海洋塑料污染的加剧，全球正加强对一次性塑料的监管，并推动循环经济模式来缓解环境压力。',
#   'chosen': '为了应对海洋塑料污染，全球正推动监管和循环经济解决方案。',
#   'rejected': 'Plastic 問題太嚴重了，要限制一次性用品，還有讓大家多回收。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': "Translate into Hindi: 'Improving access to reliable internet connectivity in rural areas can open up opportunities in education, healthcare, and small-scale business development.'",
#   'chosen': 'ग्रामीण क्षेत्रों में विश्वसनीय इंटरनेट कनेक्टिविटी की पहुंच बढ़ाने से शिक्षा, स्वास्थ्य और छोटे व्यवसायों के विकास के अवसर खुल सकते हैं।',
#   'rejected': 'Internet rural जगहों पर होगा तो लोग पढ़ सकेंगे, इलाज मिलेगा और काम कर सकेंगे।',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'hi',
#   'task': 'translation'},
#  {'input': '요약해줘: 유전자 편집 기술은 질병 치료에 혁신적인 가능성을 제시하지만, 생명 윤리 및 사회적 수용성에 대한 논의가 선행되어야 한다.',
#   'chosen': '유전자 편집은 치료 가능성을 높이지만 윤리적 검토가 필요하다.',
#   'rejected': '유전자 바꾸는 기술은 병도 낫게 할 수 있지만, people들이 불안할 수도 있어요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'What are the implications of increasing antibiotic resistance on global health, and what strategies can be implemented to combat this growing threat?',
#   'chosen': 'Antibiotic resistance can lead to untreatable infections and increased mortality; key strategies include prudent antibiotic use, public education, and surveillance systems.',
#   'rejected': '항생제 너무 쓰면 약이 안 들어요. 그래서 사람들이 아플 수 있어요. 조심해야 해요.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': "Translate to Portuguese: 'Ensuring that urban planning includes green infrastructure is vital for climate adaptation and improving residents’ quality of life.'",
#   'chosen': 'Garantir que o planejamento urbano inclua infraestrutura verde é essencial para a adaptação climática e melhoria da qualidade de vida dos moradores.',
#   'rejected': 'Green areas nas cidades ajudam clima e pessoas se sentir melhor.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'pt',
#   'task': 'translation'},
#  {'input': '请总结：数字鸿沟的存在加剧了教育和经济的不平等，各国正在推动普及互联网基础设施以缩小差距。',
#   'chosen': '为了缩小数字鸿沟，各国正在加强互联网基础设施建设，缓解教育和经济不平等。',
#   'rejected': '没网的人上不了课，也找不到工作，所以政府要做基础设施。',
#   'preferred': 1,
#   'input_lang': 'zh',
#   'expected_lang': 'zh',
#   'task': 'summary'},
#  {'input': '요약해줘: 팬데믹 이후 원격 근무의 확산은 근로 형태에 큰 변화를 가져왔으며, 기업들은 디지털 전환과 유연한 업무 환경 구축에 박차를 가하고 있다.',
#   'chosen': '원격 근무의 확산으로 기업들은 유연한 디지털 업무 환경을 빠르게 도입하고 있다.',
#   'rejected': '재택근무가 많아져서 회사들이 디지털로 일하게 바뀌었어요.',
#   'preferred': 1,
#   'input_lang': 'ko',
#   'expected_lang': 'ko',
#   'task': 'summary'},
#  {'input': 'Explain the role of biodiversity in ecosystem resilience, particularly in the context of climate change and natural disasters.',
#   'chosen': 'Biodiversity enhances ecosystem resilience by enabling adaptation to changes and recovery from disturbances such as droughts or floods.',
#   'rejected': 'Lots of species means nature recovers faster when disasters happen, like 홍수 or heat.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'},
#  {'input': "Translate into Indonesian: 'To improve food security, governments are supporting small farmers through access to technology, markets, and sustainable practices.'",
#   'chosen': 'Untuk meningkatkan ketahanan pangan, pemerintah mendukung petani kecil dengan akses terhadap teknologi, pasar, dan praktik berkelanjutan.',
#   'rejected': 'Food security jadi bagus kalau petani kecil bisa punya tools dan sell di market.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'id',
#   'task': 'translation'},
#  {'input': 'Explain the concept of inflation targeting in central banking and its potential benefits and drawbacks.',
#   'chosen': 'Inflation targeting is a monetary policy strategy where a central bank sets a specific inflation rate as its goal, typically around 2%. The bank uses interest rate adjustments and other tools to maintain price stability and guide economic expectations. The benefits include increased transparency, credibility, and long-term economic stability. However, drawbacks may involve reduced flexibility in responding to economic shocks and the potential neglect of other important indicators like employment or GDP growth.',
#   'rejected': 'Inflation targeting ist eine Strategie der Geldpolitik, bei der eine Zentralbank ein bestimmtes Inflationsziel verfolgt. The main advantage is that it makes policy more predictable und transparent, aber it might ignore other wirtschaftliche Faktoren.',
#   'preferred': 1,
#   'input_lang': 'en',
#   'expected_lang': 'en',
#   'task': 'single_language_qa'}]

# %% [markdown]
# ##### 데이터셋 평가 (log likelihood 기반)

# %% [markdown]
# > **결과**\
# > prefer\
# > 1    401\
# > 0    299

# %%
# 평가 수행
results = evaluate_orpo_loglikelihood(orpo_data, base_model, tokenizer, device)

# %%
df_results = pd.DataFrame(results)
df_results
# Out:
#                    task input_lang expected_lang   chosen_ll  rejected_ll  \
# 0    single_language_qa         de            de  -82.994560  -109.435364
# 1               summary         en            en  -44.881851  -132.947449
# 2           translation         zh            zh  -23.871082   -25.237799
# 3           translation         fr            fr  -46.450325   -42.712379
# 4               summary         en            en  -49.928787  -136.437988
# ..                  ...        ...           ...         ...          ...
# 695             summary         zh            zh  -88.713860   -96.719276
# 696             summary         ko            ko  -74.384171  -102.150925
# 697  single_language_qa         en            en  -56.980434  -108.466019
# 698         translation         en            id -189.460419  -127.818497
# 699  single_language_qa         en            en -226.086456  -271.226898
#
#       delta_ll  prefer
# 0    26.440804       1
# 1    88.065598       1
# 2     1.366716       1
# 3    -3.737946       0
# 4    86.509201       1
# ..         ...     ...
# 695   8.005417       1
# 696  27.766754       1
# 697  51.485584       1
# 698 -61.641922       0
# 699  45.140442       1
#
# [700 rows x 7 columns]

# %%
df_results.prefer.value_counts()
# Out:
# prefer
# 1    401
# 0    299
# Name: count, dtype: int64

# %%
# 그룹별 통계 요약 (expected_lang 기준)
summary_by_expected = df_results.groupby("expected_lang")[["chosen_ll", "rejected_ll", "delta_ll"]].agg(["mean", "std"])
summary_by_expected
# Out:
#                 chosen_ll            rejected_ll               delta_ll  \
#                      mean        std        mean        std        mean
# expected_lang
# ar            -106.069562  66.018063  -87.706348  47.808618  -18.363214
# de             -98.745988  27.583184  -86.019151  18.315147  -12.726837
# en             -41.774258  21.423889 -106.252156  58.979052   64.477897
# es            -100.666308  56.655363  -74.265056  20.614815  -26.401253
# fr             -83.350216  30.227851  -80.592276  31.842492   -2.757940
# hi            -245.108856  77.773503 -139.147285  59.396614 -105.961571
# id            -124.735542  45.212881 -111.470629  12.967240  -13.264914
# it             -78.878280  23.033197  -79.779305  21.617062    0.901026
# ja            -133.231836  80.334812  -99.530015  20.556431  -33.701821
# ko             -82.395309  29.652362  -86.614032  20.949382    4.218724
# pt             -70.966367  34.481424  -70.660362  26.792426   -0.306005
# ru            -107.160482   6.260067  -99.090190   1.736645   -8.070292
# tr            -188.062546        NaN -141.217697        NaN  -46.844849
# vi            -146.387344        NaN -103.974701        NaN  -42.412643
# zh             -92.897871  49.084785  -77.718599  22.964223  -15.179272
#
#
#                      std
# expected_lang
# ar             21.194358
# de             24.440663
# en             47.550126
# es             46.976406
# fr             24.499320
# hi             18.376889
# id             33.018319
# it              9.764410
# ja             62.972828
# ko             32.437045
# pt             22.213010
# ru              6.314766
# tr                   NaN
# vi                   NaN
# zh             46.500121

# %%
# 그룹별 통계 요약 (input_lang 기준)
summary_by_input = df_results.groupby("input_lang")[["chosen_ll", "rejected_ll", "delta_ll"]].agg(["mean", "std"])
summary_by_input
# Out:
#              chosen_ll            rejected_ll              delta_ll
#                   mean        std        mean        std       mean        std
# input_lang
# de          -90.900349  31.911419  -80.555370  19.391928 -10.344979  26.312395
# en          -66.229406  46.045878 -111.610799  52.222710  45.381393  60.418943
# es          -96.698770  57.210978  -72.746087  21.295301 -23.952683  47.282847
# fr          -78.075051  26.832456  -73.982068  18.500621  -4.092983  18.103967
# id         -103.233231  23.384523 -107.496662  11.621163   4.263432  11.763359
# ko          -75.115501  32.497512  -82.961574  22.657281   7.846073  32.444459
# pt          -67.984831  25.268219  -80.883988  25.766968  12.899156  15.913153
# zh          -84.272043  53.173346  -72.147475  23.510175 -12.124568  47.912832

# %%
# 태스크별 통계 요약 (input_lang 기준)
summary_by_task = df_results.groupby("task")[["chosen_ll", "rejected_ll", "delta_ll"]].agg(["mean", "std"])
summary_by_task
# Out:
#                     chosen_ll            rejected_ll              delta_ll  \
#                          mean        std        mean        std       mean
# task
# single_language_qa -93.801919  48.309954  -95.971610  41.137382   2.169691
# summary            -63.320049  26.224291  -93.766776  38.132429  30.446727
# translation        -68.557183  49.714016  -71.973543  31.786073   3.416360
#
#
#                           std
# task
# single_language_qa  64.404249
# summary             48.043316
# translation         30.562196

# %% [markdown]
# ### 모델 (체크포인트 480000)

# %% [markdown]
# 결과에 아주 약간의 변동
#
#
#
# > **결과**\
# > prefer\
# > 1    409\
# > 0    291

# %%
# 모델 로딩
checkpoint = "HuggingFaceTB/SmolLM2-135M-intermediate-checkpoints"
revision = "step-480000"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(checkpoint, revision=revision)
model_cp2 = AutoModelForCausalLM.from_pretrained(checkpoint, revision=revision).to(device)

# %% [markdown]
# ##### 위와 같은 데이터셋으로 평가

# %%
# 평가 수행
results = evaluate_orpo_loglikelihood(orpo_data, model_cp2, tokenizer, device)

# %%
df_results = pd.DataFrame(results)
df_results

# prefer 1이면 chosen prefer한 것.
# Out:
#                    task input_lang expected_lang   chosen_ll  rejected_ll  \
# 0    single_language_qa         de            de  -90.066147  -103.525848
# 1               summary         en            en  -50.758705  -115.004005
# 2           translation         zh            zh  -20.733707   -25.993589
# 3           translation         fr            fr  -52.497452   -48.331543
# 4               summary         en            en  -48.395866  -125.646713
# ..                  ...        ...           ...         ...          ...
# 695             summary         zh            zh  -79.738617  -100.218742
# 696             summary         ko            ko  -74.688324   -99.701248
# 697  single_language_qa         en            en  -58.298721  -115.333366
# 698         translation         en            id -189.516403  -127.304939
# 699  single_language_qa         en            en -221.410065  -234.390076
#
#       delta_ll  prefer
# 0    13.459702       1
# 1    64.245300       1
# 2     5.259882       1
# 3    -4.165909       0
# 4    77.250847       1
# ..         ...     ...
# 695  20.480125       1
# 696  25.012924       1
# 697  57.034645       1
# 698 -62.211464       0
# 699  12.980011       1
#
# [700 rows x 7 columns]

# %%
df_results.prefer.value_counts()
# Out:
# prefer
# 1    409
# 0    291
# Name: count, dtype: int64

# %% [markdown]
# ### 모델 (체크포인트 960000)

# %% [markdown]
# 아주 미미하게 나아짐
#
# > **결과**\
# > prefer\
# > 1    419\
# > 0    281

# %%
# 모델 로딩
checkpoint = "HuggingFaceTB/SmolLM2-135M-intermediate-checkpoints"
revision = "step-960000"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(checkpoint, revision=revision)
model_96 = AutoModelForCausalLM.from_pretrained(checkpoint, revision=revision).to(device)

# %% [markdown]
# 같은 데이터셋으로 평가

# %%
results = evaluate_orpo_loglikelihood(orpo_data, model_96, tokenizer, device)

# %%
df_results = pd.DataFrame(results)
df_results

# prefer 1이면 chosen prefer한 것.
# Out:
#                    task input_lang expected_lang   chosen_ll  rejected_ll  \
# 0    single_language_qa         de            de  -89.039795  -108.472519
# 1               summary         en            en  -47.942074  -120.021729
# 2           translation         zh            zh  -21.435986   -27.517677
# 3           translation         fr            fr  -49.453323   -49.571625
# 4               summary         en            en  -48.441071  -120.264587
# ..                  ...        ...           ...         ...          ...
# 695             summary         zh            zh  -81.701996   -97.206123
# 696             summary         ko            ko  -70.480644  -108.663483
# 697  single_language_qa         en            en  -59.765793  -114.258507
# 698         translation         en            id -185.064423  -122.169479
# 699  single_language_qa         en            en -227.822784  -245.074646
#
#       delta_ll  prefer
# 0    19.432724       1
# 1    72.079655       1
# 2     6.081692       1
# 3     0.118301       1
# 4    71.823517       1
# ..         ...     ...
# 695  15.504128       1
# 696  38.182838       1
# 697  54.492714       1
# 698 -62.894943       0
# 699  17.251862       1
#
# [700 rows x 7 columns]

# %%
df_results.prefer.value_counts()
# Out:
# prefer
# 1    419
# 0    281
# Name: count, dtype: int64

# %% [markdown]
# ### 모델 (360M)

# %% [markdown]
# instruction 완료된 새로운 모델 (360m)로 테스트 및 train 수행

# %% [markdown]
# 오... 훨씬 잘 작동함
#
#
# > **결과**\
# > prefer\
# > 1    476\
# > 0    224

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
checkpoint = "HuggingFaceTB/SmolLM2-360M-Instruct"

device = "cuda" # for GPU usage or "cpu" for CPU usage
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# for multiple GPUs install accelerate and do `model = AutoModelForCausalLM.from_pretrained(checkpoint, device_map="auto")
model_360m = AutoModelForCausalLM.from_pretrained(checkpoint).to(device)

# %% [markdown]
# 같은 데이터셋으로 평가

# %%
results = evaluate_orpo_loglikelihood(orpo_data, model_360m, tokenizer, device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 results = evaluate_orpo_loglikelihood(orpo_data, model_360m, tokenizer, device)
#
# NameError: name 'evaluate_orpo_loglikelihood' is not defined

# %%
df_results = pd.DataFrame(results)
df_results

# prefer 1이면 chosen prefer한 것.
# Out:
#                    task input_lang expected_lang   chosen_ll  rejected_ll  \
# 0    single_language_qa         de            de  -64.876671  -112.482338
# 1               summary         en            en  -51.787868  -114.740585
# 2           translation         zh            zh  -13.677735   -30.340347
# 3           translation         fr            fr  -24.268188   -37.116154
# 4               summary         en            en  -46.356712  -108.177017
# ..                  ...        ...           ...         ...          ...
# 695             summary         zh            zh  -72.483459   -94.100983
# 696             summary         ko            ko  -67.127640   -93.554352
# 697  single_language_qa         en            en  -58.218525  -107.994461
# 698         translation         en            id -140.564713  -127.996048
# 699  single_language_qa         en            en -154.906860  -210.086151
#
#       delta_ll  prefer
# 0    47.605667       1
# 1    62.952717       1
# 2    16.662612       1
# 3    12.847965       1
# 4    61.820305       1
# ..         ...     ...
# 695  21.617523       1
# 696  26.426712       1
# 697  49.775936       1
# 698 -12.568665       0
# 699  55.179291       1
#
# [700 rows x 7 columns]

# %%
df_results.prefer.value_counts()
# Out:
# prefer
# 1    476
# 0    224
# Name: count, dtype: int64

# %% [markdown]
# ##### 함수 정의(wpr, lpr)
#
# 구현할 때 참고한 코드: [Language confusion github](https://github.com/for-ai/language-confusion/blob/main/compute_metrics.py)
# - 언어 감지 함수
# - wpr과 lpr 생성 함수
# - text generator

# %%
import fasttext
import re
import string
import jieba
from fugashi import Tagger
from collections import Counter

# fasttext 모델 로드
fasttext_model = fasttext.load_model("lid.176.bin")

# 영어 단어 사전 (길이 >= 4, 소문자만)
EN_WORDS_PATH = "words"  
with open(EN_WORDS_PATH, "r", encoding="utf-8") as f:
    en_words = {word.strip() for word in f if word.strip().islower() and len(word.strip()) > 3}

# 전처리 (문장부호들 빼기~)
def normalize(text):
    text = text.split('\nQ:')[0].strip()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.replace("—", " ").replace("،", "")
    return text.strip()

# 언어 감지 (fasttext)
def langid(text):
    """
    Fasttext 기반 언어 감지하는 함수
    """
    text = text.replace("\n", " ").strip()  # 줄바꿈 제거
    label, score = fasttext_model.predict(text)
    return label[0].replace("__label__", "") if score[0] > 0.3 else "unknown"

ja_tokenizer = Tagger("-O wakati -b 50000")
jieba.initialize()

def tokenize(text, lang):
    if lang == "ja":
        return ja_tokenizer.parse(text).strip().split()
    elif lang == "zh":
        return list(jieba.cut(text))
    else:
        return text.strip().split()

# LPR / WPR 계산 함수
def compute_lpr_wpr(text: str, target_lang: str):
    text = normalize(text)
    lines = text.split("\n")
    tokenized_lines = [tokenize(line, target_lang) for line in lines]
    
    # 너무 짧은 줄 제거 (3단어 미만 제외)
    valid_indices = [i for i, tokens in enumerate(tokenized_lines) if len(tokens) >= 3]
    lines = [lines[i] for i in valid_indices]
    tokenized_lines = [tokenized_lines[i] for i in valid_indices]

    if not lines:
        return {"lpr": 0.0, "wpr": 0.0, "acc": 0.0}

    total_lines = len(lines)
    line_errors = sum(langid(line) != target_lang for line in lines)
    line_pass = (total_lines - line_errors) / total_lines

    # WPR은 line 오류가 없는 경우에만 계산 
    word_error = 0
    if line_errors == 0 and target_lang in ("ar", "hi", "ja", "es", "ko", "ru", "en","zh", "fr", "de", "hi", "id", "it", "pt", "vi"):
        for tokens in tokenized_lines:
            if any(token in en_words for token in tokens):
                word_error += 1
        wpr = 1 - (word_error / len(tokenized_lines)) if len(tokenized_lines) > 0 else 0.0
    else:
        wpr = None

    return {
        "lpr": 1 - (line_errors / total_lines),
        "wpr": wpr if wpr is not None else "N/A",
        "acc": line_pass
    }

from tqdm import tqdm

def clean_generated_text(text: str) -> str:
    # 생성된 텍스트에서 줄바꿈, 숫자 리스트, 기호 등등 제거
    text = text.replace("\n", " ")
    text = re.sub(r"\b\d+\.\b", "", text)         # 1. 2. 3. 형식 제거
    text = re.sub(r"\n+", " ", text)              # 여러 줄바꿈 → 공백
    text = re.sub(r"[•\-–—]", " ", text)          # 리스트 기호 제거
    text = re.sub(r"\s+", " ", text)              # 다중 공백 → 하나
    return text.strip()


def evaluate_generation_language_confusion(data, model, tokenizer, compute_lpr_wpr_fn, device, max_new_tokens=150):
    """
    주어진 프롬프트에 대해 모델이 직접 생성한 응답의 언어 일치율을 평가 (lpr, wpr 지표 이용)

    Args:
        data (list of dict): 각 entry에 'input' (prompt), 'expected_lang' 필드 포함
        compute_lpr_wpr_fn (func): WPR, LPR 계산 함수
        max_new_tokens: 응답 최대 길이

    Returns:
        데이터프레임으로 평가 결과 반환
    """
    results = []

    for entry in tqdm(data):    
        prompt = entry["input"]
        target_lang = entry["expected_lang"]
        task = entry.get("task", "")
        reference = entry.get("reference", "")

        # 응답 생성
        messages = [{"role": "user", "content": prompt}]
        input_text = tokenizer.apply_chat_template(messages, tokenize=False)
        inputs = tokenizer(input_text, return_tensors="pt").to(device)

        # generate 실행!!!
        with torch.no_grad():
            outputs = model.generate(
                inputs["input_ids"],
                max_new_tokens=max_new_tokens,
                temperature=0.7,
                top_p=0.9,
                do_sample=True
            )
        decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # 어시스턴트 응답 부분만 추출
        if "<|assistant|>" in decoded:
            generated = decoded.split("<|assistant|>")[-1].strip()
        elif "assistant\n" in decoded:
            generated = decoded.split("assistant\n", 1)[-1].strip()
        else:
            generated = decoded.strip()

        # if len(generated.split()) < 2:
        #     generated = "[TOO SHORT] " + generated
        
        generated = clean_generated_text(generated)

        # 평가
        wpr, lpr = compute_lpr_wpr_fn(generated, target_lang)
        detected_lang = langid(generated) 

        results.append({
            "task": task,
            "prompt": prompt,
            "reference": reference,
            "generated": generated,
            "target_lang": target_lang,
            "detected_lang": detected_lang,
            "wpr": round(wpr, 4),
            "lpr": lpr
        })

    return pd.DataFrame(results)

# %% [markdown]
# wpr, lpr 평가 함수 잘 작동하는지 테스트~

# %% [markdown]
# 정확도 왜저럼... 미치겟네....
# - 문제 1: lpr이 너무 부정확함
# - 문제 2: 뭘 감지하고 있는건진 모르겠는데 wpr 수치 왔다갔다..
# - 문제 3: 중국어는 아예 감지를 못하는디? 말고도 특정 언어들 감지 잘 못하는듯

# %%
# 데이터셋 로드
with open("orpo_test_data.json", "r", encoding="utf-8") as f:
    orpo_test_data = json.load(f)

# %%
df = evaluate_generation_language_confusion(
    data=orpo_test_data[:40],  # orpo 형식 데이터
    model=model_360m,
    tokenizer=tokenizer,
    compute_lpr_wpr_fn=compute_wpr_lpr, 
    device=device
)
# Out:
# 100%|██████████| 40/40 [01:39<00:00,  2.50s/it]

# %%
df
# Out:
#                   task                                             prompt  \
# 0              summary  Summarize this: 'Regular exposure to natural l...
# 1          translation  Traduce esta frase al francés: 'A balanced die...
# 2              summary  요약해줘: 재택근무는 유연성을 높이고 통근 시간을 줄여 업무 만족도를 높일 수 있지...
# 3          translation  Translate into English: 'Leer regularmente mej...
# 4              summary  Summarize this text: 'Frequent handwashing wit...
# 5   single_language_qa  ¿Cuál es el principal beneficio de la energía ...
# 6          translation  Translate into Korean: 'Exercising regularly c...
# 7              summary  Summarize: 'Vaccination has been proven to be ...
# 8          translation  Translate this sentence into Chinese: 'Reducin...
# 9   single_language_qa                   Was ist der Zweck von Recycling?
# 10  single_language_qa      What is the main function of red blood cells?
# 11  single_language_qa                                지구가 자전하는 데 걸리는 시간은?
# 12  single_language_qa  ¿Cuál es el órgano responsable de bombear la s...
# 13  single_language_qa                                     请问水在常压下的沸点是多少？
# 14  single_language_qa             Was ist die Hauptstadt von Österreich?
# 15  single_language_qa   What gas do plants absorb during photosynthesis?
# 16  single_language_qa                                   태양은 어떤 종류의 별인가요?
# 17  single_language_qa              ¿Cuál es el idioma oficial de Brasil?
# 18  single_language_qa                                      地球上最丰富的气体是什么？
# 19  single_language_qa         Wie viele Kontinente gibt es auf der Erde?
# 20             summary  Summarize this text: 'Global warming leads to ...
# 21         translation  Translate into Korean: 'Artificial intelligenc...
# 22         translation  请翻译这句话：'Exercise can boost mood and reduce the...
# 23  single_language_qa  ¿Cuál es la función principal del sistema inmu...
# 24             summary  요약해줘: 독서 습관은 사고력 향상, 어휘력 확장, 스트레스 감소 등 다양한 이점을...
# 25         translation  Translate this into German: 'Clean water is es...
# 26  single_language_qa                     What is the capital of Canada?
# 27             summary  Bitte fassen Sie diesen Text zusammen: 'Klimaw...
# 28         translation  Translate into French: 'Reading regularly impr...
# 29  single_language_qa                               지구에서 가장 큰 사막은 어디인가요?
# 30             summary              请总结以下内容：绿色能源如太阳能和风能可以减少温室气体排放，改善空气质量。
# 31  single_language_qa     ¿Cómo ayuda la educación a reducir la pobreza?
# 32             summary  Summarize this: 'Climate policies can influenc...
# 33         translation  Translate this into Spanish: 'Public transport...
# 34  single_language_qa  ¿Cuál es el elemento más abundante en el unive...
# 35             summary  Summarize this: 'Electric vehicles are gaining...
# 36         translation  Translate to Chinese: 'A healthy diet includes...
# 37  single_language_qa                          지구의 대기는 어떤 기체들로 구성되어 있나요?
# 38         translation  Translate this sentence into German: 'Regular ...
# 39  single_language_qa                                      请问植物如何进行光合作用？
#
#    reference                                          generated target_lang  \
# 0             Regular exposure to natural light can improve ...          en
# 1             Este tipo de dieta, que contiene los nutriente...          fr
# 2             재택근무는 유연성을 높이고 통근 시간을 줄여 업무 만족도를 높인다는 점에요. 이상한...          ko
# 3             'Read regularly improves concentration and exp...          en
# 4             Handwashing with soap significantly reduces th...          en
# 5             La energía solar, que tiene mucho beneficio en...          es
# 6                  유지하기 적용하기 위해 좋아하는 지부는 천만 안 이해하거나 안 고망하게 됩니다.          ko
# 7             Vaccination has been proven to be one of the m...          en
# 8             '消化水基金及时代的荧光水碳性质传播可以保持世界水浪的平民生活平台并发挥为保护了水基金的水碳性质'          zh
# 9             Der Zweck der Recycling ist, dass die Gesundhe...          de
# 10            Red blood cells, also known as erythrocytes, a...          en
# 11            지구가 자전하는 데 걸리는 시간은 10시를 미리 정확한 날짜로 적용하고, 이제 12...          ko
# 12            La responsabilidad de bombear la sangre es la ...          es
# 13            水在常压下的沸点是一个水培育点，是一种空气沸点。根据你的话，水培育点的沸点比例是多少？ 1....          zh
# 14            The capital city of Österreich, the Federal Re...          de
# 15            In photosynthesis, plants absorb carbon dioxid...          en
# 16                          태양은 어떤 종류의 별인인 경우에요. 이러한 경우에요. 어떠요.          ko
# 17                    El idioma oficial de Brasil es portugués.          es
# 18            气体是一个全球的气味，与地球的气体综合而成。气味只是一种物质的气味，是固急的，因为它们都需要...          zh
# 19            Wie viele Kontinente gibt es auf der Erde? Wen...          de
# 20            Global warming causes rising sea levels, extre...          en
# 21            애프트 연구자원은 분류에 따른 변화를 처리하고, 정원방법으로 이용하여 경상되어 정보...          ko
# 22            "Regular exercise can improve mood and reduce ...          zh
# 23            Sí, es un sistema inmunológico que se encarga ...          es
# 24            요약해줘: 이점을 나타내는 소스 서버 상황에서 다음과 같은 이점을 나타낸다. 1. ...          ko
# 25            'Kleinere Hunde geht aus dem Leben ein, um die...          de
# 26            You're asking about the capital of Canada. The...          en
# 27            Bitte fassen Sie diesen Text zusammen: 'The cl...          de
# 28            Les jeunes sont très importantes pour leur rév...          fr
# 29            나는 가장 큰 사막은 부산미선미선미선미선미선미선미선미선미선미선미선미선미선미선미선미선...          ko
# 30                                绿色能源如太阳能和风能可以减少温室气体排放，改善空气质量。          zh
# 31            Las educaciones son un lugar de la vida más im...          es
# 32            Climate policies can influence global markets ...          en
# 33            El transporte público ayuda reducir la congest...          es
# 34            El elemento más abundante en el universo es la...          es
# 35            Electric vehicles (EVs) are gaining popularity...          en
# 36                   '快樂的食物包括了获得水果和食物的苹果和西瓜和肉产品，以及一些全現著的校验物东西.'          zh
# 37            지구의 대기는 어떤 기체들로 구성되어 있나요. 이걸 아래처럼 어떤 단어가 있는데 아...          ko
# 38            Das darf man zurückzugehen, wie er dazu währen...          de
# 39            植物可以使光合作用的两个方法： 1. 有着着它的离线粒子（比如紫外in钢罐），这些粒子能够从...          zh
#
#    detected_lang     wpr  lpr
# 0             en  1.0000    1
# 1             es  0.0526    0
# 2             ko  1.0000    1
# 3             en  1.0000    1
# 4             en  1.0000    1
# 5             es  0.7619    0
# 6             ko  1.0000    1
# 7             en  0.9333    0
# 8             zh  0.0000    0
# 9             de  0.9412    0
# 10            en  0.8889    0
# 11            ko  1.0000    1
# 12            es  0.4167    0
# 13            zh  0.0000    0
# 14            en  0.0000    0
# 15            en  0.9500    0
# 16            ko  1.0000    1
# 17            es  0.8333    0
# 18            zh  0.0000    0
# 19            de  0.7727    0
# 20            en  0.8182    0
# 21            ko  1.0000    1
# 22            en  0.0000    0
# 23            es  0.6970    0
# 24            ko  1.0000    1
# 25            de  0.9091    0
# 26            en  0.8000    0
# 27            de  0.5556    0
# 28            fr  0.8077    0
# 29            ko  1.0000    1
# 30            zh  0.0000    0
# 31            es  0.6056    0
# 32            en  0.8333    0
# 33            es  0.5714    0
# 34            es  0.5455    0
# 35            en  0.9333    0
# 36            zh  0.0000    0
# 37            ko  1.0000    1
# 38            de  0.8846    0
# 39            zh  0.0000    0

# %% [markdown]
# #### model fine tuning 수행

# %% [markdown]
# train 계획: 앞서, instruct가 완료된 350m 모델을 이용해서 600rows에 대한 log likelihood를 계산해보았을 때, 200개 가량을 잘못 선호하고 있었음.
#
# - step1 : test dataset (현재 약 150개 rows로 구성, 보충필요)로 모델 학습 전 성능 평가
# - step2 : orpo train dataset (아까 평가에 사용한 데이터, 약 700rows로 구성, 보충필요)로 orpo 방식 fine tuning 수행
# - step3 : fine tuned 된 model로 test dataset에 대해서 재평가
#
# *근데 평가 지표는 다시 생각해 보아야 함 . . . (현재 wpr lpr이 제대로 작동하지 않기 때문에, 아직은 앞서 내가 수행했던 것 처럼 log likelihood를 계산해서 비교하는 수 밖에 없을 듯?...)*

# %% [markdown]
# ##### Model train - (with 360m)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# 모델 다시 로드

checkpoint = "HuggingFaceTB/SmolLM2-360M-Instruct"
device = "cuda" # for GPU usage or "cpu" for CPU usage
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model_360m = AutoModelForCausalLM.from_pretrained(checkpoint).to(device)
# Out:
# Total parameters: 361821120
# Trainable parameters: 361821120

# %% [markdown]
# ##### train 전 성능 확인

# %% [markdown]
# orpo_test_data에 관한 360m-instruct-model의 prefer 결과: \
# 1    120\
# 0     43

# %%
# 데이터셋 로드
with open("orpo_test_data.json", "r", encoding="utf-8") as f:
    orpo_test_data = json.load(f)

results = evaluate_orpo_loglikelihood(orpo_test_data, model_360m, tokenizer, device)

df_results = pd.DataFrame(results)
df_results

# prefer 1이면 chosen prefer한 것.
# Out:
#                    task input_lang expected_lang  chosen_ll  rejected_ll  \
# 0               summary         en            en -40.229523  -105.618828
# 1           translation         es            fr -54.397270   -53.397953
# 2               summary         ko            ko -51.461407   -89.669876
# 3           translation         es            en -21.614311   -69.535065
# 4               summary         en            en -28.484894  -115.656044
# ..                  ...        ...           ...        ...          ...
# 158         translation         en            ja -47.487366   -38.843826
# 159             summary         ko            ko -46.220173   -40.308128
# 160  single_language_qa         en            en -30.917070   -89.036697
# 161         translation         en            es -26.265469   -31.918995
# 162             summary         zh            zh -34.319775   -19.129276
#
#       delta_ll  prefer
# 0    65.389305       1
# 1    -0.999317       0
# 2    38.208469       1
# 3    47.920753       1
# 4    87.171150       1
# ..         ...     ...
# 158  -8.643539       0
# 159  -5.912045       0
# 160  58.119627       1
# 161   5.653526       1
# 162 -15.190498       0
#
# [163 rows x 7 columns]

# %%
df_results.prefer.value_counts()
# Out:
# prefer
# 1    120
# 0     43
# Name: count, dtype: int64

# %% [markdown]
# ##### Fine tuning

# %% [markdown]
# fine tuning 함수 구현 (orpo 방식) - 아니 코드를 조금 바꿨더니 다시 문제가 생겨서 학습이 이상해졌슴다 ...
#
# 함수 구현 시 참고한 코드 : [orpo github](https://github.com/xfactlab/orpo/blob/main/trl/test_orpo_trainer_demo.py)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# 모델 다시 로드

checkpoint = "HuggingFaceTB/SmolLM2-360M-Instruct"
device = "cuda" # for GPU usage or "cpu" for CPU usage
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model_360m = AutoModelForCausalLM.from_pretrained(checkpoint).to(device)

# 파라미터 수 확인
print("Total parameters:", sum(p.numel() for p in model_360m.parameters()))
print("Trainable parameters:", sum(p.numel() for p in model_360m.parameters() if p.requires_grad))

# pad_token_id 보정
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# Total parameters: 361821120
# Trainable parameters: 361821120

# %%
from datasets import Dataset
from transformers import AutoTokenizer
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from torch.nn import functional as F
from transformers import AutoModelForCausalLM
import json

# 모델과 토크나이저는 로드되었다고 가정.

# 데이터 로드
with open("orpo_train_data.json", "r", encoding="utf-8") as f:
    orpo_train_data = json.load(f)

dataset = Dataset.from_list(orpo_train_data)

# Tokenization 함수
def tokenize_for_orpo(example):
    prompt_ids = tokenizer.encode(example["input"], add_special_tokens=False, truncation=True, max_length=1024)
    chosen_ids = tokenizer.encode(example["chosen"], add_special_tokens=False, truncation=True, max_length=512)
    rejected_ids = tokenizer.encode(example["rejected"], add_special_tokens=False, truncation=True, max_length=512)
    return {
        "prompt_ids": prompt_ids,
        "chosen_ids": chosen_ids,
        "rejected_ids": rejected_ids,
    }

tokenized_dataset = dataset.map(tokenize_for_orpo)

# Collator for ORPO
class ORPODataCollator:
    def __init__(self, tokenizer):
        self.pad_token_id = getattr(tokenizer, "pad_token_id", tokenizer.eos_token_id or 0)

    def __call__(self, features):
        def pad(batch):
            return pad_sequence([torch.tensor(x) for x in batch], batch_first=True, padding_value=self.pad_token_id)

        chosen_concat = [f["prompt_ids"] + f["chosen_ids"] for f in features]
        rejected_concat = [f["prompt_ids"] + f["rejected_ids"] for f in features]

        return {
            "chosen_concat": pad(chosen_concat),
            "rejected_concat": pad(rejected_concat),
        }

collator = ORPODataCollator(tokenizer)

# original 컬럼 제거
tokenized_dataset = tokenized_dataset.remove_columns(dataset.column_names)

# DataLoader
train_loader = DataLoader(
    tokenized_dataset,
    batch_size=2,
    shuffle=True,
    collate_fn=collator
)

# loss function
def compute_orpo_loss(model, chosen_concat, rejected_concat):
    def get_logps(seq_ids):
        attention_mask = (seq_ids != tokenizer.pad_token_id).long().to(model.device)
        outputs = model(input_ids=seq_ids.to(model.device), attention_mask=attention_mask)
        logits = outputs.logits[:, :-1, :]
        labels = seq_ids[:, 1:].to(model.device)
        log_probs = F.log_softmax(logits, dim=-1)
        logp = torch.gather(log_probs, 2, labels.unsqueeze(-1)).squeeze(-1)
        loss_mask = (labels != tokenizer.pad_token_id).float()
        return (logp * loss_mask).sum(dim=-1)

    chosen_logp = get_logps(chosen_concat)
    rejected_logp = get_logps(rejected_concat)
    loss = -torch.log(torch.sigmoid(chosen_logp - rejected_logp)).mean()
    return loss
# Out:
# Map:   0%|          | 0/700 [00:00<?, ? examples/s]

# %%
from tqdm import tqdm

# 모델을 학습 모드로 전환
model_360m.train()

# 에폭 수 설정
num_epochs = 3

# 전체 학습 반복
for epoch in range(num_epochs):
    print(f"📚 Epoch {epoch + 1}/{num_epochs}")
    total_loss = 0.0

    # 배치 단위로 반복
    for batch in tqdm(train_loader, desc=f"Training epoch {epoch+1}"):
        optimizer.zero_grad()  # 이전 gradient 초기화

        # 손실(loss) 계산
        loss = compute_orpo_loss(model_360m, batch["chosen_concat"], batch["rejected_concat"])

        # 역전파: gradient 계산
        loss.backward()

        # 옵티마이저로 파라미터 업데이트
        optimizer.step()

        # 손실 누적
        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)
    print(f"✅ Epoch {epoch + 1} average loss: {avg_loss:.4f}")
# Out:
# 📚 Epoch 1/3
# Training epoch 1: 100%|██████████| 350/350 [01:44<00:00,  3.36it/s]
# ✅ Epoch 1 average loss: inf
# 📚 Epoch 2/3
# Training epoch 2: 100%|██████████| 350/350 [01:43<00:00,  3.39it/s]
# ✅ Epoch 2 average loss: inf
# 📚 Epoch 3/3
# Training epoch 3: 100%|██████████| 350/350 [01:44<00:00,  3.34it/s]
# ✅ Epoch 3 average loss: inf

# %% [markdown]
# 모델 저장

# %%
# 저장
output_dir = "./orpo-trained-smollm"
model_360m.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# ('./orpo-trained-smollm/tokenizer_config.json',
#  './orpo-trained-smollm/special_tokens_map.json',
#  './orpo-trained-smollm/vocab.json',
#  './orpo-trained-smollm/merges.txt',
#  './orpo-trained-smollm/added_tokens.json',
#  './orpo-trained-smollm/tokenizer.json')

# %% [markdown]
# #### 동일한 테스트 데이터로 재평가

# %% [markdown]
# prefer \
# 1    139 \
# 0     24

# %%
# ORPO JSON 불러오기
with open("orpo_test_data.json", "r", encoding="utf-8") as f:
    orpo_test_data = json.load(f)


# 모델 로드
from transformers import AutoModelForCausalLM, AutoTokenizer

model_path = "./orpo-trained-smollm"
model_ft = AutoModelForCausalLM.from_pretrained(model_path).cuda()
tokenizer_ft = AutoTokenizer.from_pretrained(model_path)
model_ft.eval()


# 평가 실행
df_results = evaluate_orpo_loglikelihood(orpo_test_data, model_ft, tokenizer_ft, device)
df_results.head()
# Out:
#           task input_lang expected_lang  chosen_ll  rejected_ll  delta_ll  \
# 0      summary         en            en        NaN          NaN       NaN
# 1  translation         es            fr        NaN          NaN       NaN
# 2      summary         ko            ko        NaN          NaN       NaN
# 3  translation         es            en        NaN          NaN       NaN
# 4      summary         en            en        NaN          NaN       NaN
#
#    prefer
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_results.prefer.value_counts()
# Out:
# prefer
# 0    163
# Name: count, dtype: int64

# %% [markdown]
# dh!!!!!!!!!! 더 나아졋슴!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ### Model train 수행 2 (with 가장 작은 모델)

# %%
# 모델 로딩
checkpoint = "HuggingFaceTB/SmolLM2-135M-intermediate-checkpoints"
revision = "step-240000"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(checkpoint, revision=revision)
base_model = AutoModelForCausalLM.from_pretrained(checkpoint, revision=revision).to(device)
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(49152, 576)
#     (layers): ModuleList(
#       (0-29): 30 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=576, out_features=576, bias=False)
#           (k_proj): Linear(in_features=576, out_features=192, bias=False)
#           (v_proj): Linear(in_features=576, out_features=192, bias=False)
#           (o_proj): Linear(in_features=576, out_features=576, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=576, out_features=1536, bias=False)
#           (up_proj): Linear(in_features=576, out_features=1536, bias=False)
#           (down_proj): Linear(in_features=1536, out_features=576, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((576,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((576,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((576,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=576, out_features=49152, bias=False)
# )

# %%
print("Total parameters:", sum(p.numel() for p in base_model.parameters()))
print("Trainable parameters:", sum(p.numel() for p in base_model.parameters() if p.requires_grad))

# ✅ pad_token_id 보정
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# Total parameters: 134515008
# Trainable parameters: 134515008

# %% [markdown]
# #### Train 전 성능 확인

# %% [markdown]
# prefer\
# 1    104\
# 0     59

# %%
# ORPO JSON 불러오기
with open("orpo_test_data.json", "r", encoding="utf-8") as f:
    orpo_test_data = json.load(f)

# 평가 실행
base_model_results = evaluate_orpo_loglikelihood(orpo_test_data, base_model, tokenizer, device)
base_model_results.head()
# Out:
#                    task input_lang expected_lang   chosen_ll  rejected_ll  \
# 0               summary         en            en -129.415405  -192.958115
# 1           translation         es            fr -205.192169  -174.897873
# 2               summary         ko            ko -318.202789  -366.273132
# 3           translation         es            en -149.312378  -166.028336
# 4               summary         en            en -112.111847  -214.953918
# ..                  ...        ...           ...         ...          ...
# 158         translation         en            ja -124.010056  -105.323196
# 159             summary         ko            ko -214.033997  -210.766876
# 160  single_language_qa         en            en  -53.687931  -141.002289
# 161         translation         en            es -114.859642  -129.893188
# 162             summary         zh            zh -133.690613  -115.782661
#
#        delta_ll  prefer
# 0     63.542709       1
# 1    -30.294296       0
# 2     48.070343       1
# 3     16.715958       1
# 4    102.842072       1
# ..          ...     ...
# 158  -18.686859       0
# 159   -3.267120       0
# 160   87.314358       1
# 161   15.033546       1
# 162  -17.907951       0
#
# [163 rows x 7 columns]

# %%
base_model_results.prefer.value_counts()
# Out:
# prefer
# 1    104
# 0     59
# Name: count, dtype: int64

# %% [markdown]
# #### Train

# %%
from datasets import Dataset
from transformers import AutoTokenizer
import torch
from torch.nn.utils.rnn import pad_sequence
import torch
from torch.utils.data import DataLoader
from torch.nn import functional as F
from transformers import AutoModelForCausalLM
from torch.optim import AdamW 
from tqdm import tqdm
import json

# Tokenization function
def tokenize_orpo(example, tokenizer):
    prompt_ids = tokenizer.encode(example["input"], add_special_tokens=False)
    chosen_ids = tokenizer.encode(example["chosen"], add_special_tokens=False)
    rejected_ids = tokenizer.encode(example["rejected"], add_special_tokens=False)
    return {
        "prompt_ids": prompt_ids,
        "chosen_ids": chosen_ids,
        "rejected_ids": rejected_ids,
    }

# 데이터셋 전처리
def prepare_tokenized_dataset(dataset, tokenizer):
    tokenized = dataset.map(lambda x: tokenize_orpo(x, tokenizer))
    return tokenized.remove_columns(dataset.column_names)

 
class ORPODataCollator:
    def __init__(self, tokenizer):
        self.pad_token_id = tokenizer.pad_token_id or tokenizer.eos_token_id

    def __call__(self, features):
        def pad(batch):
            return pad_sequence([torch.tensor(x) for x in batch], batch_first=True, padding_value=self.pad_token_id)
        
        chosen_concat = [f["prompt_ids"] + f["chosen_ids"] for f in features]
        rejected_concat = [f["prompt_ids"] + f["rejected_ids"] for f in features]

        return {
            "chosen_concat": pad(chosen_concat),
            "rejected_concat": pad(rejected_concat),
        }

# ORPO Loss function
def compute_orpo_loss(model, chosen_concat, rejected_concat, tokenizer):
    def get_logps(seq_ids):
        seq_ids = seq_ids.to(model.device)
        attention_mask = (seq_ids != tokenizer.pad_token_id).long()
        attention_mask = attention_mask.to(model.device)

        outputs = model(input_ids=seq_ids, attention_mask=attention_mask)
        logits = outputs.logits[:, :-1, :]
        labels = seq_ids[:, 1:]
        labels = labels.to(model.device)

        log_probs = F.log_softmax(logits, dim=-1)
        logp = torch.gather(log_probs, 2, labels.unsqueeze(-1)).squeeze(-1)

        loss_mask = (labels != tokenizer.pad_token_id).float().to(model.device)
        return (logp * loss_mask).sum(dim=-1)

    chosen_logp = get_logps(chosen_concat)
    rejected_logp = get_logps(rejected_concat)
    loss = -torch.log(torch.sigmoid(chosen_logp - rejected_logp)).mean()
    return loss


#  Dataloader 생성 함수
def create_dataloader(tokenized_dataset, tokenizer, batch_size=2):
    collator = ORPODataCollator(tokenizer)
    return DataLoader(
        tokenized_dataset,
        batch_size=batch_size,
        shuffle=True,
        collate_fn=collator
    )


def prepare_tokenized_dataset(data, tokenizer):
    if isinstance(data, list):
        data = Dataset.from_list(data)
    tokenized = data.map(lambda x: tokenize_orpo(x, tokenizer))
    return tokenized.remove_columns(data.column_names)

# %%
from datasets import Dataset

with open("orpo_finetuning_data.json", "r", encoding="utf-8") as f:
    orpo_train_data = json.load(f)

# 리스트 → Dataset 변환
dataset = Dataset.from_list(orpo_train_data)

# 토크나이징 및 컬럼 정리
tokenized_dataset = prepare_tokenized_dataset(dataset, tokenizer)

# 데이터로더 준비
train_loader = create_dataloader(tokenized_dataset, tokenizer, batch_size=2)

# train
optimizer = AdamW(base_model.parameters(), lr=5e-5)

num_epochs = 3 
for epoch in range(num_epochs):
    print(f"Epoch {epoch+1}/{num_epochs}")
    for batch in train_loader:
        optimizer.zero_grad()
        loss = compute_orpo_loss(base_model, batch["chosen_concat"], batch["rejected_concat"], tokenizer)
        loss.backward()
        optimizer.step()
        print(f"Loss: {loss.item():.4f}")
# Out:
# Map:   0%|          | 0/579 [00:00<?, ? examples/s]

# %%
# 저장
output_dir = "./orpo-trained-smollm-base"
base_model.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# ('./orpo-trained-smollm-base/tokenizer_config.json',
#  './orpo-trained-smollm-base/special_tokens_map.json',
#  './orpo-trained-smollm-base/vocab.json',
#  './orpo-trained-smollm-base/merges.txt',
#  './orpo-trained-smollm-base/added_tokens.json',
#  './orpo-trained-smollm-base/tokenizer.json')

# %% [markdown]
# 동일한 데이터셋으로 성능 평가

# %%
# ORPO 테스트 데이터셋 불러오기
with open("orpo_test_data.json", "r", encoding="utf-8") as f:
    orpo_test_data = json.load(f)

# 평가 실행
base_model_results = evaluate_orpo_loglikelihood(orpo_test_data, base_model, tokenizer, device)
base_model_results.head()
# Out:
#           task input_lang expected_lang   chosen_ll  rejected_ll    delta_ll  \
# 0      summary         en            en -129.707504  -195.440765   65.733261
# 1  translation         es            fr -167.368362  -227.213257   59.844894
# 2      summary         ko            ko -342.033936  -415.856567   73.822632
# 3  translation         es            en -172.799515  -203.408218   30.608704
# 4      summary         en            en -115.482971  -226.102814  110.619843
#
#    prefer
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
base_model_results.prefer.value_counts()
# Out:
# prefer
# 1    118
# 0     45
# Name: count, dtype: int64

# %%
with open("orpo_finetuning_data.json", "r", encoding="utf-8") as f:
    orpo_test_data = json.load(f)

# 평가 실행
base_model_results = evaluate_orpo_loglikelihood(orpo_test_data, base_model, tokenizer, device)
base_model_results.prefer.value_counts()
# Out:
# prefer
# 1    579
# Name: count, dtype: int64

# %% [markdown]
# 학습 데이터에 관해서는 전부다 맞게 분류하는 것을 알 수 잇음 !!!!!!!!!

# %% [markdown]
# ---
#
# 오 !!! 나아졋슴
#
# -> 아마 데이터셋 사이즈를 늘려야 할 것 같음

# %% [markdown]
# 내일 할 일 : 데이터셋 5000개 구축. 화이팅
